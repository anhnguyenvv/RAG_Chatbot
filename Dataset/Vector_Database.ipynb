# %%
# !pip install langchain qdrant-client -q
# !pip install -U langchain-community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.6/306.6 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 39.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 16.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.
# Collecting langchain-community
#   Downloading langchain_community-0.3.15-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.11)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.15)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.31)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from langchain<0.4.0,>=0.3.15->langchain-community) (0.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<0.4.0,>=0.3.15->langchain-community) (2.10.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.31->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.31->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.31->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.15->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.15->langchain-community) (2.27.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.15-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 27.3 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading marshmallow-3.26.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 2.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.15 marshmallow-3.26.0 mypy-extensions-1.0.0 pydantic-settings-2.7.1 python-dotenv-1.0.1 typing-inspect-0.9.0

# %%
import os
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain.vectorstores import Qdrant
from qdrant_client import QdrantClient

# %% [markdown]
# # **Tải về văn bản Chương trình đào tạo 2023**

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import gdown

# Link tải file ZIP
# https://drive.google.com/file/d/12U_2V2y5bUB9JLx9DdqDFmGH_OQQLW3o/view?usp=sharing
zip_file_id = '12U_2V2y5bUB9JLx9DdqDFmGH_OQQLW3o'
gdown.download(f'https://drive.google.com/uc?id={zip_file_id}', 'Data.zip', quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12U_2V2y5bUB9JLx9DdqDFmGH_OQQLW3o
# To: /content/Data.zip
# 100%|██████████| 163k/163k [00:00<00:00, 67.2MB/s]
# 'Data.zip'

# %%
import zipfile

with zipfile.ZipFile('Data.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %% [markdown]
# # **Xử lý dữ liệu**

# %%
folder_path = "/content/Data"
documents = []
for file_name in os.listdir(folder_path):
    if file_name.endswith(".txt"):
        file_path = os.path.join(folder_path, file_name)
        loader = TextLoader(file_path)
        documents.extend(loader.load())  # Nạp tài liệu từ từng file

# %%
# Kiểm tra số lượng và kiểu dữ liệu của documents
print(f"Số lượng tài liệu: {len(documents)}, Kiểu dữ liệu của documents: {type(documents)}")

# Kiểm tra nội dung và metadata của tài liệu đầu tiên
print(f"Nội dung của tài liệu đầu tiên: {documents[0].page_content}")
print(f"Metadata của tài liệu đầu tiên: {documents[0].metadata}")
print(f"Source trong metadata của tài liệu đầu tiên: {documents[0].metadata.get('source', 'Không có thông tin về source')}")
# Out:
# Số lượng tài liệu: 10, Kiểu dữ liệu của documents: <class 'list'>
# Nội dung của tài liệu đầu tiên: Ngành Trí tuệ nhân tạo
# Chương trình: Đại học Chính quy
# Khóa tuyển: 2023
# (Ban hành kèm theo Quyết định số 1712/QĐ - KHTN ngày 07/9/2023
# của Hiệu trưởng Trường Đại học Khoa học Tự nhiên, ĐHQG-HCM)
#
# 1. Thông tin chung về chương trình đào tạo
# 1.1. Tên ngành:
# - Tiếng Việt: Trí tuệ nhân tạo
# - Tiếng Anh: Artificial Intelligence
# 1.2. Mã ngành: 7480107
# 1.3. Trình độ đào tạo : Đại học
# 1.4. Tên chương trình : Cử nhân Trí tuệ nhân tạo
# 1.5. Loại hình đào tạo : Chính quy
# 1.6. Thời gian đào tạo : 4 năm
# 1.7. Tên văn bằng sau khi tốt nghiệp:
# - Tiếng Việt : Cử nhân Trí tuệ nhân tạo
# - Tiếng Anh Bachelor of Science in Artificial Intelligence
# 1.8. Ngôn ngữ giảng dạy tiếng Việt
# 1.9. Nơi đào tạo:
# - Cơ sở 1: 227 Nguyễn Văn Cừ, P4, Q5, Tp. HCM
# - Cơ sở 2: Phường Linh Trung, Thành phố Thủ Đức, Tp. HCM
#
# 2. Mục tiêu đào tạo
# 2.1. Mục tiêu chung
# Mục tiêu của chương trình là nhằm đào tạo ra các sinh viên tốt nghiệp:
# - Có kiến thức kỹ thuật vững chắc; hiểu được trách nhiệm và đạo đức nghề nghiệp để áp dụng các công nghệ, kỹ thuật mới nhất của ngành công nghệ thông tin (CNTT) vào việc giải quyết các vấn đề thực tế; có thể áp dụng các phương pháp khoa học trong việc thực hiện nghiên cứu trong lĩnh vực CNTT.
# - Được trang bị những kỹ năng cá nhân, kỹ năng nhóm, kỹ năng giao tiếp và kỹ năng phân tích để nhận biết và giải quyết các vấn đề thực tế một cách có hệ thống, có logic và sáng
# tạo.
# - Được trang bị đầy đủ kiến thức và kỹ năng để có thể hình thành vấn đề, phân tích, thiết kế, giải quyết vấn đề và vận hành hệ thống CNTT.
#
# 2.2. Mục tiêu cụ thể
# PO1: Nhận biết được trách nhiệm, đạo đức nghề nghiệp, và hiện trạng kinh tế, môi trường
# và xã hội.
# PO2: Có đầy đủ các kỹ năng cá nhân, kỹ năng nhóm, kỹ năng giao tiếp và kỹ năng phân
# tích.
# РОЗ: Có khả năng học và tự học suốt đời; có khả năng kế thừa và phát triển kiến thức, kỹ năng chuyên môn.
# PO4: Có khả năng áp dụng các kiến thức và kỹ năng chuyên môn trong quá trình giải quyết các vấn đề thực tế.
# PO5: Có khả năng hình thành ý tưởng, phân tích, thiết kế, giải quyết và vận hành các hệ thống CNTT.
# PO6: Có khả năng sử dụng các công cụ, phương pháp, quy trình, kỹ thuật,... trong quá trình giải quyết các bài toán CNTT.
#
# 2.3. Chuẩn đầu ra (CĐR) của chương trình đào tạo
# ELO 1. Kiến thức
# ELO 1. 1. Kiến thức nền tảng về Khoa học
# ELO 1. 1. 1 Khối kiến thức về Toán
# ELO 1. 1. 2 Khối kiến thức về Vật lý
# ELO 1. 1. 3 Khối kiến thức về Điện – Điện tử
# ELO 1. 2. Kiến thức nền tảng của lĩnh vực CNTT
# ELO 1. 2. 1 Khối kiến thức về lập trình
# ELO 1. 2. 2 Kiến thức tổng quát về lĩnh vực CNTT
# ELO 1. 3. Kiến thức kỹ thuật nâng cao, các công cụ và phương pháp trong ngành CNTT
# ELO 1. 3. 1 Khối kiến thức cấu trúc dữ liệu và giải thuật
# ELO 1. 3. 2 Khối kiến thức về hệ điều hành máy tính
# ELO 1. 3. 3 Khối kiến thức kiến trúc máy tính
# ELO 1. 3. 4 Khối kiến thức mạng máy tính
# ELO 1. 3. 5 Khối kiến thức cơ sở dữ liệu
# ELO 1. 3. 6 Khối kiến thức về an ninh, bảo mật và tính riêng tư
# ELO 1. 3. 7 Các công cụ, phương pháp và công nghệ hỗ trợ trong ngành CNTT
# ELO 1. 4. Các kiến thức nâng cao của Hệ thống thông tin
# ELO 1. 4. 1 Kiến thức về dữ liệu và khai thác dữ liệu
# ELO 1. 4. 2 Kiến thức về Hệ thống thông tin
# ELO 1. 4. 3 Kiến thức về các loại ứng dụng Hệ thống thông tin
#
# ELO 2. Kỹ năng mềm
# ELO 2. 1. Kỹ năng và tính cách cá nhân
# ELO 2. 1. 1 Độc lập
# ELO 2. 1. 2 Tự tin trong môi trường nghề nghiệp
# ELO 2. 1. 3 Sẵn sàng ra quyết định
# ELO 2. 1. 4 Cách nghĩ sáng tạo
# ELO 2. 1. 5 Cách nghĩ mang tính phản biện
# ELO 2. 1. 6 Thích nghi vào môi trường mới
# ELO 2. 1. 7 Quản lý tài nguyên cá nhân (thời gian, tiền bạc...)
# ELO 2. 1. 8 Học và tự học suốt đời
# ELO 2. 1. 9 Quản trị dự án
# ELO 2. 2. Kỹ năng nhóm
# ELO 2. 2. 1 Thành lập nhóm
# ELO 2. 2. 2 Hoạt động trong nhóm
# ELO 2. 2. 3 Lãnh đạo nhóm
# ELO 2. 2. 4 Phát triển nhóm
# ELO 2. 3. Kỹ năng giao tiếp
# ELO 2. 3. 1 Kỹ năng giao tiếp nghe, nói, đọc, viết
# ELO 2. 3. 2 Kỹ năng trình bày
# ELO 2. 3. 3 Kỹ năng đàm phán
# ELO 2. 3. 4 Kỹ năng phát triển các mối quan hệ xã hội
# ELO 2. 4. Kỹ năng ngoại ngữ
# ELO 2. 4. 1 Kỹ năng nói tiếng Anh
# ELO 2. 4. 2 Kỹ năng nghe tiếng Anh
# ELO 2. 4. 3 Kỹ năng đọc tiếng Anh
# ELO 2. 4. 4 Kỹ năng viết tiếng Anh
# ELO 2. 4. 5 Sử dụng các thuật ngữ chuyên ngành
# ELO 2. 5. Kỹ năng lãnh đạo
# ELO 2. 5. 1 Thái độ lãnh đạo
# ELO 2. 5. 2 Nhận biết các vấn đề, sự cố và nghịch lý
# ELO 2. 5. 3 Đề xuất và sáng tạo trong việc giải quyết các vấn đề, sự cố
# ELO 2. 5. 4 Xây dựng và dẫn dắt một tổ chức
# ELO 2. 5. 5 Lên kế hoạch và dẫn dắt dự án đến thành công
# ELO 2. 6. Kỹ năng khởi nghiệp
# ELO 2. 6. 1 Thành lập công ty, tổ chức công ty và quản trị
# ELO 2. 6. 2 Viết kế hoạch kinh doanh
# ELO 2. 6. 3 Tài chính công ty
# ELO 2. 6. 4 Hình thành ý tưởng sản phẩm, dịch vụ dựa trên công nghệ
# ELO 2. 6. 5 Sáng tạo trong sản phẩm/ dịch vụ, quảng bá
#
# ELO 3. Ngữ cảnh, trách nhiệm và đạo đức
# ELO 3. 1. Ngữ cảnh bên ngoài, xã hội, kinh tế và môi trường
# ELO 3. 1. 1 Các vấn đề và giá trị của xã hội, kinh tế và môi trường đương đại
# ELO 3. 1. 2 Vai trò và trách nhiệm
# ELO 3. 1. 3 Ngữ cảnh văn hóa, lịch sử
# ELO 3. 1. 4 Luật lệ và quy định của xã hội
# ELO 3. 2. Ngữ cảnh công ty và doanh nghiệp
# ELO 3. 2. 1 Ngữ cảnh và văn hóa của công ty, tổ chức
# ELO 3. 2. 2 Các bên liên quan, mục tiêu và chiến lược của công ty/ doanh nghiệp
# ELO 3. 2. 3 Luật lệ và quy định của công ty/ doanh nghiệp
# ELO 3. 3. Đạo đức, trách nhiệm và các giá trị cá nhân cốt lõi
# ELO 3. 3. 1 Các chuẩn mực và nguyên tắc đạo đức
# ELO 3. 3. 2 Trách nhiệm và cách hành xử chuyên nghiệp
# ELO 3. 3. 3 Sự cam kết
# ELO 3. 3. 4 Trung thực, uy tín và trung thành
#
# ELO 4. Phương pháp khoa học và nghiên cứu
# ELO 4. 1. Suy luận có phân tích và giải quyết vấn đề
# ELO 4. 1. 1 Xác định và hình thành vấn đề
# ELO 4. 1. 2 Mô hình hóa và phân tích
# ELO 4. 1. 3 Suy luận và giải quyết
# ELO 4. 1. 4 Đánh giá giải pháp và đề xuất
# ELO 4. 2. Thực nghiệm, điều tra và khám phá tri thức
# ELO 4. 2. 1 Hình thành giả thuyết
# ELO 4. 2. 2 Khảo sát trên tài liệu
# ELO 4. 2. 3 Khảo sát trên thực tế
# ELO 4. 2. 4 Kiểm chứng và bảo vệ giả thuyết
# ELO 4. 3. Suy nghĩ tầm mức hệ thống
# ELO 4. 3. 1 Suy nghĩ toàn cục
# ELO 4. 3. 2 Sự tương tác giữa các thành phần trong hệ thống
# ELO 4. 3. 3 Xác định độ ưu tiên và quan trọng
# ELO 4. 3. 4 Đánh giá hệ thống
#
# ELO 5. Hình thành ý tưởng, thiết kế và hiện thực hóa hệ thống CNTT
# ELO 5. 1. Hình thành ý tưởng/ bài toán/ dự án
# ELO 5. 1. 1 Xác định mục tiêu của bài toán/ dự án và thu thập yêu cầu
# ELO 5. 1. 2 Phân tích và nghiên cứu tính khả thi của bài toán/ dự án
# ELO 5. 1. 3 Đặc tả mục tiêu, yêu cầu của bài toán/ dự án
# ELO 5, 2. Thiết kế hệ thống CNTT (giải pháp, sản phẩm, ...)
# ELO 5. 2. 1 Tiến trình và phương pháp thiết kế
# ELO 5. 2. 2 Thiết kế kiến trúc và các thành phần của hệ thống CNTT (chức năng, cơ sở dữ liệu,...)
# ELO 5. 2. 3 Thiết kế đa ngành, đa mục tiêu
# ELO 5. 3. Hiện thực hóa (implementation)
# ELO 5. 3. 1 Các tiến trình và phương pháp hiện thực hóa
# ELO 5. 3. 2 Hiện thực hóa hệ thống dựa trên thiết kế
# ELO 5. 3. 3 Tích hợp các thành phần trong hệ thống
#
# ELO 6. Kiểm chứng, vận hành, bảo trì và phát triển hệ thống CNTT
# ELO 6. 1. Kiểm chứng
# ELO 6. 1. 1 Tiến trình và phương pháp kiểm chứng
# ELO 6. 1. 2 Kiểm chứng các yêu cầu
# ELO 6. 1. 3 Kiểm chứng các thành phần hay toàn bộ hệ thống
# ELO 6. 2. Vận hành và bảo trì
# ELO 6. 2. 1 Huấn luyện và vận hành
# ELO 6. 2. 2 Quản lý việc vận hành
# ELO 6. 2. 3 Bảo trì hệ thống
# ELO 6. 3. Cải tiến và kết thúc
# ELO 6. 3. 1 Cải tiến hệ thống
# ELO 6. 3. 2 Kết thúc và hủy bỏ hệ thống
#
# 2.4. Cơ hội nghề nghiệp/ công việc người học có thể đảm nhận
# Sinh viên sau khi tốt nghiệp có thể có các cơ hội nghề nghiệp sau:
# - Các vị trí thuộc nhóm Phát triển hệ thống phần mềm: Phân tích phần mềm, Thiết kế phần mềm, Lập trình phần mềm, Phát triển phẩn mềm, Kiểm thử phần mềm, Triển khai và vận hành hệ thống, Quản lý dự án, Tư vấn giải pháp, v.v...
# - Các vị trí thuộc nhóm Hệ thống thông tin: Thiết kế và Quản trị cơ sở dữ liệu, Quản trị hệ thống CNTT cho doanh nghiệp, Tư vấn hệ thống CNTT, Quản trị thông tin, Quản trị an ninh/bảo mật, Phân tích dữ liệu, Kỹ sư dữ liệu, Tư vấn kiến trúc dữ liệu, Giám đốc
# thông tin, v.v...
# - Các vị trí thuộc nhóm Mạng máy tính và viễn thông: Lập trình viên mạng máy tính, Kỹ sư bảo mật máy tính, Kỹ sư phát triển – vận hành hệ thống CNTT cho doanh nghiệp, Quản trị mạng, Quản trị hệ thống CNTT, An ninh và bảo mật hệ thống mạng, v.v...
# - Các vị trí thuộc nhóm Nghiên cứu và triển khai giải pháp tại các viện, trường đại học, phòng thí nghiệm, các công ty phần mềm: Máy học, Khai thác dữ liệu, Xử lý ngôn ngữ,
# V.V...
# - Các vị trí thuộc nhóm Trí tuệ nhân tạo: Thiết kế và xây dựng các thuật toán học máy, học sâu; Thiết kế và xây dựng các ứng dụng xử lý ngôn ngữ tự nhiên (hiểu ngôn ngữ, tóm tắt văn bản, hệ thống hỏi và đáp, nhận dạng tiếng nói,...), thị giác máy tính,..
# - Các vị trí thuộc nhóm Giảng dạy: Trợ giảng, Giáo viên, Giảng viên các cấp phổ thông, trung tâm đào tạo, cao đẳng, đại học, V.V...
# - Các vị trí khác: tư vấn, huấn luyện về các hệ thống, giải pháp CNTT, v.v...
#
# 3. Khối lượng kiến thức toàn khóa: 138 tín chỉ (Không kể môn Giáo dục Quốc phòng - An ninh, Giáo dục thể chất và ngoại ngữ)
#
# 4. Đối tượng tuyển sinh
# Theo Quy chế tuyển sinh của Bộ Giáo dục và đào tạo và Đại học Quốc gia Thành phố Hồ Chí Minh.
#
# 5. Quy trình đào tạo và điều kiện tốt nghiệp
# 5.1. Quy trình đào tạo
# Căn cứ Quy chế đào tạo trình độ đại học ban hành kèm theo Quyết định số 1175/QĐ-KHTN
# ngày 24 tháng 9 năm 2021 của Hiệu trưởng Trường Đại học Khoa học Tự nhiên, ĐHQG-HCM.
# 5.2. Điều kiện tốt nghiệp
# Sinh viên phải đồng thời thỏa các điều kiện sau đây:
# - Tích lũy đủ số tín chỉ của khối kiến thức giáo dục đại cương và giáo dục chuyên nghiệp như đã mô tả ở mục 6. Cấu trúc chương trình đào tạo và mục 7. Nội dung chương trình đào tạo của Chương trình đào tạo này;
# - Thỏa các điều kiện tại Điều 17 của Quy chế đào tạo trình độ đại học ban hành kèm theo Quyết định số 1175/QĐ-KHTN ngày 24 tháng 9 năm 2021 của Hiệu trưởng Trường Đại học Khoa học Tự nhiên, ĐHQG-HCM.
#
# 6. Cấu trúc chương trình đào tạo
# Tổng số tín chỉ tích lũy: 138 tín chỉ
# 6.1. Giáo dục đại cương (Không kể Ngoại ngữ, Giáo dục thể chất và Giáo dục Quốc phòng - An ninh)
# Tổng cộng 56 tín chỉ bao gồm:
# - Bắt buộc: 42
# - Tự chọn: 14
# - Tự chọn tự do: 0
#
# 6.2. Giáo dục chuyên nghiệp Ngành Trí tuệ nhân tạo
# Tổng cộng 82 tín chỉ
# 6.2.1. Cơ sở ngành
# Tổng cộng 38 tín chỉ bao gồm:
# - Bắt buộc: 38
# - Tự chọn: 0
# - Tự chọn tự do: 0
#
# 6.2.2. Ngành/Chuyên ngành
# Tổng cộng 34 tín chỉ bao gồm:
# - Bắt buộc: 16
# - Tự chọn: 8
# - Tự chọn tự do: 10
#
# 6.2.3. Tốt nghiệp
# Tổng cộng 10 tín chỉ bao gồm:
# - Bắt buộc: 0
# - Tự chọn: 10
# - Tự chọn tự do: 0
#
# 7. Nội dung chương trình đào tạo
# 7.1. Kiến thức giáo dục đại cương
# Tổng số tín chỉ tích lũy: 56 tín chỉ (không kể Ngoại ngữ, Giáo dục thể chất và Giáo dục quốc phòng – an ninh)
# 7.1.1. Lý luận chính trị - Pháp luật
# Tổng số tín chỉ tích lũy: 14 tín chỉ
# - STT: 1
# - Tên học phần: Triết học Mác – Lênin
# - Mã học phần: BAA00101
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - STT: 2
# - Tên học phần: Kinh tế chính trị Mác – Lênin
# - Mã học phần: BAA00102
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
#
# - STT: 3
# - Tên học phần: Chủ nghĩa xã hội khoa học
# - Mã học phần: BAA00103
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
#
# - STT: 4
# - Tên học phần: Lịch sử Đảng Cộng sản Việt Nam
# - Mã học phần: BAA00104
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
#
# - STT: 5
# - Tên học phần: Tư tưởng Hồ Chí Minh
# - Mã học phần: BAA00103
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
#
# - STT: 6
# - Tên học phần: Pháp luật đại cương
# - Mã học phần: BAA00004
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# 7.1.2. Khoa học xã hội – Kinh tế – Kỹ năng
# Tổng số tín chỉ tích lũy: 2 tín chỉ
# Chọn 1 học phần:
# - STT: 1
# - Tên học phần: Kinh tế đại cương
# - Mã học phần: BAA00005
# - Số tín chỉ: 2
# - Loại học phần: Tự chọn
#
# - STT: 2
# - Tên học phần: Tâm lý đại cương
# - Mã học phần: BAA00006
# - Số tín chỉ: 2
# - Loại học phần: Tự chọn
#
# - STT: 3
# - Tên học phần: Phương pháp luận sáng tạo
# - Mã học phần: BAA00007
# - Số tín chỉ: 2
# - Loại học phần: Tự chọn
#
# 7.1.3. Toán – Khoa học tự nhiên – Công nghệ – Môi trường
# - STT: 1
# - Tên học phần: Vi tích phân 1B
# - Mã học phần: MTH00003
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - STT: 2
# - Tên học phần: Thực hành Vi tích phân 1B
# - Mã học phần: MTH00081
# - Số tín chỉ: 1
# - Loại học phần: Bắt buộc
#
# - STT: 3
# - Tên học phần: Vi tích phân 2B
# - Mã học phần: MTH00004
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - STT: 4
# - Tên học phần: Thực hành Vi tích phân 2B
# - Mã học phần: MTH00082
# - Số tín chỉ: 1
# - Loại học phần: Bắt buộc
#
# - STT: 5
# - Tên học phần: Đại số tuyến tính
# - Mã học phần: MTH00007
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - STT: 6
# - Tên học phần: Thực hành Đại số tuyến tính
# - Mã học phần: MTH00083
# - Số tín chỉ: 1
# - Loại học phần: Bắt buộc
#
# - STT: 7
# - Tên học phần: Xác suất thống kê
# - Mã học phần: MTH00008
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - STT: 8
# - Tên học phần: Thực hành Xác suất thống kê
# - Mã học phần: MTH00085
# - Số tín chỉ: 1
# - Loại học phần: Bắt buộc
#
# - STT: 9
# - Tên học phần: Toán rời rạc
# - Mã học phần: MTH00041
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - STT: 10
# - Tên học phần: Thực hành Toán rời rạc
# - Mã học phần: MTH00086
# - Số tín chỉ: 1
# - Loại học phần: Bắt buộc
#
# - STT: 11
# - Tên học phần: Toán học tổ hợp
# - Mã học phần: MTH00050
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - STT: 12
# - Tên học phần: Toán ứng dụng và thống kê
# - Mã học phần: MTH00051
# - Số tín chỉ: 4
# - Loại học phần: Tự chọn
#
# - STT: 13
# - Tên học phần: Phương pháp tính
# - Mã học phần: MTH00052
# - Số tín chỉ: 4
# - Loại học phần: Tự chọn
#
# - STT: 14
# - Tên học phần: Lý thuyết số
# - Mã học phần: MTH00053
# - Số tín chỉ: 4
# - Loại học phần: Tự chọn
#
# - STT: 15
# - Tên học phần: Hóa đại cương 1
# - Mã học phần: CHE00001
# - Số tín chỉ: 3
# - Loại học phần: Tự chọn
#
# - STT: 16
# - Tên học phần: Hóa đại cương 2
# - Mã học phần: CHE00002
# - Số tín chỉ: 3
# - Loại học phần: Tự chọn
#
# - STT: 17
# - Tên học phần: Sinh đại cương 1
# - Mã học phần: BIO00001
# - Số tín chỉ: 3
# - Loại học phần: Tự chọn
#
# - STT: 18
# - Tên học phần: Sinh đại cương 2
# - Mã học phần: BIO00002
# - Số tín chỉ: 3
# - Loại học phần: Tự chọn
#
# - STT: 19
# - Tên học phần: Vật lý đại cương 1 (Cơ - Nhiệt)
# - Mã học phần: PHY00001
# - Số tín chỉ: 3
# - Loại học phần: Tự chọn
#
# - STT: 20
# - Tên học phần: Khoa học Trái đất
# - Mã học phần: GEO00002
# - Số tín chỉ: 2
# - Loại học phần: Tự chọn
#
# Tổng cộng số tín chỉ: 36
#
# 7.1.4 Tin học
# - STT: 1
# - Tên học phần: Nhập môn công nghệ thông tin
# - Mã học phần: CSC00004
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# 7.1.5 Ngoại ngữ (không tính vào điểm trung bình và tín chỉ tích lũy)
# Ghi chú: SV đạt chuẩn ngoại ngữ đầu ra theo quy định hiện hành thì không đăng ký học các học phần Anh văn
# - STT: 1
# - Tên học phần: Anh văn 1
# - Mã học phần: ADD00031
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - STT: 2
# - Tên học phần: Anh văn 2
# - Mã học phần: ADD00032
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - STT: 3
# - Tên học phần: Anh văn 3
# - Mã học phần: ADD00033
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - STT: 4
# - Tên học phần: Anh văn 4
# - Mã học phần: ADD00034
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# 7.1.6 Giáo dục thể chất (không tính vào điểm trung bình và tín chỉ tích lũy)
# - STT: 1
# - Tên học phần: Thể dục 1
# - Mã học phần: BAA00021
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
#
# - STT: 2
# - Tên học phần: Thể dục 2
# - Mã học phần: BAA00022
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
#
# 7.1.7 Giáo dục quốc phòng - an ninh (không tính vào điểm trung bình và tín chỉ tích lũy)
# - STT: 1
# - Tên học phần: Giáo dục quốc phòng – An ninh
# - Mã học phần: BAA00030
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# 7.2. Kiến thức giáo dục chuyên nghiệp
# Khối kiến thức này bao gồm: kiến thức cơ sở ngành, kiến thúc ngành và kiến thức tốt nghiệp
# 7.2.1. Kiến thức cơ sở ngành
# - STT: 1
# - Tên học phần: Nhập môn lập trình
# - Mã học phần: CSC10001
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - STT: 2
# - Tên học phần: Kỹ thuật lập trình
# - Mã học phần: CSC10002
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - STT: 3
# - Tên học phần: Phương pháp lập trình hướng đối tượng
# - Mã học phần: CSC10003
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - STT: 4
# - Tên học phần: Cấu trúc dữ liệu và giải thuật
# - Mã học phần: CSC10004
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - STT: 5
# - Tên học phần: Cơ sở dữ liệu
# - Mã học phần: CSC10006
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - STT: 6
# - Tên học phần: Hệ điều hành
# - Mã học phần: CSC10007
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - STT: 7
# - Tên học phần: Mạng máy tính
# - Mã học phần: CSC10008
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - STT: 8
# - Tên học phần: Hệ thống máy tính
# - Mã học phần: CSC10009
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
#
# - STT: 9
# - Tên học phần: Nhập môn công nghệ phần mềm
# - Mã học phần: CSC13002
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - STT: 10
# - Tên học phần: Cơ sở trí tuệ nhân tạo
# - Mã học phần: CSC14003
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# 7.2.2. Kiến thức ngành/ chuyên ngành: gồm các kiến thức bắt buộc, tự chọn và tự chọn tự do (tổng cộng 34 tín chỉ) như sau:
# 7.2.2.1. Kiến thức bắt buộc ngành/ chuyên ngành
# Sinh viên tích lũy ít nhất 4 học phần, sao cho tối thiểu 16 tín chỉ, trong danh sách học phần sau đây:
# STT: 1
# Tên học phần: Khai thác dữ liệu và ứng dụng
# Mã học phần: CSC14004
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 2
# Tên học phần: Nhập môn học máy
# Mã học phần: CSC14005
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 3
# Tên học phần: Nhập môn xử lý ngôn ngữ tự nhiên
# Mã học phần: CSC15006
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 4
# Tên học phần: Xử lý tín hiệu số
# Mã học phần: CSC15009
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 5
# Tên học phần: Thị giác máy tính
# Mã học phần: CSC16004
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 6
# Tên học phần: Nhập môn học sâu
# Mã học phần: CSC18001
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# 7.2.2.2. Kiến thức tự chọn ngành/chuyên ngành
# Sinh viên tích lũy ít nhất 2 học phần, sao cho tối thiểu 8 tín chỉ, trong danh sách học phần sau đây:
# STT: 1
# Tên học phần: Kiến tập nghề nghiệp
# Mã học phần: CSC10102
# Số tín chỉ: 2
# Loại học phần: Tự chọn
#
# STT: 2
# Tên học phần: Khởi nghiệp
# Mã học phần: CSC10103
# Số tín chỉ: 3
# Loại học phần: Tự chọn
#
# STT: 3
# Tên học phần: Quy hoạch tuyến tỉnh
# Mã học phần: CSC10104
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 4
# Tên học phần: Tương tác người - máy
# Mã học phần: CSC12106
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 5
# Tên học phần: Sinh trắc học
# Mã học phần: CSC14112
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 6
# Tên học phần: Lập trình song song
# Mã học phần: CSC14120
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 7
# Tên học phần: Blockchain và ứng dụng
# Mã học phần: CSC15010
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 8
# Tên học phần: Ứng dụng xử lý ảnh số và video số
# Mã học phần: CSC16109
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 9
# Tên học phần: Phân tích dữ liệu thông minh
# Mã học phần: CSC17001
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 10
# Tên học phần: Trí tuệ nhân tạo cho an ninh thông tin
# Mã học phần: CSC18101
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 11
# Tên học phần: Phương pháp toán cho tối ưu
# Mã học phần: CSC18102
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 12
# Tên học phần: Trí tuệ bầy đàn
# Mã học phần: CSC18103
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 13
# Tên học phần: Nhập môn hệ thống đa tác nhân
# Mã học phần: CSC18104
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# 7.2.2.3. Kiến thức tự chọn tự do
# Nếu tổng số tín chỉ của những học phần bắt buộc và tự chọn ngành/ chuyên ngành chưa đủ 34 tín chỉ thì sinh viên tiếp tục tích lũy đủ ít nhất 34 tín chỉ cho phần kiến thức ngành của khối kiến thức giáo dục chuyên nghiệp, bằng cách chọn trong danh sách các học phần thuộc các mục sau đây:
# STT: 1
# Tên học phần: Kỹ năng mềm
# Mã học phần: CSC10121
# Số tín chỉ: 3
# Loại học phần: Tự chọn
#
# STT: 2
# Tên học phần: Lập trình mạng
# Mã học phần: CSC11003
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 3
# Tên học phần: Mạng máy tính nâng cao
# Mã học phần: CSC11004
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 4
# Tên học phần: Cơ sở dữ liệu nâng cao
# Mã học phần: CSC12002
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 5
# Tên học phần: Hệ quản trị cơ sở dữ liệu
# Mã học phần: CSC12003
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 6
# Tên học phần: Phân tích thiết kế hệ thống thông tin
# Mã học phần: CSC12004
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 7
# Tên học phần: Quản lý dự án phần mềm
# Mã học phần: CSC13006
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 8
# Tên học phần: Phát triển phần mềm cho thiết bị di động
# Mã học phần: CSC13009
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 9
# Tên học phần: Thiết kế giao diện
# Mã học phần: CSC13112
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# Hoặc các học phần thuộc các mục sau đây:
# mục 7.2.2.1. và mục 7.2.2.2. (bên trên);
# mục 7.2.3. (bên dưới);
# mục 7.2.2.1. và mục 7.2.2.2. của chương trình đào tạo đại học chính quy ngành Kỹ thuật phần mềm, khóa tuyển 2023;
# mục 7.2.2.x.1. và mục 7.2.2.x.2. (với 1≤x≤ 5) của chương trình đào tạo đại học chính quy ngành Khoa học máy tính, khóa tuyển 2023;
# mục 7.2.2.1. và mục 7.2.2.2. của chương trình đào tạo đại học chính quy ngành Trí tuệ nhân tạo, khóa tuyển 2023;
# mục 7.2.2.1.1. và mục 7.2.2.1.2. của chương trình đào tạo đại học chính quy ngành Công nghệ thông tin, khóa tuyển 2023.
# (chi tiết xem tại mục 9. PHỤ LỤC 1: CÁC HỌC PHẦN TỰ CHỌN TỰ DO).
#
# 7.2.3. Kiến thức tốt nghiệp
# Sinh viên tích lũy tối thiểu 10 tín chỉ, chọn 01 trong 03 phương án sau đây:
# Sinh viên tích lũy tối thiểu 10 tín chỉ, chọn 01 trong 03 phương án sau đây:
# Phương án 1:
# - STT: 1
# - Tên học phần: Khóa luận tốt nghiệp
# - Mã học phần: CSC10251
# - Số tín chỉ: 10
# - Loại học phần: Tự chọn
#
# Phương án 2:
# - STT: 2
# - Tên học phần: Thực tập tốt nghiệp
# - Mã học phần: CSC10252
# - Số tín chỉ: 10
# - Loại học phần: Tự chọn
#
# Phương án 3:
# - STT: 3
# - Tên học phần: Thực tập dự án tốt nghiệp
# - Mã học phần: CSC10204
# - Số tín chỉ: 6
# - Loại học phần: Tự chọn
#
# Học phần tự chọn:
# STT: 1
# Tên học phần: Ứng dụng thị giác máy tính
# Mã học phần: CSC18105
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 2
# Tên học phần: Trí tuệ nhân tạo ứng dụng
# Mã học phần: CSC18105
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT: 3
# Tên học phần: Ứng dụng xử lý ngôn ngữ tự nhiên trong doanh nghiệp
# Mã học phần: CSC15012
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# 8. Dự kiến kế hoạch giảng dạy Ngành Trí tuệ nhân tạo
# 8.1. Các môn học Học kỳ 1 năm 1 Ngành Trí tuệ nhân tạo
# BAA00030 Giáo dục quốc phòng – An ninh
# BAA00021 Thể dục 1
# ADD00031 Anh văn 1
# MTH00003 Vi tích phân 1B
# MTH00081 Thực hành Vi tích phân 1B
# MTH00041 Toán rời rạc
# MTH00086 Thực hành Toán rời rạc
# CSC00009 Giới thiệu ngành Trí tuệ nhân tạo
# CSC10001 Nhập môn lập trình
#
# 8.2. Các môn học Học kỳ 2 năm 1 Ngành Trí tuệ nhân tạo
# BAA00022 Thể dục 2
# ADD00032 Anh văn 2
# BAA00004 Pháp luật đại cương
# CHE00001 Hóa đại cương 1
# CHE00081 Thực hành Hóa đại cương 1
# BIO00001 Sinh đại cương 1
# BIO00081 Thực tập Sinh đại cương 1
# PHY00001 Vật lý đại cương 1 (Cơ - Nhiệt)
# PHY00081 Thực hành Vật lý đại cương
# MTH00004 Vi tích phân 2B
# MTH00082 Thực hành Vi tích phân 2B
# MTH00030 Đại số tuyến tính
# MTH00083 Thực hành Đại số tuyến tính
# CSC100010 Lập trình cho trí tuệ nhân tạo
#
# 8.3. Các môn học Học kỳ 1 năm 2 Ngành Trí tuệ nhân tạo
# ADD00033 Anh văn 3
# CHE00002 Hóa đại cương 2
# CHE00082 Thực hành Hóa đại cương 2
# BIO00002 Sinh đại cương 2
# BIO00082 Thực tập Sinh đại cương 2
# PHY00002 Vật lý đại cương 2 (Điện từ – Quang)
# MTH00040 Xác suất thống kê
# MTH00085 Thực hành Xác suất thống kê
# MTH00050 Toán học tổ hợp
# CSC10004 Cấu trúc dữ liệu và giải thuật
# CSC10008 Mạng máy tính
#
# 8.4. Các môn học Học kỳ 2 năm 2 Ngành Trí tuệ nhân tạo
# ADD00034 Anh văn 4
# BAA00101 Triết học Mác – Lênin
# BAA00005 Kinh tế đại cương
# BAA00006 Tâm lý đại cương
# BAA00007 Phương pháp luận sáng tạo
# MTH00051 Toán ứng dụng và thống kê
# MTH00052 Phương pháp tính
# MTH00053 Lý thuyết số
# MTH00056 Phương pháp toán cho trí tuệ nhân tạo
# CSC10003 Phương pháp lập trình hướng đối tượng
# CSC10006 Cơ sở dữ liệu
# CSC10009 Hệ thống máy tính
# CSC10121 Kỹ năng mềm (Học kỳ hè năm 2)
#
# 8.5. Các môn học Học kỳ 1 năm 3 Ngành Trí tuệ nhân tạo
# BAA00102 Kinh tế chính trị Mác – Lênin
# GEO00002 Khoa học Trái đất
# ENV00001 Môi trường đại cương
# ENV00003 Con người và môi trường
# CSC10007 Hệ điều hành
# CSC14004 Khai thác dữ liệu và ứng dụng
# CSC15006 Nhập môn xử lý ngôn ngữ tự nhiên
# CSC11004 Mạng máy tính nâng cao
# CSC14003 Cơ sở trí tuệ nhân tạo
# CSC12002 Cơ sở dữ liệu nâng cao
# CSC12003 Hệ quản trị cơ sở dữ liệu
# CSC13009 Phát triển phần mềm cho thiết bị di động
#
# 8.6. Các môn học Học kỳ 2 năm 3 Ngành Trí tuệ nhân tạo
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10011 Công nghệ phần mềm cho hệ thống trí tuệ nhân tạo
# CSC10102 Kiến tập nghề nghiệp
# CSC10103 Khởi nghiệp (Học kỳ hè năm 3)
# CSC10104 Quy hoạch tuyến tính
# CSC14005 Nhập môn học máy
# CSC16004 Thị giác máy tính
# CSC16109 Ứng dụng xử lý ảnh số và video số
# CSC12004 Phân tích thiết kế hệ thống thông tin
# CSC15012 Ứng dụng xử lý ngôn ngữ tự nhiên trong doanh nghiệp
#
# 8.7. Các môn học Học kỳ 1 năm 4 Ngành Trí tuệ nhân tạo
# BAA00104 Lịch sử Đảng Cộng sản Việt Nam
# CSC15009 Xử lý tín hiệu số
# CSC18001 Nhập môn học sâu
# CSC18101 Trí tuệ nhân tạo cho an ninh thông tin
# CSC12106 Tương tác người - máy
# CSC14112 Sinh trắc học
# CSC14120 Lập trình song song
# CSC15010 Blockchain và ứng dụng
# CSC11003 Lập trình mạng
# CSC13112 Thiết kế giao diện
# CSC10251 Khóa luận tốt nghiệp
# CSC10252 Thực tập tốt nghiệp
# CSC10204 Thực tập dự án tốt nghiệp
# CSC16107 Ứng dụng thị giác máy tính
# CSC18105 Trí tuệ nhân tạo ứng dụng
#
# 8.8. Các môn học Học kỳ 2 năm 4 Ngành Trí tuệ nhân tạo
# BAA00003 Tư tưởng Hồ Chí Minh
# CSC17001 Phân tích dữ liệu thông minh
# CSC18102 Phương pháp toán cho tối ưu
# CSC18103 Trí tuệ bày đàn
# CSC18104 Nhập môn hệ thống đa tác nhân
# CSC10251 Khóa luận tốt nghiệp
# CSC10252 Thực tập tốt nghiệp
# CSC10204 Thực tập dự án tốt nghiệp
#
# 9. Khả năng liên thông với các chương trình đào tạo khác
# Sinh viên có thể liên thông với chương trình đào tạo trình độ đại học của các ngành sau đây:
# Ngành Công nghệ thông tin
# Ngành Kỹ thuật phần mềm
# Ngành Khoa học máy tính
# Ngành Trí tuệ nhân tạo
# Ngoài ra, sinh viên cũng có thể liên thông với chương trình đào tạo trình độ thạc sỹ của các ngành sau đây:
# Ngành Hệ thống thông tin
# Ngành Khoa học máy tính
# Ngành Trí tuệ nhân tạo
# Sinh viên khi tham gia vào chương trình liên thông môn học Đại học – Thạc sỹ nói trên sẽ được tùy ý lựa chọn học tối đa 04 học phần cùng với bậc đào tạo Thạc sỹ và được xét chuyển điểm tương đương cho bậc đại học.
#
#
#
# Metadata của tài liệu đầu tiên: {'source': '/content/Data/TTNT.txt'}
# Source trong metadata của tài liệu đầu tiên: /content/Data/TTNT.txt

# %% [markdown]
# #**Khai báo biến môi trường**
# - Lưu ý: Nếu API hết hạn truy cập chương trình sẽ không hoạt động và báo lỗi, cần thay API key mới

# %%
# Cài đặt thông tin truy cập vector database
QDRANT_API_KEY = userdata.get("QDRANT_API_KEY")
QDRANT_URL = userdata.get("QDRANT_URL")
EMBEDDINGS_MODEL_NAME="intfloat/multilingual-e5-base"
#  EMBEDDINGS_MODEL_NAME="sentence-transformers/LaBSE"
HUGGINGFACE_API_KEY= userdata.get("HUGGINGFACE_API_KEY")

# %% [markdown]
# #**Sử dụng RecursiveCharacterTextSplitter của LangChain**

# %%
COLLECTION_NAME = "ITUS_e5_R_600"

# %%
import os
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Giả sử documents là một danh sách các document, và mỗi document có tên file trong metadata.
# Cập nhật metadata để chứa chỉ tên file

text_splitter = RecursiveCharacterTextSplitter(chunk_size=600,
                                               chunk_overlap=200)

# Cắt các document thành các đoạn nhỏ và gán tên file vào metadata
chunked_documents = []
for doc in documents:
    # Tạo các đoạn nhỏ từ từng document
    chunks = text_splitter.split_documents([doc])
    # Thêm metadata cho mỗi chunk chỉ chứa tên file (không có đường dẫn)
    for chunk in chunks:
        file_name = os.path.basename(doc.metadata.get('source', 'unknown'))  # Lấy tên file từ đường dẫn
        chunk.metadata['source'] = file_name  # Gán tên file vào metadata
        chunked_documents.append(chunk)

# %%
len(chunked_documents)
# Out:
# 1602

# %%
# Kiểm tra nội dung của các đoạn văn bản
for i, doc in enumerate(chunked_documents):
    print(f"Document {i} content: {doc.page_content[:100]}")  # In 100 ký tự đầu tiên
    print(f"Document {i} metadata: {doc.metadata}")
    if not doc.page_content.strip():
        print(f"Document {i} is empty!")
# Out:
# Document 0 content: Ngành Trí tuệ nhân tạo
# Chương trình: Đại học Chính quy
# Khóa tuyển: 2023
# (Ban hành kèm theo Quyết địn
# Document 0 metadata: {'source': 'TTNT.txt'}
# Document 1 content: 1. Thông tin chung về chương trình đào tạo
# 1.1. Tên ngành:
# - Tiếng Việt: Trí tuệ nhân tạo
# - Tiếng A
# Document 1 metadata: {'source': 'TTNT.txt'}
# Document 2 content: - Tiếng Anh Bachelor of Science in Artificial Intelligence
# 1.8. Ngôn ngữ giảng dạy tiếng Việt
# 1.9.
# Document 2 metadata: {'source': 'TTNT.txt'}
# Document 3 content: 2. Mục tiêu đào tạo
# 2.1. Mục tiêu chung
# Mục tiêu của chương trình là nhằm đào tạo ra các sinh viên t
# Document 3 metadata: {'source': 'TTNT.txt'}
# Document 4 content: - Được trang bị những kỹ năng cá nhân, kỹ năng nhóm, kỹ năng giao tiếp và kỹ năng phân tích để nhận
# Document 4 metadata: {'source': 'TTNT.txt'}
# Document 5 content: 2.2. Mục tiêu cụ thể
# PO1: Nhận biết được trách nhiệm, đạo đức nghề nghiệp, và hiện trạng kinh tế, mô
# Document 5 metadata: {'source': 'TTNT.txt'}
# Document 6 content: PO5: Có khả năng hình thành ý tưởng, phân tích, thiết kế, giải quyết và vận hành các hệ thống CNTT.
# Document 6 metadata: {'source': 'TTNT.txt'}
# Document 7 content: 2.3. Chuẩn đầu ra (CĐR) của chương trình đào tạo
# ELO 1. Kiến thức
# ELO 1. 1. Kiến thức nền tảng về
# Document 7 metadata: {'source': 'TTNT.txt'}
# Document 8 content: ELO 1. 3. Kiến thức kỹ thuật nâng cao, các công cụ và phương pháp trong ngành CNTT
# ELO 1. 3. 1 Khối
# Document 8 metadata: {'source': 'TTNT.txt'}
# Document 9 content: ELO 1. 3. 7 Các công cụ, phương pháp và công nghệ hỗ trợ trong ngành CNTT
# ELO 1. 4. Các kiến thức n
# Document 9 metadata: {'source': 'TTNT.txt'}
# Document 10 content: ELO 2. Kỹ năng mềm
# ELO 2. 1. Kỹ năng và tính cách cá nhân
# ELO 2. 1. 1 Độc lập
# ELO 2. 1. 2 Tự tin
# Document 10 metadata: {'source': 'TTNT.txt'}
# Document 11 content: ELO 2. 1. 9 Quản trị dự án
# ELO 2. 2. Kỹ năng nhóm
# ELO 2. 2. 1 Thành lập nhóm
# ELO 2. 2. 2 Hoạt độn
# Document 11 metadata: {'source': 'TTNT.txt'}
# Document 12 content: ELO 2. 4. 1 Kỹ năng nói tiếng Anh
# ELO 2. 4. 2 Kỹ năng nghe tiếng Anh
# ELO 2. 4. 3 Kỹ năng đọc tiếng
# Document 12 metadata: {'source': 'TTNT.txt'}
# Document 13 content: ELO 2. 5. 4 Xây dựng và dẫn dắt một tổ chức
# ELO 2. 5. 5 Lên kế hoạch và dẫn dắt dự án đến thành côn
# Document 13 metadata: {'source': 'TTNT.txt'}
# Document 14 content: ELO 3. Ngữ cảnh, trách nhiệm và đạo đức
# ELO 3. 1. Ngữ cảnh bên ngoài, xã hội, kinh tế và môi trường
# Document 14 metadata: {'source': 'TTNT.txt'}
# Document 15 content: ELO 3. 2. 1 Ngữ cảnh và văn hóa của công ty, tổ chức
# ELO 3. 2. 2 Các bên liên quan, mục tiêu và chi
# Document 15 metadata: {'source': 'TTNT.txt'}
# Document 16 content: ELO 4. Phương pháp khoa học và nghiên cứu
# ELO 4. 1. Suy luận có phân tích và giải quyết vấn đề
# ELO
# Document 16 metadata: {'source': 'TTNT.txt'}
# Document 17 content: ELO 4. 2. 4 Kiểm chứng và bảo vệ giả thuyết
# ELO 4. 3. Suy nghĩ tầm mức hệ thống
# ELO 4. 3. 1 Suy ng
# Document 17 metadata: {'source': 'TTNT.txt'}
# Document 18 content: ELO 5. Hình thành ý tưởng, thiết kế và hiện thực hóa hệ thống CNTT
# ELO 5. 1. Hình thành ý tưởng/ bà
# Document 18 metadata: {'source': 'TTNT.txt'}
# Document 19 content: ELO 5. 2. 1 Tiến trình và phương pháp thiết kế
# ELO 5. 2. 2 Thiết kế kiến trúc và các thành phần của
# Document 19 metadata: {'source': 'TTNT.txt'}
# Document 20 content: ELO 6. Kiểm chứng, vận hành, bảo trì và phát triển hệ thống CNTT
# ELO 6. 1. Kiểm chứng
# ELO 6. 1. 1
# Document 20 metadata: {'source': 'TTNT.txt'}
# Document 21 content: 2.4. Cơ hội nghề nghiệp/ công việc người học có thể đảm nhận
# Sinh viên sau khi tốt nghiệp có thể có
# Document 21 metadata: {'source': 'TTNT.txt'}
# Document 22 content: - Các vị trí thuộc nhóm Hệ thống thông tin: Thiết kế và Quản trị cơ sở dữ liệu, Quản trị hệ thống CN
# Document 22 metadata: {'source': 'TTNT.txt'}
# Document 23 content: - Các vị trí thuộc nhóm Nghiên cứu và triển khai giải pháp tại các viện, trường đại học, phòng thí n
# Document 23 metadata: {'source': 'TTNT.txt'}
# Document 24 content: - Các vị trí thuộc nhóm Giảng dạy: Trợ giảng, Giáo viên, Giảng viên các cấp phổ thông, trung tâm đào
# Document 24 metadata: {'source': 'TTNT.txt'}
# Document 25 content: 3. Khối lượng kiến thức toàn khóa: 138 tín chỉ (Không kể môn Giáo dục Quốc phòng - An ninh, Giáo dục
# Document 25 metadata: {'source': 'TTNT.txt'}
# Document 26 content: 5. Quy trình đào tạo và điều kiện tốt nghiệp
# 5.1. Quy trình đào tạo
# Căn cứ Quy chế đào tạo trình độ
# Document 26 metadata: {'source': 'TTNT.txt'}
# Document 27 content: - Thỏa các điều kiện tại Điều 17 của Quy chế đào tạo trình độ đại học ban hành kèm theo Quyết định s
# Document 27 metadata: {'source': 'TTNT.txt'}
# Document 28 content: 6. Cấu trúc chương trình đào tạo
# Tổng số tín chỉ tích lũy: 138 tín chỉ
# 6.1. Giáo dục đại cương (Khô
# Document 28 metadata: {'source': 'TTNT.txt'}
# Document 29 content: 6.2.2. Ngành/Chuyên ngành
# Tổng cộng 34 tín chỉ bao gồm:
# - Bắt buộc: 16
# - Tự chọn: 8
# - Tự chọn tự do:
# Document 29 metadata: {'source': 'TTNT.txt'}
# Document 30 content: - STT: 2
# - Tên học phần: Kinh tế chính trị Mác – Lênin
# - Mã học phần: BAA00102
# - Số tín chỉ: 2
# Document 30 metadata: {'source': 'TTNT.txt'}
# Document 31 content: - STT: 5
# - Tên học phần: Tư tưởng Hồ Chí Minh
# - Mã học phần: BAA00103
# - Số tín chỉ: 2
# - Loại h
# Document 31 metadata: {'source': 'TTNT.txt'}
# Document 32 content: - STT: 2
# - Tên học phần: Tâm lý đại cương
# - Mã học phần: BAA00006
# - Số tín chỉ: 2
# - Loại học
# Document 32 metadata: {'source': 'TTNT.txt'}
# Document 33 content: - STT: 2
# - Tên học phần: Thực hành Vi tích phân 1B
# - Mã học phần: MTH00081
# - Số tín chỉ: 1
# - Loại họ
# Document 33 metadata: {'source': 'TTNT.txt'}
# Document 34 content: - STT: 6
# - Tên học phần: Thực hành Đại số tuyến tính
# - Mã học phần: MTH00083
# - Số tín chỉ: 1
# - Loại
# Document 34 metadata: {'source': 'TTNT.txt'}
# Document 35 content: - STT: 10
# - Tên học phần: Thực hành Toán rời rạc
# - Mã học phần: MTH00086
# - Số tín chỉ: 1
# - Loại học
# Document 35 metadata: {'source': 'TTNT.txt'}
# Document 36 content: - STT: 14
# - Tên học phần: Lý thuyết số
# - Mã học phần: MTH00053
# - Số tín chỉ: 4
# - Loại học phần: Tự c
# Document 36 metadata: {'source': 'TTNT.txt'}
# Document 37 content: - STT: 18
# - Tên học phần: Sinh đại cương 2
# - Mã học phần: BIO00002
# - Số tín chỉ: 3
# - Loại học phần:
# Document 37 metadata: {'source': 'TTNT.txt'}
# Document 38 content: Tổng cộng số tín chỉ: 36
#
# 7.1.4 Tin học
# - STT: 1
# - Tên học phần: Nhập môn công nghệ thông tin
# - Mã h
# Document 38 metadata: {'source': 'TTNT.txt'}
# Document 39 content: - STT: 2
# - Tên học phần: Anh văn 2
# - Mã học phần: ADD00032
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
# Document 39 metadata: {'source': 'TTNT.txt'}
# Document 40 content: - STT: 2
# - Tên học phần: Thể dục 2
# - Mã học phần: BAA00022
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
# Document 40 metadata: {'source': 'TTNT.txt'}
# Document 41 content: - STT: 2
# - Tên học phần: Kỹ thuật lập trình
# - Mã học phần: CSC10002
# - Số tín chỉ: 4
# - Loại học phần:
# Document 41 metadata: {'source': 'TTNT.txt'}
# Document 42 content: - STT: 6
# - Tên học phần: Hệ điều hành
# - Mã học phần: CSC10007
# - Số tín chỉ: 4
# - Loại học phần: Bắt b
# Document 42 metadata: {'source': 'TTNT.txt'}
# Document 43 content: - STT: 10
# - Tên học phần: Cơ sở trí tuệ nhân tạo
# - Mã học phần: CSC14003
# - Số tín chỉ: 4
# - Loại học
# Document 43 metadata: {'source': 'TTNT.txt'}
# Document 44 content: STT: 2
# Tên học phần: Nhập môn học máy
# Mã học phần: CSC14005
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# ST
# Document 44 metadata: {'source': 'TTNT.txt'}
# Document 45 content: STT: 5
# Tên học phần: Thị giác máy tính
# Mã học phần: CSC16004
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# S
# Document 45 metadata: {'source': 'TTNT.txt'}
# Document 46 content: STT: 2
# Tên học phần: Khởi nghiệp
# Mã học phần: CSC10103
# Số tín chỉ: 3
# Loại học phần: Tự chọn
#
# STT: 3
#
# Document 46 metadata: {'source': 'TTNT.txt'}
# Document 47 content: STT: 7
# Tên học phần: Blockchain và ứng dụng
# Mã học phần: CSC15010
# Số tín chỉ: 4
# Loại học phần: Tự ch
# Document 47 metadata: {'source': 'TTNT.txt'}
# Document 48 content: STT: 11
# Tên học phần: Phương pháp toán cho tối ưu
# Mã học phần: CSC18102
# Số tín chỉ: 4
# Loại học phần:
# Document 48 metadata: {'source': 'TTNT.txt'}
# Document 49 content: STT: 13
# Tên học phần: Nhập môn hệ thống đa tác nhân
# Mã học phần: CSC18104
# Số tín chỉ: 4
# Loại học phầ
# Document 49 metadata: {'source': 'TTNT.txt'}
# Document 50 content: STT: 2
# Tên học phần: Lập trình mạng
# Mã học phần: CSC11003
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# STT:
# Document 50 metadata: {'source': 'TTNT.txt'}
# Document 51 content: STT: 6
# Tên học phần: Phân tích thiết kế hệ thống thông tin
# Mã học phần: CSC12004
# Số tín chỉ: 4
# Loại
# Document 51 metadata: {'source': 'TTNT.txt'}
# Document 52 content: Hoặc các học phần thuộc các mục sau đây:
# mục 7.2.2.1. và mục 7.2.2.2. (bên trên);
# mục 7.2.3. (bên d
# Document 52 metadata: {'source': 'TTNT.txt'}
# Document 53 content: mục 7.2.2.1.1. và mục 7.2.2.1.2. của chương trình đào tạo đại học chính quy ngành Công nghệ thông ti
# Document 53 metadata: {'source': 'TTNT.txt'}
# Document 54 content: 7.2.3. Kiến thức tốt nghiệp
# Sinh viên tích lũy tối thiểu 10 tín chỉ, chọn 01 trong 03 phương án sau
# Document 54 metadata: {'source': 'TTNT.txt'}
# Document 55 content: Phương án 3:
# - STT: 3
# - Tên học phần: Thực tập dự án tốt nghiệp
# - Mã học phần: CSC10204
# - Số tín chỉ
# Document 55 metadata: {'source': 'TTNT.txt'}
# Document 56 content: STT: 3
# Tên học phần: Ứng dụng xử lý ngôn ngữ tự nhiên trong doanh nghiệp
# Mã học phần: CSC15012
# Số tí
# Document 56 metadata: {'source': 'TTNT.txt'}
# Document 57 content: 8.2. Các môn học Học kỳ 2 năm 1 Ngành Trí tuệ nhân tạo
# BAA00022 Thể dục 2
# ADD00032 Anh văn 2
# BAA00
# Document 57 metadata: {'source': 'TTNT.txt'}
# Document 58 content: 8.3. Các môn học Học kỳ 1 năm 2 Ngành Trí tuệ nhân tạo
# ADD00033 Anh văn 3
# CHE00002 Hóa đại cương 2
# Document 58 metadata: {'source': 'TTNT.txt'}
# Document 59 content: 8.4. Các môn học Học kỳ 2 năm 2 Ngành Trí tuệ nhân tạo
# ADD00034 Anh văn 4
# BAA00101 Triết học Mác –
# Document 59 metadata: {'source': 'TTNT.txt'}
# Document 60 content: 8.5. Các môn học Học kỳ 1 năm 3 Ngành Trí tuệ nhân tạo
# BAA00102 Kinh tế chính trị Mác – Lênin
# GEO00
# Document 60 metadata: {'source': 'TTNT.txt'}
# Document 61 content: 8.6. Các môn học Học kỳ 2 năm 3 Ngành Trí tuệ nhân tạo
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10011 C
# Document 61 metadata: {'source': 'TTNT.txt'}
# Document 62 content: 8.7. Các môn học Học kỳ 1 năm 4 Ngành Trí tuệ nhân tạo
# BAA00104 Lịch sử Đảng Cộng sản Việt Nam
# CSC15
# Document 62 metadata: {'source': 'TTNT.txt'}
# Document 63 content: 8.8. Các môn học Học kỳ 2 năm 4 Ngành Trí tuệ nhân tạo
# BAA00003 Tư tưởng Hồ Chí Minh
# CSC17001 Phân
# Document 63 metadata: {'source': 'TTNT.txt'}
# Document 64 content: 9. Khả năng liên thông với các chương trình đào tạo khác
# Sinh viên có thể liên thông với chương trìn
# Document 64 metadata: {'source': 'TTNT.txt'}
# Document 65 content: Ngoài ra, sinh viên cũng có thể liên thông với chương trình đào tạo trình độ thạc sỹ của các ngành s
# Document 65 metadata: {'source': 'TTNT.txt'}
# Document 66 content: Chương trình: Liên thông môn học Đại học - Thạc sỹ
#
# 1. Danh sách học phần Chương trình liên thông mô
# Document 66 metadata: {'source': 'BSMS.txt'}
# Document 67 content: STT 2
# Tên học phần (ĐH): Cơ sở trí tuệ nhân tạo
# Mã học phần (ĐH): CSC14003
# Số tín chỉ (ĐH): 4
# Tên họ
# Document 67 metadata: {'source': 'BSMS.txt'}
# Document 68 content: STT 5
# Tên học phần (ĐH): Hệ thống thông tin phục vụ trí tuệ kinh doanh
# Mã học phần (ĐH): CSC12107
# Số
# Document 68 metadata: {'source': 'BSMS.txt'}
# Document 69 content: STT 7
# Tên học phần (ĐH): Phân tích dữ liệu ứng dụng
# Mã học phần (ĐH): CSC12110
# Số tín chỉ (ĐH): 4
# Tê
# Document 69 metadata: {'source': 'BSMS.txt'}
# Document 70 content: STT 9
# Tên học phần (ĐH): Phương pháp nghiên cứu khoa học
# Mã học phần (ĐH): CSC14008
# Số tín chỉ (ĐH):
# Document 70 metadata: {'source': 'BSMS.txt'}
# Document 71 content: STT 13
# Tên học phần (ĐH): Blockchain và ứng dụng
# Mã học phần (ĐH): CSC15010
# Số tín chỉ (ĐH): 4
# Tên h
# Document 71 metadata: {'source': 'BSMS.txt'}
# Document 72 content: STT 14
# Tên học phần (ĐH): Phân tích mạng xã hội
# Mã học phần (ĐH): CSC15102
# Số tín chỉ (ĐH): 4
# Tên họ
# Document 72 metadata: {'source': 'BSMS.txt'}
# Document 73 content: STT 16
# Tên học phần (ĐH): Phân tích dữ liệu bảo toàn tính riêng tư
# Mã học phần (ĐH): CSC15107
# Số tín
# Document 73 metadata: {'source': 'BSMS.txt'}
# Document 74 content: STT 18
# Tên học phần (ĐH): Thị giác máy tính
# Mã học phần (ĐH): CSC16004
# Số tín chỉ (ĐH): 4
# Tên học ph
# Document 74 metadata: {'source': 'BSMS.txt'}
# Document 75 content: 1. QUY CHẾ ĐÀO TẠO TRÌNH ĐỘ ĐẠI HỌC
# (Ban hành kèm theo Quyết định số 1175/QĐ-KHTN ngày 24 tháng 9 n
# Document 75 metadata: {'source': 'QuyChe.txt'}
# Document 76 content: 1.1. Chương I
# NHỮNG QUY ĐỊNH CHUNG
# 1.1.1. Điều 1. Phạm vi điều chỉnh và đối tượng áp dụng
# 1.1.1.1
# Document 76 metadata: {'source': 'QuyChe.txt'}
# Document 77 content: 1.1.1.2. Quy chế này áp dụng đối với sinh viên đại học hệ chính quy các khoá đào
# tạo, các đơn vị, c
# Document 77 metadata: {'source': 'QuyChe.txt'}
# Document 78 content: 1.1.2. Điều 2. Chương trình đào tạo và thời gian học tập
# 1.1.2.1. Chương trình đào tạo được xây dựn
# Document 78 metadata: {'source': 'QuyChe.txt'}
# Document 79 content: 1.1.2.2. Chương trình đào tạo là những thông tin cơ bản mà sinh viên cần nắm vững
# trong quá trình h
# Document 79 metadata: {'source': 'QuyChe.txt'}
# Document 80 content: gian thiết kế; phương pháp và hình thức đánh giá đối với học phần; điều kiện tốt
# nghiệp; các điều k
# Document 80 metadata: {'source': 'QuyChe.txt'}
# Document 81 content: về tự nhiên, xã hội và con người; nắm vững phương pháp tư duy khoa học; có đạo
# đức, nhận thức trách
# Document 81 metadata: {'source': 'QuyChe.txt'}
# Document 82 content: 1.1.2.4. Nội dung, chuẩn đầu ra của chương trình đào tạo áp dụng chung đối với các
# hình thức, phươn
# Document 82 metadata: {'source': 'QuyChe.txt'}
# Document 83 content: 1.1.2.5. Chương trình đào tạo phải được công khai đối với người học trước khi tuyển
# sinh và khi bắt
# Document 83 metadata: {'source': 'QuyChe.txt'}
# Document 84 content: 1.1.2.6. Đối với mỗi hình thức đào tạo, chương trình đào tạo được cung cấp kế hoạch
# học tập chuẩn t
# Document 84 metadata: {'source': 'QuyChe.txt'}
# Document 85 content: 1.1.2.7. Thời gian tối đa để sinh viên hoàn thành khoá học
# Tuỳ theo khả năng học tập, sinh viên đượ
# Document 85 metadata: {'source': 'QuyChe.txt'}
# Document 86 content: hoạch học tập.
# b) Quá thời hạn tối đa của khóa học, sinh viên sẽ bị xóa tên khỏi danh sách sinh
# vi
# Document 86 metadata: {'source': 'QuyChe.txt'}
# Document 87 content: 1.1.3. Điều 3. Học phần, đề cương chi tiết học phần và tín chỉ
# 1.1.3.1. Học phần
# a) Học phần là mộ
# Document 87 metadata: {'source': 'QuyChe.txt'}
# Document 88 content: b) Có hai loại học phần: học phần bắt buộc và học phần tự chọn. - Học phần bắt buộc là học phần chứa
# Document 88 metadata: {'source': 'QuyChe.txt'}
# Document 89 content: c) Ngoài việc được phân loại là bắt buộc hoặc tự chọn, các học phần có các
# khái niệm khác như sau:
# Document 89 metadata: {'source': 'QuyChe.txt'}
# Document 90 content: theo quy định (Giáo dục Quốc phòng - An ninh, Giáo dục Thể chất, các học phần lý
# luận chính trị, ph
# Document 90 metadata: {'source': 'QuyChe.txt'}
# Document 91 content: ký học phần này thì bắt buộc phải đăng ký học phần kia. - Học phần thay thế: là học phần được sử dụn
# Document 91 metadata: {'source': 'QuyChe.txt'}
# Document 92 content: 1.1.3.2. Mỗi học phần đều phải có đề cương chi tiết học phần, trong đó phải thể hiện
# rõ: mục tiêu;
# Document 92 metadata: {'source': 'QuyChe.txt'}
# Document 93 content: 1.1.3.3. Tín chỉ được sử dụng để tính khối lượng học tập của sinh viên. Một tín chỉ
# được quy định b
# Document 93 metadata: {'source': 'QuyChe.txt'}
# Document 94 content: 1.1.4.2. Đào tạo theo tín chỉ:
# a) Là phương thức tổ chức đào tạo theo từng lớp học phần, cho phép s
# Document 94 metadata: {'source': 'QuyChe.txt'}
# Document 95 content: một học phần thay thế nếu học phần đó không còn được giảng dạy;
# c) Sinh viên không đạt một học phần
# Document 95 metadata: {'source': 'QuyChe.txt'}
# Document 96 content: 1.1.5. Điều 5. Hình thức đào tạo
# 1.1.5.1. Đào tạo chính quy
# a) Các hoạt động giảng dạy được thực h
# Document 96 metadata: {'source': 'QuyChe.txt'}
# Document 97 content: 1.1.5.2. Đối với các ngành đào tạo ưu tiên phục vụ nguồn nhân lực phát triển kinh tế - xã hội trong
# Document 97 metadata: {'source': 'QuyChe.txt'}
# Document 98 content: 1.2.1.2. Khoá học là thời gian thiết kế để sinh viên hoàn thành một chương trình cụ
# thể. Tuỳ thuộc
# Document 98 metadata: {'source': 'QuyChe.txt'}
# Document 99 content: 1.2.1.3. Tổng số tín chỉ trong một khoá học được ghi rõ trong chương trình đào tạo.
# Khối lượng và n
# Document 99 metadata: {'source': 'QuyChe.txt'}
# Document 100 content: 1.2.1.4. Một năm học của Trường được tổ chức như sau:
# a)  Đối với chương trình đại trà: một năm học
# Document 100 metadata: {'source': 'QuyChe.txt'}
# Document 101 content: 03 học kỳ chính với tổng số tối thiểu 30 tuần lên lớp.
# c) Kế hoạch năm học thể hiện những mốc thời
# Document 101 metadata: {'source': 'QuyChe.txt'}
# Document 102 content: hoặc trực tuyến), lịch học, lịch thi/kiểm tra của các học phần được tổ chức trong học
# kỳ cho các kh
# Document 102 metadata: {'source': 'QuyChe.txt'}
# Document 103 content: 1.2.1.6. Thời khoá biểu thể hiện thời gian, địa điểm, hoạt động dạy và học của từng
# lớp thuộc các k
# Document 103 metadata: {'source': 'QuyChe.txt'}
# Document 104 content: Buổi chiều
# Tiết 7 : 12g30-13g20
# Tiết 8 : 13g20-14g10
# Tiết 9 : 14g20-15g10
# Tiết 10: 15g10-16g00
#
# Document 104 metadata: {'source': 'QuyChe.txt'}
# Document 105 content: Buổi chiều
# Tiết 6 : 12g30-13g20
# Tiết 7 : 13g20-14g10
# Tiết 8 : 14g20-15g10
# Tiết 9: 15g10-16g00
# T
# Document 105 metadata: {'source': 'QuyChe.txt'}
# Document 106 content: b) Tổng số tín chỉ của các học phần trong một học kỳ được tính bao gồm: số tín
# chỉ của học phần đăn
# Document 106 metadata: {'source': 'QuyChe.txt'}
# Document 107 content: 1.2.2.2. Số tín chỉ tối thiểu, tối đa trong học kỳ
# a) Số tín chỉ đăng ký học tối thiểu trong học kỳ
# Document 107 metadata: {'source': 'QuyChe.txt'}
# Document 108 content: b) Số tín chỉ đăng ký học tối đa trong học kỳ chính: - Đối với chương trình Tiên tiến, Liên kết, Chấ
# Document 108 metadata: {'source': 'QuyChe.txt'}
# Document 109 content: đồng ý và Hiệu trưởng chấp thuận.
#
# c) Đối với sinh viên học cùng lúc hai chương trình, tổng số tín
# Document 109 metadata: {'source': 'QuyChe.txt'}
# Document 110 content: 1.2.2.4. Trách nhiệm của sinh viên:
# a) Chủ động theo dõi kết quả đăng ký học phần để xác nhận hoặc
# Document 110 metadata: {'source': 'QuyChe.txt'}
# Document 111 content: viên, phù hợp với quy định về chế độ làm việc của giảng viên;
#
# b) Phát huy vai trò chủ động đồng th
# Document 111 metadata: {'source': 'QuyChe.txt'}
# Document 112 content: c) Có cơ chế thanh tra, giám sát nội bộ và có hệ thống cải tiến chất lượng dựa
# trên thu thập, đánh
# Document 112 metadata: {'source': 'QuyChe.txt'}
# Document 113 content: 1.2.3.2. Dạy và học trực tuyến:
# a) Hiệu trưởng quyết định tổ chức các lớp học theo phương thức trực
# Document 113 metadata: {'source': 'QuyChe.txt'}
# Document 114 content: 1.2.3.3. Tổ chức lớp học
# a) Lớp học phần: là lớp học bao gồm những sinh viên theo học cùng một học
# Document 114 metadata: {'source': 'QuyChe.txt'}
# Document 115 content: b) Lớp sinh hoạt: bao gồm những sinh viên cùng khoá tuyển, cùng ngành và
# cùng chương trình đào tạo
# Document 115 metadata: {'source': 'QuyChe.txt'}
# Document 116 content: 1.2.3.4. Các quy định về tổ chức đào tạo
# a) Hiệu trưởng ban hành quy định về triển khai công tác đà
# Document 116 metadata: {'source': 'QuyChe.txt'}
# Document 117 content: 1.3. Chương III
# ĐÁNH GIÁ KẾT QUẢ HỌC TẬP VÀ CẤP BẰNG TỐT NGHIỆP
# 1.3.1. Điều 9. Đánh giá học phần
#
# Document 117 metadata: {'source': 'QuyChe.txt'}
# Document 118 content: đánh giá, hình thức đánh giá và trọng số của mỗi điểm thành phần được quy định
# trong đề cương chi t
# Document 118 metadata: {'source': 'QuyChe.txt'}
# Document 119 content: a) Điểm quá trình chiếm tỉ trọng từ 50% đến 60% bao gồm tối thiểu ba trong
# số các hình thức sau đây
# Document 119 metadata: {'source': 'QuyChe.txt'}
# Document 120 content: (không dưới 40%). Hình thức thi kết thúc học phần có thể là: thi viết (trắc nghiệm
# hoặc tự luận); t
# Document 120 metadata: {'source': 'QuyChe.txt'}
# Document 121 content: 1.3.1.2. Đối với loại học phần thực hành: sinh viên phải tham dự đầy đủ các bài thực
# hành. Điểm tổn
# Document 121 metadata: {'source': 'QuyChe.txt'}
# Document 122 content: 1.3.2. Điều 10. Đánh giá đồ án tốt nghiệp, khóa luận tốt nghiệp/thực tập tốt
# nghiệp/dự án tốt nghiệ
# Document 122 metadata: {'source': 'QuyChe.txt'}
# Document 123 content: a) Làm khoá luận tốt nghiệp có khối lượng 10 tín chỉ.
# b) Làm đồ án tốt nghiệp và học một số học phầ
# Document 123 metadata: {'source': 'QuyChe.txt'}
# Document 124 content: 1.3.2.2. Sinh viên thực hiện khoá luận tốt nghiệp và đồ án tốt nghiệp trong thời gian
# là một học kỳ
# Document 124 metadata: {'source': 'QuyChe.txt'}
# Document 125 content: b) Hội đồng đánh giá do Hiệu trưởng ký quyết định thành lập trên cơ sở đề nghị
# của Khoa phụ trách đ
# Document 125 metadata: {'source': 'QuyChe.txt'}
# Document 126 content: c) Điểm đánh giá khóa luận tốt nghiệp, đồ án tốt nghiệp được đánh giá theo
# thang điểm 10. Điểm tổng
# Document 126 metadata: {'source': 'QuyChe.txt'}
# Document 127 content: án tốt nghiệp so với cách tính này thì quy định về cách tính điểm này của Khoa phải
# được đề xuất bằ
# Document 127 metadata: {'source': 'QuyChe.txt'}
# Document 128 content: a) Tổ chức bảo vệ và đánh giá khoá luận tốt nghiệp, đồ án tốt nghiệp được thực
# hiện trực tuyến tron
# Document 128 metadata: {'source': 'QuyChe.txt'}
# Document 129 content: 1.3.3. Điều 11. Tính điểm học phần
# 1.3.3.1. Điểm học phần theo thang điểm 10, là điểm cuối cùng để
# Document 129 metadata: {'source': 'QuyChe.txt'}
# Document 130 content: Thang điểm 10: 7,0 đến cận 8,0
# Điểm 4: 3,0
# Điểm chữ: B_
#
# Thang điểm 10: 6,0 đến cận 7,0
# Điểm 4: 2
# Document 130 metadata: {'source': 'QuyChe.txt'}
# Document 131 content: Thang điểm 10: <3,0
# Điểm 4: 0,0
# Điểm chữ: F
#
# 1.3.3.2. Thang điểm 4 và thang điểm chữ chỉ mang tính
# Document 131 metadata: {'source': 'QuyChe.txt'}
# Document 132 content: 1.3.3.4. Học phần có điểm từ 5,0 (năm) trở lên được xem là học phần đạt, số tín chỉ
# của học phần nà
# Document 132 metadata: {'source': 'QuyChe.txt'}
# Document 133 content: 1.3.4. Điều 12. Hoãn thi
# 1.3.4.1. Những trường hợp đột xuất và có lý do chính đáng (ví dụ như: ốm
# Document 133 metadata: {'source': 'QuyChe.txt'}
# Document 134 content: 1.3.4.3. Sinh viên sẽ không bị điểm không (0) đối với học phần được xét nhận điểm
# I ở học kỳ đó. Si
# Document 134 metadata: {'source': 'QuyChe.txt'}
# Document 135 content: 1.3.4.4. Đối với kiểm tra lấy điểm quá trình, trong trường hợp sinh viên vắng kiểm
# tra có lý do chí
# Document 135 metadata: {'source': 'QuyChe.txt'}
# Document 136 content: 1.3.5. Điều 13. Công nhận kết quả học tập và chuyển đổi tín chỉ (miễn học)
# 1.3.5.1. Sinh viên đã đạ
# Document 136 metadata: {'source': 'QuyChe.txt'}
# Document 137 content: 1.3.5.2. Trường sẽ xem xét công nhận, chuyển đổi tín chỉ trên cơ sở đối sánh chuẩn
# đầu ra, nội dung
# Document 137 metadata: {'source': 'QuyChe.txt'}
# Document 138 content: 1.3.5.3. Điểm bảo lưu (BL) và điểm miễn (M) không tính vào điểm trung bình học
# kỳ và điểm trung bìn
# Document 138 metadata: {'source': 'QuyChe.txt'}
# Document 139 content: b) Đối với các học phần bắt buộc có điểm học phần dưới năm (5,0) sinh viên
# phải đăng ký học lại.
#
# Document 139 metadata: {'source': 'QuyChe.txt'}
# Document 140 content: b) Tùy vào điều kiện giảng dạy thực tế đối các các học phần, Trường sẽ quy
# định cụ thể các học phần
# Document 140 metadata: {'source': 'QuyChe.txt'}
# Document 141 content: c) Điểm cải thiện không được sử dụng vào việc tính điểm trung bình học kỳ để
# xét học bổng khuyến kh
# Document 141 metadata: {'source': 'QuyChe.txt'}
# Document 142 content: a) Điểm trung bình: là điểm trung bình của những học phần mà sinh viên đã
# học trong một học kỳ, tro
# Document 142 metadata: {'source': 'QuyChe.txt'}
# Document 143 content: b) Điểm trung bình tích lũy: là điểm trung bình của những học phần mà sinh
# viên đã đạt trong một họ
# Document 143 metadata: {'source': 'QuyChe.txt'}
# Document 144 content: d)  Việc đánh giá kết quả hoặc điều kiện cấp chứng chỉ đối với học phần Giáo
# dục quốc phòng - An ni
# Document 144 metadata: {'source': 'QuyChe.txt'}
# Document 145 content: 1.3.7.2. Cách tính điểm trung bình và xếp loại
# a) Điểm trung bình hoặc điểm trung bình tích lũy củ
# Document 145 metadata: {'source': 'QuyChe.txt'}
# Document 146 content: b. Loại không đạt
# Từ 4 đến cận 5: Yếu
# Dưới 4: Kém
#
# 1.3.7.3. Sinh viên được xếp trình độ năm học că
# Document 146 metadata: {'source': 'QuyChe.txt'}
# Document 147 content: 1.3.8. Điều 16. Xử lý kết quả học tập theo tín chỉ
# 1.3.8.1. Cuối mỗi học kỳ chính, sinh viên được c
# Document 147 metadata: {'source': 'QuyChe.txt'}
# Document 148 content: b) Điểm trung bình chung học tập học kỳ liền kề trước đó dưới 3,0 hoặc điểm
# trung bình chung học tậ
# Document 148 metadata: {'source': 'QuyChe.txt'}
# Document 149 content: 1.3.8.3. Sinh viên thuộc diện bị buộc thôi học sẽ bị xóa tên khỏi danh sách sinh viên.
# Trường sẽ th
# Document 149 metadata: {'source': 'QuyChe.txt'}
# Document 150 content: 1.3.9.3. Sinh viên được xét và công nhận tốt nghiệp khi có đủ các điều kiện sau:
# a) Cho đến thời đi
# Document 150 metadata: {'source': 'QuyChe.txt'}
# Document 151 content: d) Đạt chuẩn trình độ ngoại ngữ theo quy định của Trường;
#
# e) Đạt chuẩn trình độ tin học theo quy đ
# Document 151 metadata: {'source': 'QuyChe.txt'}
# Document 152 content: 1.3.9.4. Hiệu trưởng ban hành quyết định thành lập Hội đồng xét tốt nghiệp để điều
# hành công tác xé
# Document 152 metadata: {'source': 'QuyChe.txt'}
# Document 153 content: 1.3.9.5. Hiệu trưởng ban hành quyết định thành lập Ban thư ký Hội đồng xét tốt
# nghiệp để thực hiện
# Document 153 metadata: {'source': 'QuyChe.txt'}
# Document 154 content: 1.3.9.6. Căn cứ kết quả xét tốt nghiệp và đề nghị của Hội đồng xét tốt nghiệp, Hiệu
# trưởng ban hành
# Document 154 metadata: {'source': 'QuyChe.txt'}
# Document 155 content: 1.3.10.2. Bằng tốt nghiệp đại học được cấp theo ngành đào tạo. Việc cấp bằng được
# thực hiện theo qu
# Document 155 metadata: {'source': 'QuyChe.txt'}
# Document 156 content: 1.3.10.4. Kết quả học tập của sinh viên được ghi vào bảng điểm theo từng học phần
# và phát kèm theo
# Document 156 metadata: {'source': 'QuyChe.txt'}
# Document 157 content: 1.3.10.6. Sinh viên không tốt nghiệp được cấp chứng nhận về các học phần đã tích luỹ
# trong chương t
# Document 157 metadata: {'source': 'QuyChe.txt'}
# Document 158 content: 1.4. Chương IV
# NHỮNG QUY ĐỊNH KHÁC ĐỐI VỚI SINH VIÊN
# 1.4.1. Điều 19. Nghỉ học tạm thời, thôi học
#
# Document 158 metadata: {'source': 'QuyChe.txt'}
# Document 159 content: thi, giải đấu quốc tế;
# c) Bị ốm, thai sản hoặc tai nạn phải điều trị thời gian dài có chứng nhận củ
# Document 159 metadata: {'source': 'QuyChe.txt'}
# Document 160 content: 1.4.1.2. Thời gian nghỉ học tạm thời vì lý do cá nhân tại điểm c và d khoản 1 Điều
# này phải được tí
# Document 160 metadata: {'source': 'QuyChe.txt'}
# Document 161 content: 1.4.1.4. Sinh viên xin thôi học vì lý do cá nhân, trừ trường hợp bị xem xét buộc thôi
# học hoặc xem
# Document 161 metadata: {'source': 'QuyChe.txt'}
# Document 162 content: 1.4.2. Điều 20. Chuyển chương trình, chuyển trường
# 1.4.2.1. Sinh viên được xem xét chuyển sang học
# Document 162 metadata: {'source': 'QuyChe.txt'}
# Document 163 content: b) Sinh viên đạt điều kiện trúng tuyển của chương trình, ngành/nhóm ngành
# đào tạo trong cùng khóa t
# Document 163 metadata: {'source': 'QuyChe.txt'}
# Document 164 content: d) Được sự đồng ý của Trưởng khoa chuyên môn phụ trách chương trình, ngành
# đào tạo và của Hiệu trưở
# Document 164 metadata: {'source': 'QuyChe.txt'}
# Document 165 content: c) Nơi chuyển đến có đủ các điều kiện bảo đảm chất lượng, chưa vượt quá năng
# lực đào tạo đối với ch
# Document 165 metadata: {'source': 'QuyChe.txt'}
# Document 166 content: d) Được sự đồng ý của Hiệu trưởng cơ sở đào tạo xin chuyển đi và cơ sở đào
# tạo xin chuyển đến.
#
# 1.
# Document 166 metadata: {'source': 'QuyChe.txt'}
# Document 167 content: 1.4.2.4. Thời gian học được phép học tối đa đối với sinh viên chuyển đến là thời gian
# tối đa hoàn t
# Document 167 metadata: {'source': 'QuyChe.txt'}
# Document 168 content: 1.4.3.2. Trường sẽ quy định cụ thể về điều kiện trao đổi sinh viên, hợp tác đào tạo,
# việc công nhận
# Document 168 metadata: {'source': 'QuyChe.txt'}
# Document 169 content: b) Ngành đào tạo của chương trình đào tạo thứ hai (ngành thứ hai) phải khác
# ngành đào tạo của chươn
# Document 169 metadata: {'source': 'QuyChe.txt'}
# Document 170 content: f) Học kỳ liền kề trước thời điểm xét của ngành thứ nhất phải có điểm trung
# bình tích lũy học kỳ tố
# Document 170 metadata: {'source': 'QuyChe.txt'}
# Document 171 content: 1.4.4.3. Thời gian tối đa được phép học đối với sinh viên học cùng lúc hai chương
# trình là thời gia
# Document 171 metadata: {'source': 'QuyChe.txt'}
# Document 172 content: 1.4.4.4. Điều kiện để sinh viên được xét cấp bằng tốt nghiệp ngành thứ hai:
# a) Được cấp bằng tốt ng
# Document 172 metadata: {'source': 'QuyChe.txt'}
# Document 173 content: 1.4.5. Điều 23. Xử lý vi phạm đối với sinh viên
# 1.4.5.1. Sinh viên có gian lận trong thi, kiểm tra,
# Document 173 metadata: {'source': 'QuyChe.txt'}
# Document 174 content: 1.4.5.3. Người học sử dụng hồ sơ, văn bằng, chứng chỉ giả làm điều kiện trúng tuyển
# hoặc điều kiện
# Document 174 metadata: {'source': 'QuyChe.txt'}
# Document 175 content: 1. QUY ĐỊNH NGOẠI NGỮ
# Về việc tổ chức học ngoại ngữ, chuẩn ngoại ngữ trong quá trình học và chuẩn tr
# Document 175 metadata: {'source': 'NN.txt'}
# Document 176 content: 1.1. Điều 1. Phạm vi điều chỉnh và đối tượng áp dụng
# 1.1.1 Văn bản này quy định về việc tổ chức học
# Document 176 metadata: {'source': 'NN.txt'}
# Document 177 content: 1.1.3. Ngoại ngữ được lựa chọn để tổ chức giảng dạy theo quy định này là tiếng Anh.
# 1.1.4. Trong quy
# Document 177 metadata: {'source': 'NN.txt'}
# Document 178 content: 1.2. Điều 2. Quy định về tổ chức học ngoại ngữ
# 1.2.1. Đối với SV chưa có chứng chỉ đạt chuẩn ngoại n
# Document 178 metadata: {'source': 'NN.txt'}
# Document 179 content: 1.2.3. Kế hoạch tổ chức giảng dạy các học phần Anh văn được phân bố theo các học kỳ tương ứng với mỗ
# Document 179 metadata: {'source': 'NN.txt'}
# Document 180 content: 1.2.4. Kiểm tra và xếp lớp Anh văn đầu khóa học
# a) Đầu khóa học, SV chưa có chứng chỉ để xét miễn họ
# Document 180 metadata: {'source': 'NN.txt'}
# Document 181 content: • SV không đủ trình độ học Anh văn 1, phải học lớp bổ túc Anh văn.
# 1.2.5. Quy định về điều kiện tiên
# Document 181 metadata: {'source': 'NN.txt'}
# Document 182 content: 1.2.6. Kết quả thi các học phần Anh văn không đưa vào bảng điểm của SV , không sử dụng để xét học bổ
# Document 182 metadata: {'source': 'NN.txt'}
# Document 183 content: 1.3. Điều 3. Quy định miễn học các học phần Anh văn
# 1.3.1. SV được miễn học 04 học phần Anh văn nếu
# Document 183 metadata: {'source': 'NN.txt'}
# Document 184 content: 1.4. Điều 4. Quy định về tổ chức kỳ thi đánh giá trình độ tiếng Anh nội bộ
# a) Đối tượng được tham gi
# Document 184 metadata: {'source': 'NN.txt'}
# Document 185 content: 1.5. Điều 5. Đánh giá kết quả học tập các học phần Anh văn
# 1.5.1. Điểm đánh giá quá trình chiếm 60%
# Document 185 metadata: {'source': 'NN.txt'}
# Document 186 content: Tiêu chí: Bài tập online
# Nội dung: Sinh viên hoàn thành các bài tập được giao qua Richmond Learning
# Document 186 metadata: {'source': 'NN.txt'}
# Document 187 content: 1.5.2. Điểm thi kết thúc học phần chiếm 40% điểm tổng kết học phần, các tiêu chí đánh giá như sau:
# A
# Document 187 metadata: {'source': 'NN.txt'}
# Document 188 content: 1.5.4. Bài thi cuối kỳ
# a) Đối với học phần Anh văn bổ túc: Bài thi cuối kỳ là bài thi gồm 02 kỹ năng
# Document 188 metadata: {'source': 'NN.txt'}
# Document 189 content: 1.6. Điều 6. Chuẩn tiếng Anh trong quá trình học
# 1.6.1. Chuẩn tiếng Anh trong quá trình học là yêu c
# Document 189 metadata: {'source': 'NN.txt'}
# Document 190 content: 1.6.2. Chuẩn tiếng Anh trong quá trình học được quy định như sau:
# Để được xét đăng ký và học các học
# Document 190 metadata: {'source': 'NN.txt'}
# Document 191 content: c) SV đạt từ 5,0 (năm) điểm trở lên trong kết quả kỳ thi đánh giá trình độ tiếng Anh nội bộ do Trung
# Document 191 metadata: {'source': 'NN.txt'}
# Document 192 content: 1.7. Điều 7. Chuẩn ngoại ngữ đầu ra trình độ đại học hệ chính quy
# Document 192 metadata: {'source': 'NN.txt'}
# Document 193 content: 1.7.1. Chuẩn ngoại ngữ đầu ra của sinh viên tốt nghiệp trình độ đại học hệ chính quy chương trình đạ
# Document 193 metadata: {'source': 'NN.txt'}
# Document 194 content: 1.7.2. Đối với chuẩn trình độ ngoại ngữ đầu ra bằng tiếng Anh, các chứng chỉ ngoại ngữ tiếng Anh đượ
# Document 194 metadata: {'source': 'NN.txt'}
# Document 195 content: e) TOEIC 4 kỹ năng: 450 Nghe-Đọc và 181 Nói-Viết do ETS cấp.
# f) Chứng chỉ PET - CEFR B1 do Cambridge
# Document 195 metadata: {'source': 'NN.txt'}
# Document 196 content: 1.7.3. Văn bằng tốt nghiệp đại học về ngôn ngữ hoặc ngoại ngư khác: Theo quyết định số 170/QD-ĐHQG n
# Document 196 metadata: {'source': 'NN.txt'}
# Document 197 content: 1.7.5. Hiệu lực của chứng chỉ ngoại ngữ
# a) Đối với chứng chỉ có ghi hiệu lực thời gian: Trường sẽ că
# Document 197 metadata: {'source': 'NN.txt'}
# Document 198 content: c) Thời hạn nộp chứng chỉ
# SV nộp chứng chỉ đạt chuẩn ngoại ngữ đầu ra một lần duy nhất trong thời gi
# Document 198 metadata: {'source': 'NN.txt'}
# Document 199 content: - Nộp trước hai tuần lễ kể từ ngày bắt đầu học kỳ để được xét miễn học các học phần Anh văn còn lại
# Document 199 metadata: {'source': 'NN.txt'}
# Document 200 content: 1.7.6. Hồ sơ xét đạt chuẩn ngoại ngữ đầu ra gồm:
# a) Bản photo có công chứng các chứng chỉ (hoặc bản
# Document 200 metadata: {'source': 'NN.txt'}
# Document 201 content: 1.7.7. Xác minh chứng chỉ ngoại ngữ và xử lý đối với các trường hợp nộp chứng chỉ giả.
# a) Xác minh c
# Document 201 metadata: {'source': 'NN.txt'}
# Document 202 content: 1.8. Điều 8. Điều khoản thi hành
# Trong quá trình thực hiện, Hiệu trưởng sẽ xem xét và quyết định sửa
# Document 202 metadata: {'source': 'NN.txt'}
# Document 203 content: Ngành Khoa học máy tính
# Chương trình: Đại học Chính quy
# Khóa tuyển: 2023
# (Ban hành kèm theo Quyết đị
# Document 203 metadata: {'source': 'KHMT.txt'}
# Document 204 content: Ngành Khoa học máy tính
# 1. Thông tin chung về chương trình đào tạo Ngành Khoa học máy tính:
# 1.1. Tên
# Document 204 metadata: {'source': 'KHMT.txt'}
# Document 205 content: - Tiếng Việt: Cử nhân Khoa học máy tính
# - Tiếng Anh: Bachelor of Science in Computer Science
# 1.8. Ng
# Document 205 metadata: {'source': 'KHMT.txt'}
# Document 206 content: 2. Mục tiêu đào tạo Ngành Khoa học máy tính
# 2.1. Mục tiêu chung:
# Mục tiêu của chương trình là nhằm
# Document 206 metadata: {'source': 'KHMT.txt'}
# Document 207 content: - Được trang bị những kỹ năng cá nhân, kỹ năng nhóm, kỹ năng giao tiếp và kỹ năng phân tích để nhận
# Document 207 metadata: {'source': 'KHMT.txt'}
# Document 208 content: PO1: Nhận biết được trách nhiệm, đạo đức nghề nghiệp, và hiện trạng kinh tế, môi trường
# và xã hội.
# Document 208 metadata: {'source': 'KHMT.txt'}
# Document 209 content: PO5: Có khả năng hình thành ý tưởng, phân tích, thiết kế, giải quyết và vận hành các hệ thống CNTT.
# Document 209 metadata: {'source': 'KHMT.txt'}
# Document 210 content: ELO 1. 1. 2 Khối kiến thức về Vật lý
# ELO 1. 1. 3 Khối kiến thức về Điện – Điện tử
# ELO 1. Kiến thức
# Document 210 metadata: {'source': 'KHMT.txt'}
# Document 211 content: ELO 1. 3. 3 Khối kiến thức kiến trúc máy tính
# ELO 1. Kiến thức
# ELO 1. 3. Kiến thức kỹ thuật nâng c
# Document 211 metadata: {'source': 'KHMT.txt'}
# Document 212 content: ELO 1. 4. 1 Kiến thức về dữ liệu và khai thác dữ liệu
# ELO 1. 4. 2 Kiến thức về Khoa học máy tính
# E
# Document 212 metadata: {'source': 'KHMT.txt'}
# Document 213 content: ELO 2. 1. Kỹ năng và tính cách cá nhân
# ELO 2. 1. 4 Cách nghĩ sáng tạo
# ELO 2. 1. 5 Cách nghĩ mang t
# Document 213 metadata: {'source': 'KHMT.txt'}
# Document 214 content: ELO 2. 2. 3 Lãnh đạo nhóm
# ELO 2. 2. 4 Phát triển nhóm
# ELO 2. 3. Kỹ năng giao tiếp
# ELO 2. 3. 1 Kỹ n
# Document 214 metadata: {'source': 'KHMT.txt'}
# Document 215 content: ELO 2. 4. 3 Kỹ năng đọc tiếng Anh
# ELO 2. 4. 4 Kỹ năng viết tiếng Anh
# ELO 2. 4. 5 Sử dụng các thuật
# Document 215 metadata: {'source': 'KHMT.txt'}
# Document 216 content: ELO 2. Kỹ năng mềm
# ELO 2. 6. Kỹ năng khởi nghiệp
# ELO 2. 6. 1 Thành lập công ty, tổ chức công ty và
# Document 216 metadata: {'source': 'KHMT.txt'}
# Document 217 content: ELO 3. 1. 1 Các vấn đề và giá trị của xã hội, kinh tế và môi trường đương đại
# ELO 3. 1. 2 Vai trò v
# Document 217 metadata: {'source': 'KHMT.txt'}
# Document 218 content: ELO 3. 2. 3 Luật lệ và quy định của công ty/ doanh nghiệp
# ELO 3. 3. Đạo đức, trách nhiệm và các giá
# Document 218 metadata: {'source': 'KHMT.txt'}
# Document 219 content: ELO 4. 1. 1 Xác định và hình thành vấn đề
# ELO 4. 1. 2 Mô hình hóa và phân tích
# ELO 4. 1. 3 Suy luậ
# Document 219 metadata: {'source': 'KHMT.txt'}
# Document 220 content: ELO 4. 3. 1 Suy nghĩ toàn cục
# ELO 4. 3. 2 Sự tương tác giữa các thành phần trong hệ thống
# ELO 4. 3
# Document 220 metadata: {'source': 'KHMT.txt'}
# Document 221 content: ELO 5. 1. 3 Đặc tả mục tiêu, yêu cầu của bài toán/ dự án
# ELO 5, 2. Thiết kế hệ thống CNTT (giải phá
# Document 221 metadata: {'source': 'KHMT.txt'}
# Document 222 content: ELO 5. 3. 1 Các tiến trình và phương pháp hiện thực hóa
# ELO 5. 3. 2 Hiện thực hóa hệ thống dựa trên
# Document 222 metadata: {'source': 'KHMT.txt'}
# Document 223 content: ELO 6. Kiểm chứng, vận hành, bảo trì và phát triển hệ thống CNTT
# ELO 6. 2. Vận hành và bảo trì
# ELO
# Document 223 metadata: {'source': 'KHMT.txt'}
# Document 224 content: ELO 6. 3. 2 Kết thúc và hủy bỏ hệ thống
# 2.4. Cơ hội nghề nghiệp Ngành Khoa học máy tính/ công việc
# Document 224 metadata: {'source': 'KHMT.txt'}
# Document 225 content: - Các vị trí thuộc nhóm Khoa học máy tính: Thiết kế và Quản trị cơ sở dữ liệu, Quản trị hệ thống CNT
# Document 225 metadata: {'source': 'KHMT.txt'}
# Document 226 content: - Các vị trí thuộc nhóm Nghiên cứu và triển khai giải pháp tại các viện, trường đại học, phòng thí n
# Document 226 metadata: {'source': 'KHMT.txt'}
# Document 227 content: - Các vị trí thuộc nhóm Giảng dạy: Trợ giảng, Giáo viên, Giảng viên các cấp phổ thông, trung tâm đào
# Document 227 metadata: {'source': 'KHMT.txt'}
# Document 228 content: 3. Khối lượng kiến thức toàn khóa Ngành Khoa học máy tính: 138 tín chỉ (Không kể môn Giáo dục Quốc p
# Document 228 metadata: {'source': 'KHMT.txt'}
# Document 229 content: 5. Quy trình đào tạo và điều kiện tốt nghiệp Ngành Khoa học máy tính
# 5.1. Quy trình đào tạo Ngành K
# Document 229 metadata: {'source': 'KHMT.txt'}
# Document 230 content: ngày 24 tháng 9 năm 2021 của Hiệu trưởng Trường Đại học Khoa học Tự nhiên, ĐHQG-HCM.
# 5.2. Điều kiện
# Document 230 metadata: {'source': 'KHMT.txt'}
# Document 231 content: - Thỏa các điều kiện tại Điều 17 của Quy chế đào tạo trình độ đại học ban hành kèm theo Quyết định s
# Document 231 metadata: {'source': 'KHMT.txt'}
# Document 232 content: 6. Cấu trúc chương trình đào tạo Ngành Khoa học máy tính
# Tổng số tín chỉ tích lũy Ngành Khoa học má
# Document 232 metadata: {'source': 'KHMT.txt'}
# Document 233 content: Tổng cộng 38 tín chỉ bao gồm:
# - Bắt buộc: 38
# - Tự chọn: 0
# - Tự chọn tự do: 0
# 6.2.2. Ngành/Chuyên ngà
# Document 233 metadata: {'source': 'KHMT.txt'}
# Document 234 content: 7. Nội dung chương trình đào tạo Ngành Khoa học máy tính
# 7.1. Kiến thức giáo dục đại cương
# Tổng số
# Document 234 metadata: {'source': 'KHMT.txt'}
# Document 235 content: - Tên học phần: Kinh tế chính trị Mác – Lênin
# - Mã học phần: BAA00102
# - Số tín chỉ: 2
# - Loại
# Document 235 metadata: {'source': 'KHMT.txt'}
# Document 236 content: - Tên học phần: Pháp luật đại cương
# - Mã học phần: BAA00004
# - Số tín chỉ: 3
# - Loại học phần: B
# Document 236 metadata: {'source': 'KHMT.txt'}
# Document 237 content: - Tên học phần: Phương pháp luận sáng tạo
# - Mã học phần: BAA00007
# - Số tín chỉ: 2
# - Loại học ph
# Document 237 metadata: {'source': 'KHMT.txt'}
# Document 238 content: - Tên học phần: Vi tích phân 2B
# - Mã học phần: MTH00004
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# -
# Document 238 metadata: {'source': 'KHMT.txt'}
# Document 239 content: - Tên học phần: Xác suất thống kê
# - Mã học phần: MTH00008
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# Document 239 metadata: {'source': 'KHMT.txt'}
# Document 240 content: - Tên học phần: Toán học tổ hợp
# - Mã học phần: MTH00050
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# -
# Document 240 metadata: {'source': 'KHMT.txt'}
# Document 241 content: - Tên học phần: Hóa đại cương 1
# - Mã học phần: CHE00001
# - Số tín chỉ: 3
# - Loại học phần: Tự chọn
#
# -
# Document 241 metadata: {'source': 'KHMT.txt'}
# Document 242 content: - Tên học phần: Vật lý đại cương 1 (Cơ - Nhiệt)
# - Mã học phần: PHY00001
# - Số tín chỉ: 3
# - Loại học p
# Document 242 metadata: {'source': 'KHMT.txt'}
# Document 243 content: 7.1.4 Tin học
# - Tên học phần: Nhập môn Khoa học máy tính
# - Mã học phần: CSC00004
# - Số tín chỉ: 4
# - L
# Document 243 metadata: {'source': 'KHMT.txt'}
# Document 244 content: - Tên học phần: Anh văn 2
# - Mã học phần: ADD00032
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - Tên h
# Document 244 metadata: {'source': 'KHMT.txt'}
# Document 245 content: - Tên học phần: Thể dục 2
# - Mã học phần: BAA00022
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
#
# 7.1.7 G
# Document 245 metadata: {'source': 'KHMT.txt'}
# Document 246 content: 7.2. Kiến thức giáo dục chuyên nghiệp Ngành Khoa học máy tính
# Khối kiến thức này bao gồm: kiến thức
# Document 246 metadata: {'source': 'KHMT.txt'}
# Document 247 content: - Tên học phần: Phương pháp lập trình hướng đối tượng
# - Mã học phần: CSC10003
# - Số tín chỉ: 4
# - Loại
# Document 247 metadata: {'source': 'KHMT.txt'}
# Document 248 content: - Tên học phần: Hệ điều hành
# - Mã học phần: CSC10007
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - Tê
# Document 248 metadata: {'source': 'KHMT.txt'}
# Document 249 content: 7.2.2. Kiến thức ngành/ chuyên ngành Ngành Khoa học máy tính: gồm các kiến thức bắt buộc, tự chọn và
# Document 249 metadata: {'source': 'KHMT.txt'}
# Document 250 content: 7.2.2.1. Chuyên ngành Khoa học máy tính
# 7.2.2.1.1. Kiến thức bắt buộc chuyên ngành Khoa học máy tính
# Document 250 metadata: {'source': 'KHMT.txt'}
# Document 251 content: Tên học phần: Khai thác dữ liệu và ứng dụng
# Mã học phần: CSC14004
# Số tín chỉ: 4
# Loại học phần: Tự ch
# Document 251 metadata: {'source': 'KHMT.txt'}
# Document 252 content: Tên học phần: Lập trình song song
# Mã học phần: CSC14120
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# 7.2.2.
# Document 252 metadata: {'source': 'KHMT.txt'}
# Document 253 content: Tên học phần: Quy hoạch tuyến tính
# Mã học phần: CSC10104
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# Tên h
# Document 253 metadata: {'source': 'KHMT.txt'}
# Document 254 content: Tên học phần: Sinh trắc học
# Mã học phần: CSC14112
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# Tên học phần
# Document 254 metadata: {'source': 'KHMT.txt'}
# Document 255 content: Tên học phần: Nhập môn khoa học dữ liệu
# Mã học phần: CSC14119
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
#
# Document 255 metadata: {'source': 'KHMT.txt'}
# Document 256 content: 7.2.2.1.3. Kiến thức tự chọn tự do chuyên ngành Khoa học máy tính
# Nếu tổng số tín chỉ của những học
# Document 256 metadata: {'source': 'KHMT.txt'}
# Document 257 content: — mục 7,2.2.x.1, và mục 7.2.2.x.2, (với l <= x <= 5)
# — mục 7.2.3. (bên dưới);
# — mục 7.2.2.1. và mục
# Document 257 metadata: {'source': 'KHMT.txt'}
# Document 258 content: 7.2.2.2. Chuyên ngành Công nghệ tri thức
# 7.2.2.2.1. Kiến thức bắt buộc chuyên ngành Công nghệ tri th
# Document 258 metadata: {'source': 'KHMT.txt'}
# Document 259 content: Tên học phần: Bảo mật cơ sở dữ liệu
# Mã học phần: CSC15002
# Số tín chỉ: 4
# Loại học phần: Bắt buộc
#
# Tên
# Document 259 metadata: {'source': 'KHMT.txt'}
# Document 260 content: Tên học phần: Thống kê máy tính và ứng dụng
# Mã học phần: CSC15007
# Số tín chỉ: 4
# Loại học phần: Bắt b
# Document 260 metadata: {'source': 'KHMT.txt'}
# Document 261 content: Tên học phần: Ứng dụng xử lý ngôn ngữ tự nhiên trong doanh nghiệp
# Mã học phần: CSC15012
# Số tín chỉ:
# Document 261 metadata: {'source': 'KHMT.txt'}
# Document 262 content: Tên học phần: Khởi nghiệp
# Mã học phần: CSC10103
# Số tín chỉ: 3
# Loại học phần: Tự chọn
#
# Tên học phần:
# Document 262 metadata: {'source': 'KHMT.txt'}
# Document 263 content: Tên học phần: Thuật toán tổ hợp và ứng dụng
# Mã học phần: CSC10106
# Số tín chỉ: 4
# Loại học phần: Tự ch
# Document 263 metadata: {'source': 'KHMT.txt'}
# Document 264 content: Tên học phần: Blockchain và ứng dụng
# Mã học phần: CSC15101
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# Tên
# Document 264 metadata: {'source': 'KHMT.txt'}
# Document 265 content: Tên học phần: Nhập môn tính toán lượng tử
# Mã học phần: CSC15109
# Số tín chỉ: 4
# Loại học phần: Tự chọn
# Document 265 metadata: {'source': 'KHMT.txt'}
# Document 266 content: 7.2.2.2.3. Kiến thức tự chọn tự do chuyên ngành Công nghệ tri thức
# Nếu tổng số tín chỉ của những học
# Document 266 metadata: {'source': 'KHMT.txt'}
# Document 267 content: — mục 7.2.2.x.1. và mục 7.2.2.x.2. (với 1 <= x <= 5);
# — mục 7.2.3.;
# — mục 7.2.2.1. và mục 7.2.2.2. c
# Document 267 metadata: {'source': 'KHMT.txt'}
# Document 268 content: 7.2.2.3. Chuyên ngành Thị giác máy tính
# 7.2.2.3.1. Kiến thức bắt buộc chuyên ngành Thị giác máy tính
# Document 268 metadata: {'source': 'KHMT.txt'}
# Document 269 content: Tên học phần: Thị giác máy tính
# Mã học phần: CSC16004
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# Tên học
# Document 269 metadata: {'source': 'KHMT.txt'}
# Document 270 content: Tên học phần: Kỹ thuật lập trình xử lý ảnh số và video số
# Mã học phần: CSC16102
# Số tín chỉ: 4
# Loại h
# Document 270 metadata: {'source': 'KHMT.txt'}
# Document 271 content: Tên học phần: Ứng dụng xử lý ảnh số và video số
# Mã học phần: CSC16109
# Số tín chỉ: 4
# Loại học phần: T
# Document 271 metadata: {'source': 'KHMT.txt'}
# Document 272 content: 7.2.2.3.3. Kiến thức tự chọn tự do chuyên ngành Thị giác máy tính
# Nếu tổng số tín chỉ của những học
# Document 272 metadata: {'source': 'KHMT.txt'}
# Document 273 content: — mục 7.2.2.x.1. và mục 7.2.2.x.2. (với l <= x <= 5);
# — mục 7.2.3.;
# — mục 7.2.2.1. và mục 7.2.2.2, c
# Document 273 metadata: {'source': 'KHMT.txt'}
# Document 274 content: 2.2.4 Chuyên ngành An toàn thông tin
# 7.2.2.4.1. Kiến thức bắt buộc chuyên ngành An toàn thông tin
# Si
# Document 274 metadata: {'source': 'KHMT.txt'}
# Document 275 content: Tên học phần: Mã hóa ứng dụng
# Mã học phần: CSC15003
# Số tín chỉ: 4
# Loại học phần: Bắt buộc
#
# Tên học p
# Document 275 metadata: {'source': 'KHMT.txt'}
# Document 276 content: Tên học phần: Thực tập thực tế
# Mã học phần: CSC10107
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# Tên học p
# Document 276 metadata: {'source': 'KHMT.txt'}
# Document 277 content: Tên học phần: Nhập môn phân tích độ phức tạp thuật toán
# Mã học phần: CSC14007
# Số tín chỉ: 4
# Loại học
# Document 277 metadata: {'source': 'KHMT.txt'}
# Document 278 content: Tên học phần: Phân tích dữ liệu bảo toàn tính riêng tư
# Mã học phần: CSC15107
# Số tín chỉ: 4
# Loại học
# Document 278 metadata: {'source': 'KHMT.txt'}
# Document 279 content: 7.2.2.4.3, Kiến thức tự chọn tự do chuyên ngành An toàn thông tin
# Nếu tổng số tín chỉ của những học
# Document 279 metadata: {'source': 'KHMT.txt'}
# Document 280 content: mục 7.2.2.x.1. và mục 7.2.2.x.2. (với 1 <= x <= 5);
# mục 7.2.3.;
# mục 7.2.2.1. và mục 7.2.2.2. của chư
# Document 280 metadata: {'source': 'KHMT.txt'}
# Document 281 content: 7.2.2.5 Chuyên ngành Khoa học dữ liệu
# 7.2.2.5.1. Kiến thức bắt buộc chuyên ngành Khoa học dữ liệu
# Si
# Document 281 metadata: {'source': 'KHMT.txt'}
# Document 282 content: Tên học phần: Nhập môn khoa học dữ liệu
# Mã học phần: CSC14119
# Số tín chỉ: 4
# Loại học phần: Tự
# Document 282 metadata: {'source': 'KHMT.txt'}
# Document 283 content: Tên học phần: Nhập môn dữ liệu lớn
# Mã học phần: CSC14118
# Số tín chỉ: 4
# Loại học phần: TC
#
# Tê
# Document 283 metadata: {'source': 'KHMT.txt'}
# Document 284 content: Tên học phần: Phân tích mạng xã hội
# Mã học phần: CSC15102
# Số tín chỉ: 4
# ...
# - Loại học phần: Bắt buộc
#
# 7.1.7 G
# Document 1508 metadata: {'source': 'KTPM.txt'}
# Document 1509 content: 7.2. Kiến thức giáo dục chuyên nghiệp Ngành Kỹ thuật phần mềm
# Khối kiến thức này bao gồm: kiến thức
# Document 1509 metadata: {'source': 'KTPM.txt'}
# Document 1510 content: - Tên học phần: Phương pháp lập trình hướng đối tượng
# - Mã học phần: CSC10003
# - Số tín chỉ: 4
# - Loại
# Document 1510 metadata: {'source': 'KTPM.txt'}
# Document 1511 content: - Tên học phần: Hệ điều hành
# - Mã học phần: CSC10007
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - Tê
# Document 1511 metadata: {'source': 'KTPM.txt'}
# Document 1512 content: - Tên học phần: Cơ sở trí tuệ nhân tạo
# - Mã học phần: CSC14003
# - Số tín chỉ: 4
# - Loại học phần: Bắt
# Document 1512 metadata: {'source': 'KTPM.txt'}
# Document 1513 content: STT: 1
# Tên học phần: Kiểm thử phần mềm
# Mã học phần: CSC13003
# Số tín chỉ: 4
# Loại học phần: Bắt buộc
#
#
# Document 1513 metadata: {'source': 'KTPM.txt'}
# Document 1514 content: STT: 5
# Tên học phần: Phát triển ứng dụng web
# Mã học phần: CSC13008
# Số tín chỉ: 4
# Loại học phần: Bắt
# Document 1514 metadata: {'source': 'KTPM.txt'}
# Document 1515 content: STT: 9
# Tên học phần: Thiết kế giao diện
# Mã học phần: CSC13112
# Số tín chỉ: 4
# Loại học phần: Bắt buộc
#
# Document 1515 metadata: {'source': 'KTPM.txt'}
# Document 1516 content: STT: 2
# Tên học phần: Kiến tập nghề nghiệp
# Mã học phần: CSC10102
# Số tín chỉ: 2
# Loại học phần: Tự chọn
# Document 1516 metadata: {'source': 'KTPM.txt'}
# Document 1517 content: STT: 5
# Tên học phần: Thực tập thực tế
# Mã học phần: CSC10107
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# ST
# Document 1517 metadata: {'source': 'KTPM.txt'}
# Document 1518 content: STT: 9
# Tên học phần: Nhập môn hệ thống phân tán
# Mã học phần: CSC13103
# Số tín chỉ: 4
# Loại học phần: T
# Document 1518 metadata: {'source': 'KTPM.txt'}
# Document 1519 content: STT: 12
# Tên học phần: Nhập môn DevOps
# Mã học phần: CSC11007
# Số tín chỉ: 4
# Loại học phần: Tự chọn
#
# ST
# Document 1519 metadata: {'source': 'KTPM.txt'}
# Document 1520 content: 7.2.2.3. Kiến thức tự chọn tự do Ngành Kỹ thuật phần mềm
# Nếu tổng số tín chỉ của những học phần bắt
# Document 1520 metadata: {'source': 'KTPM.txt'}
# Document 1521 content: mục 7.2.2.1. và mục 7.2.2.2.;
# mục 7.2.3.;
# mục 7.2.2.1. và mục 7.2.2.2. của chương trình đào tạo đạ
# Document 1521 metadata: {'source': 'KTPM.txt'}
# Document 1522 content: 7.2.3. Kiến thức tốt nghiệp Ngành Kỹ thuật phần mềm
# Sinh viên tích lũy tối thiêu 10 tín chỉ, chọn 01
# Document 1522 metadata: {'source': 'KTPM.txt'}
# Document 1523 content: Phương án 3:
# - Tên học phần: Thực tập dự án tốt nghiệp
# - Mã học phần: CSC10204
# - Số tín chỉ: 6
# - Loạ
# Document 1523 metadata: {'source': 'KTPM.txt'}
# Document 1524 content: Phương án 3:
# Học phần tự chọn:
# Lựa chọn 3:
# Tên học phần: Đồ án Công nghệ phần mềm
# Mã học phần: CSC13
# Document 1524 metadata: {'source': 'KTPM.txt'}
# Document 1525 content: Phương án 3:
# Học phần tự chọn:
# Lựa chọn 4:
# Tên học phần: Phát triển ứng dụng cho thiết bị di động nâ
# Document 1525 metadata: {'source': 'KTPM.txt'}
# Document 1526 content: 8.2. Các môn học Học kỳ 2 năm 1 Ngành Kỹ thuật phần mềm
# BAA00022 Thể dục 2
# ADD00032 Anh văn 2
# BAA0
# Document 1526 metadata: {'source': 'KTPM.txt'}
# Document 1527 content: 8.3. Các môn học Học kỳ 1 năm 2 Ngành Kỹ thuật phần mềm
# ADD00033 Anh văn 3
# CHE00002 Hóa đại cương 2
# Document 1527 metadata: {'source': 'KTPM.txt'}
# Document 1528 content: 8.4. Các môn học Học kỳ 2 năm 2 Ngành Kỹ thuật phần mềm
# ADD00034 Anh văn 4
# BAA00101 Triết học Mác –
# Document 1528 metadata: {'source': 'KTPM.txt'}
# Document 1529 content: 8.5. Các môn học Học kỳ 1 năm 3 Ngành Kỹ thuật phần mềm
# BAA00102 Kinh tế chính trị Mác – Lênin
# GEO0
# Document 1529 metadata: {'source': 'KTPM.txt'}
# Document 1530 content: 8.6. Các môn học Học kỳ 2 năm 3 Ngành Kỹ thuật phần mềm
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC14003
# Document 1530 metadata: {'source': 'KTPM.txt'}
# Document 1531 content: 8.7. Các môn học Học kỳ 1 năm 4 Ngành Kỹ thuật phần mềm
# BAA00104 Lịch sử Đảng Cộng sản Việt Nam
# CSC1
# Document 1531 metadata: {'source': 'KTPM.txt'}
# Document 1532 content: 8.8. Các môn học Học kỳ 2 năm 4 Ngành Kỹ thuật phần mềm
# BAA00003 Tư tưởng Hồ Chí Minh
# CSC13101 Các
# Document 1532 metadata: {'source': 'KTPM.txt'}
# Document 1533 content: 9. Khả năng liên thông với các chương trình đào tạo khác của Ngành Kỹ thuật phần mềm
# Sinh viên có th
# Document 1533 metadata: {'source': 'KTPM.txt'}
# Document 1534 content: Ngoài ra, sinh viên cũng có thể liên thông với chương trình đào tạo trình độ thạc sỹ của các ngành s
# Document 1534 metadata: {'source': 'KTPM.txt'}
# Document 1535 content: Ngành Hệ thống thông tin
# Chương trình: Đại học Chính quy
# Khóa tuyển: 2023
# (Ban hành kèm theo Quyết
# Document 1535 metadata: {'source': 'HTTT.txt'}
# Document 1536 content: 1. Thông tin chung về chương trình đào tạo Ngành Hệ thống thông tin:
# 1.1. Tên ngành:
# - Tiếng việt: H
# Document 1536 metadata: {'source': 'HTTT.txt'}
# Document 1537 content: - Tiếng Anh: Bachelor of Science in Information Systems
# 1.8. Ngôn ngữ giảng dạy: tiếng Việt
# 1.9. N
# Document 1537 metadata: {'source': 'HTTT.txt'}
# Document 1538 content: 2. Mục tiêu đào tạo Ngành Hệ thống thông tin
# 2.1. Mục tiêu chung:
# Mục tiêu của chương trình là nhằ
# Document 1538 metadata: {'source': 'HTTT.txt'}
# Document 1539 content: - Được trang bị những kỹ năng cá nhân, kỹ năng nhóm, kỹ năng giao tiếp và kỹ năng phân tích để nhận
# Document 1539 metadata: {'source': 'HTTT.txt'}
# Document 1540 content: PO1: Nhận biết được trách nhiệm, đạo đức nghề nghiệp, và hiện trạng kinh tế, môi trường
# và xã hội.
# Document 1540 metadata: {'source': 'HTTT.txt'}
# Document 1541 content: PO5: Có khả năng hình thành ý tưởng, phân tích, thiết kế, giải quyết và vận hành các hệ thống CNTT.
# Document 1541 metadata: {'source': 'HTTT.txt'}
# Document 1542 content: 2.3. Chuẩn đầu ra (CĐR) của chương trình đào tạo Ngành Hệ thống thông tin
# ELO 1. Kiến thức
# ELO 1.
# Document 1542 metadata: {'source': 'HTTT.txt'}
# Document 1543 content: ELO 1. 3. Kiến thức kỹ thuật nâng cao, các công cụ và phương pháp trong ngành CNTT
# ELO 1. 3. 1 Khối
# Document 1543 metadata: {'source': 'HTTT.txt'}
# Document 1544 content: ELO 1. 3. 5 Khối kiến thức cơ sở dữ liệu
# ELO 1. 3. 6 Khối kiến thức về an ninh, bảo mật và tính riê
# Document 1544 metadata: {'source': 'HTTT.txt'}
# Document 1545 content: ELO 2. Kỹ năng mềm
# ELO 2. 1. Kỹ năng và tính cách cá nhân
# ELO 2. 1. 1 Độc lập
# ELO 2. 1. 2 Tự tin
# Document 1545 metadata: {'source': 'HTTT.txt'}
# Document 1546 content: ELO 2. 1. 8 Học và tự học suốt đời
# ELO 2. 1. 9 Quản trị dự án
# ELO 2. 2. Kỹ năng nhóm
# ELO 2. 2. 1
# Document 1546 metadata: {'source': 'HTTT.txt'}
# Document 1547 content: ELO 2. 4. Kỹ năng ngoại ngữ
# ELO 2. 4. 1 Kỹ năng nói tiếng Anh
# ELO 2. 4. 2 Kỹ năng nghe tiếng Anh
# E
# Document 1547 metadata: {'source': 'HTTT.txt'}
# Document 1548 content: ELO 2. 5. 4 Xây dựng và dẫn dắt một tổ chức
# ELO 2. 5. 5 Lên kế hoạch và dẫn dắt dự án đến thành côn
# Document 1548 metadata: {'source': 'HTTT.txt'}
# Document 1549 content: ELO 3. Ngữ cảnh, trách nhiệm và đạo đức
# ELO 3. 1. Ngữ cảnh bên ngoài, xã hội, kinh tế và môi trường
# Document 1549 metadata: {'source': 'HTTT.txt'}
# Document 1550 content: ELO 3. 2. 1 Ngữ cảnh và văn hóa của công ty, tổ chức
# ELO 3. 2. 2 Các bên liên quan, mục tiêu và chi
# Document 1550 metadata: {'source': 'HTTT.txt'}
# Document 1551 content: ELO 4. Phương pháp khoa học và nghiên cứu
# ELO 4. 1. Suy luận có phân tích và giải quyết vấn đề
# ELO
# Document 1551 metadata: {'source': 'HTTT.txt'}
# Document 1552 content: ELO 4. 2. 4 Kiểm chứng và bảo vệ giả thuyết
# ELO 4. 3. Suy nghĩ tầm mức hệ thống
# ELO 4. 3. 1 Suy ng
# Document 1552 metadata: {'source': 'HTTT.txt'}
# Document 1553 content: ELO 5. Hình thành ý tưởng, thiết kế và hiện thực hóa hệ thống CNTT
# ELO 5. 1. Hình thành ý tưởng/ bà
# Document 1553 metadata: {'source': 'HTTT.txt'}
# Document 1554 content: ELO 5. 2. 1 Tiến trình và phương pháp thiết kế
# ELO 5. 2. 2 Thiết kế kiến trúc và các thành phần của
# Document 1554 metadata: {'source': 'HTTT.txt'}
# Document 1555 content: ELO 6. Kiểm chứng, vận hành, bảo trì và phát triển hệ thống CNTT
# ELO 6. 1. Kiểm chứng
# ELO 6. 1. 1
# Document 1555 metadata: {'source': 'HTTT.txt'}
# Document 1556 content: 2.4. Cơ hội nghề nghiệp Ngành Hệ thống thông tin/ công việc người học có thể đảm nhận
# Sinh viên sau
# Document 1556 metadata: {'source': 'HTTT.txt'}
# Document 1557 content: - Các vị trí thuộc nhóm Hệ thống thông tin: Thiết kế và Quản trị cơ sở dữ liệu, Quản trị hệ thống CN
# Document 1557 metadata: {'source': 'HTTT.txt'}
# Document 1558 content: - Các vị trí thuộc nhóm Nghiên cứu và triển khai giải pháp tại các viện, trường đại học, phòng thí n
# Document 1558 metadata: {'source': 'HTTT.txt'}
# Document 1559 content: - Các vị trí thuộc nhóm Giảng dạy: Trợ giảng, Giáo viên, Giảng viên các cấp phổ thông, trung tâm đào
# Document 1559 metadata: {'source': 'HTTT.txt'}
# Document 1560 content: 3. Khối lượng kiến thức toàn khóa Ngành Hệ thống thông tin: 138 tín chỉ (Không kể môn Giáo dục Quốc
# Document 1560 metadata: {'source': 'HTTT.txt'}
# Document 1561 content: 5. Quy trình đào tạo và điều kiện tốt nghiệp Ngành Hệ thống thông tin
# 5.1. Quy trình đào tạo Ngành
# Document 1561 metadata: {'source': 'HTTT.txt'}
# Document 1562 content: ngày 24 tháng 9 năm 2021 của Hiệu trưởng Trường Đại học Khoa học Tự nhiên, ĐHQG-HCM.
# 5.2. Điều kiện
# Document 1562 metadata: {'source': 'HTTT.txt'}
# Document 1563 content: - Thỏa các điều kiện tại Điều 17 của Quy chế đào tạo trình độ đại học ban hành kèm theo Quyết định s
# Document 1563 metadata: {'source': 'HTTT.txt'}
# Document 1564 content: 6. Cấu trúc chương trình đào tạo Ngành Hệ thống thông tin
# Tổng số tín chỉ tích lũy Ngành Hệ thống t
# Document 1564 metadata: {'source': 'HTTT.txt'}
# Document 1565 content: 6.2. Giáo dục chuyên nghiệp Ngành Hệ thống thông tin
# Tổng cộng 82 tín chỉ
# 6.2.1. Cơ sở ngành
# Tổng c
# Document 1565 metadata: {'source': 'HTTT.txt'}
# Document 1566 content: 6.2.3. Tốt nghiệp Ngành Hệ thống thông tin
# Tổng cộng 10 tín chỉ bao gồm:
# - Bắt buộc: 0
# - Tự chọn: 1
# Document 1566 metadata: {'source': 'HTTT.txt'}
# Document 1567 content: - Tên học phần: Kinh tế chính trị Mác – Lênin
# - Mã học phần: BAA00102
# - Số tín chỉ: 2
# - Loại
# Document 1567 metadata: {'source': 'HTTT.txt'}
# Document 1568 content: - Tên học phần: Pháp luật đại cương
# - Mã học phần: BAA00004
# - Số tín chỉ: 3
# - Loại học phần: B
# Document 1568 metadata: {'source': 'HTTT.txt'}
# Document 1569 content: - Tên học phần: Phương pháp luận sáng tạo
# - Mã học phần: BAA00007
# - Số tín chỉ: 2
# - Loại học ph
# Document 1569 metadata: {'source': 'HTTT.txt'}
# Document 1570 content: - Tên học phần: Vi tích phân 2B
# - Mã học phần: MTH00004
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# -
# Document 1570 metadata: {'source': 'HTTT.txt'}
# Document 1571 content: - Tên học phần: Xác suất thống kê
# - Mã học phần: MTH00008
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# Document 1571 metadata: {'source': 'HTTT.txt'}
# Document 1572 content: - Tên học phần: Toán học tổ hợp
# - Mã học phần: MTH00050
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# -
# Document 1572 metadata: {'source': 'HTTT.txt'}
# Document 1573 content: - Tên học phần: Hóa đại cương 1
# - Mã học phần: CHE00001
# - Số tín chỉ: 3
# - Loại học phần: Tự chọn
#
# -
# Document 1573 metadata: {'source': 'HTTT.txt'}
# Document 1574 content: - Tên học phần: Vật lý đại cương 1 (Cơ - Nhiệt)
# - Mã học phần: PHY00001
# - Số tín chỉ: 3
# - Loại học p
# Document 1574 metadata: {'source': 'HTTT.txt'}
# Document 1575 content: 7.1.4 Tin học
# - Tên học phần: Nhập môn công nghệ thông tin
# - Mã học phần: CSC00004
# - Số tín chỉ: 4
# -
# Document 1575 metadata: {'source': 'HTTT.txt'}
# Document 1576 content: - Tên học phần: Anh văn 2
# - Mã học phần: ADD00032
# - Số tín chỉ: 3
# - Loại học phần: Bắt buộc
#
# - Tên h
# Document 1576 metadata: {'source': 'HTTT.txt'}
# Document 1577 content: - Tên học phần: Thể dục 2
# - Mã học phần: BAA00022
# - Số tín chỉ: 2
# - Loại học phần: Bắt buộc
#
# 7.1.7 G
# Document 1577 metadata: {'source': 'HTTT.txt'}
# Document 1578 content: 7.2. Kiến thức giáo dục chuyên nghiệp Ngành Hệ thống Thông tin
# Khối kiến thức này bao gồm: kiến thức
# Document 1578 metadata: {'source': 'HTTT.txt'}
# Document 1579 content: - Tên học phần: Phương pháp lập trình hướng đối tượng
# - Mã học phần: CSC10003
# - Số tín chỉ: 4
# - Loại
# Document 1579 metadata: {'source': 'HTTT.txt'}
# Document 1580 content: - Tên học phần: Hệ điều hành
# - Mã học phần: CSC10007
# - Số tín chỉ: 4
# - Loại học phần: Bắt buộc
#
# - Tê
# Document 1580 metadata: {'source': 'HTTT.txt'}
# Document 1581 content: - Tên học phần: Cơ sở trí tuệ nhân tạo
# - Mã học phần: CSC14003
# - Số tín chỉ: 4
# - Loại học phần: Bắt
# Document 1581 metadata: {'source': 'HTTT.txt'}
# Document 1582 content: - Tên học phần: Cơ sở dữ liệu nâng cao
# - Mã học phần: CSC12002
# - Số tín chỉ: 4
# - Loại học phần: Tự c
# Document 1582 metadata: {'source': 'HTTT.txt'}
# Document 1583 content: - Tên học phần: Phát triển ứng dụng hệ thống thông tin hiện đại
# - Mã học phần: CSC12005
# - Số tín chỉ
# Document 1583 metadata: {'source': 'HTTT.txt'}
# Document 1584 content: - Tên học phần: Kiến tập nghề nghiệp
# - Mã học phần: CSC10102
# - Số tín chỉ: 2
# - Loại học phần: Tự chọ
# Document 1584 metadata: {'source': 'HTTT.txt'}
# Document 1585 content: - Tên học phần: Thuật toán tổ hợp và ứng dụng
# - Mã học phần: CSC10106
# - Số tín chỉ: 4
# - Loại học phầ
# Document 1585 metadata: {'source': 'HTTT.txt'}
# Document 1586 content: - Tên học phần: Chuyên đề Hệ quản trị cơ sở dữ liệu nâng cao
# - Mã học phần: CSC12103
# - Số tín chỉ: 4
# Document 1586 metadata: {'source': 'HTTT.txt'}
# Document 1587 content: - Tên học phần: Phân tích dữ liệu ứng dụng
# - Mã học phần: CSC12110
# - Số tín chỉ: 4
# - Loại học phần:
# Document 1587 metadata: {'source': 'HTTT.txt'}
# Document 1588 content: 7.2.2.3. Kiến thức tự chọn tự do Ngành Hệ thống Thông tin
# Nếu tổng số tín chỉ của những học phần bắt
# Document 1588 metadata: {'source': 'HTTT.txt'}
# Document 1589 content: mục 7.2.2.1. và mục 7.2.2.2.;
# mục 7.2.3.;
# mục 7.2.2.1. và mục 7.2.2.2. của chương trình đào tạo đạ
# Document 1589 metadata: {'source': 'HTTT.txt'}
# Document 1590 content: 7.2.3. Kiến thức tốt nghiệp Ngành Hệ thống Thông tin
# Sinh viên tích lũy tối thiểu 10 tín chỉ, chọn 0
# Document 1590 metadata: {'source': 'HTTT.txt'}
# Document 1591 content: Phương án 2:
# - Tên học phần: Thực tập tốt nghiệp
# - Mã học phần: CSC10252
# - Số tín chỉ: 10
# - Loại học
# Document 1591 metadata: {'source': 'HTTT.txt'}
# Document 1592 content: - Tên học phần: Quản trị cơ sở dữ liệu hiện đại
# - Mã học phần: CSC12111
# - Số tín chỉ: 4
# - Loại học p
# Document 1592 metadata: {'source': 'HTTT.txt'}
# Document 1593 content: 8.2. Các môn học Học kỳ 2 năm 1 Ngành Hệ thống Thông tin
# BAA00022 Thể dục 2
# ADD00032 Anh văn 2
# BAA
# Document 1593 metadata: {'source': 'HTTT.txt'}
# Document 1594 content: 8.3. Các môn học Học kỳ 1 năm 2 Ngành Hệ thống Thông tin
# ADD00033 Anh văn 3
# CHE00002 Hóa đại cương
# Document 1594 metadata: {'source': 'HTTT.txt'}
# Document 1595 content: 8.4. Các môn học Học kỳ 2 năm 2 Ngành Hệ thống Thông tin
# ADD00034 Anh văn 4
# BAA00101 Triết học Mác
# Document 1595 metadata: {'source': 'HTTT.txt'}
# Document 1596 content: 8.5. Các môn học Học kỳ hè năm 2 Ngành Hệ thống Thông tin
# CSC10121 Kỹ năng mềm
#
# 8.6. Các môn học Học
# Document 1596 metadata: {'source': 'HTTT.txt'}
# Document 1597 content: 8.7. Các môn học Học kỳ 2 năm 3 Ngành Hệ thống Thông tin
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC1400
# Document 1597 metadata: {'source': 'HTTT.txt'}
# Document 1598 content: 8.8. Các môn học Học kỳ hè năm 3 Ngành Hệ thống Thông tin
# CSC10103 Khởi nghiệp
#
# 8.9. Các môn học Họ
# Document 1598 metadata: {'source': 'HTTT.txt'}
# Document 1599 content: 8.10. Các môn học Học kỳ 2 năm 4 Ngành Hệ thống Thông tin
# CSC12107 Hệ thống thông tin phục vụ trí tu
# Document 1599 metadata: {'source': 'HTTT.txt'}
# Document 1600 content: 9. Khả năng liên thông với các chương trình đào tạo khác của Ngành Hệ thống Thông tin
# Sinh viên có t
# Document 1600 metadata: {'source': 'HTTT.txt'}
# Document 1601 content: Ngoài ra, sinh viên cũng có thể liên thông với chương trình đào tạo trình độ thạc sỹ của các ngành s
# Document 1601 metadata: {'source': 'HTTT.txt'}

# %%
from langchain.embeddings import HuggingFaceInferenceAPIEmbeddings

# 1. Sử dụng chunked_documents từ TextSplitter
print(f"Số lượng chunks để add vào Qdrant: {len(chunked_documents)}")

# 2. Tạo embeddings và add vào Qdrant
if len(chunked_documents) > 0:
    # Khởi tạo embeddings
    embeddings = HuggingFaceInferenceAPIEmbeddings(
        model_name=EMBEDDINGS_MODEL_NAME,
        api_key=HUGGINGFACE_API_KEY
    )

    # Tạo vector database từ chunks
    qdrant = Qdrant.from_documents(
        chunked_documents,
        embeddings,
        url=QDRANT_URL,
        prefer_grpc=False,
        collection_name=COLLECTION_NAME,  # Đổi tên collection để phân biệt
        api_key=QDRANT_API_KEY
    )
    print("Đã tạo vector database thành công!")
else:
    print("Không có dữ liệu chunks để tạo vector database!")
# Out:
# Số lượng chunks để add vào Qdrant: 1602
# Đã tạo vector database thành công!

# %%
# Test tìm kiếm
query = "Các môn học Học kỳ 2 năm 3 ngành hệ thống thông tin"
found_docs = qdrant.similarity_search(query, k=10)

print("\nKết quả test tìm kiếm:")
for i, doc in enumerate(found_docs):
    print(f"\nKết quả {i+1}:")
    print(doc.page_content)
    print(doc.metadata)
    print("-" * 80)
# Out:
# Kết quả test tìm kiếm:
#
# Kết quả 1:
# 8.2.6. Các môn học Học kỳ 2 năm 3 Chuyên ngành Công nghệ thông tin
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10107 Thực tập thực tế
# CSC11006 Nhập môn điện toán đám mây
# CSC15003 Mã hóa ứng dụng
# CSC10102 Kiến tập nghề nghiệp
# CSC10103 Khởi nghiệp
# CSC10104 Quy hoạch tuyển tinh
# CSC10106 Thuật toán tổ hợp và ứng dụng
# CSC12004 Phân tích thiết kế hệ thống thông tin
# CSC11006 Nhập môn điện toán đám mây
# CSC12105 Thương mại điện tử
# CSC13010 Thiết kế phần mềm
# CSC14005 Nhập môn học máy
# CSC14118 Nhập môn dữ liệu lớn
# CSC17001 Phân tích dữ liệu thông minh
# CSC15004 Học thống kê
# {'source': 'CNTT.txt', '_id': '867dc2de-032d-4ff1-8392-531220a1cb79', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------
#
# Kết quả 2:
# 8.1.6. Các môn học Học kỳ 2 năm 3 Chuyên ngành Mạng máy tính và Viễn thông
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10107 Thực tập thực tế (Học kỳ hè năm 3)
# CSC11002 Hệ thống viễn thông
# CSC11003 Lập trình mạng
# CSC11006 Nhập môn điện toán đám mây
# CSC11007 Nhập môn DevOps
# CSC11115 An ninh mạng
# CSC15003 Mã hóa ứng dụng
# {'source': 'CNTT.txt', '_id': 'a060440c-edff-46b5-8469-2b144fcd6657', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------
#
# Kết quả 3:
# 8.5.6. Các môn học Học kỳ 2 năm 3 Chuyên ngành Khoa học dữ liệu
# CSC13002 Nhập môn công nghệ phần mềm
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10108 Trực quan hóa dữ liệu
# CSC14005 Nhập môn học máy
# CSC15007 Thống kê máy tính và ứng dụng
# CSC17001 Phân tích dữ liệu thông minh
# CSC14004 Khai thác dữ liệu và ứng dụng
# CSC14118 Nhập môn dữ liệu lớn
# CSC15004 Học thống kê
# {'source': 'KHMT.txt', '_id': 'd318e030-bc39-4cab-bd4f-55907530a3ee', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------
#
# Kết quả 4:
# 8.4.6. Các môn học Học kỳ 2 năm 3 Chuyên ngành An toàn thông tin
# CSC13002 Nhập môn công nghệ phần mềm
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10104 Quy hoạch tuyến tính
# CSC10107 Thực tập thực tế
# CSC15002 Bảo mật cơ sở dữ liệu
# CSC15003 Mã hóa ứng dụng
# CSC12001 An toàn và bảo mật dữ liệu trong hệ thống thông tin
# CSC14005 Nhập môn học máy
# CSC15004 Học thống kê
# CSC15107 Phân tích dữ liệu bảo toàn tính riêng tư
# {'source': 'KHMT.txt', '_id': 'f31986e3-e233-4831-a54f-d024126c8ae3', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------
#
# Kết quả 5:
# 8.1.6. Các môn học Học kỳ 2 năm 3 Chuyên ngành Khoa học máy tính
# CSC13002 Nhập môn công nghệ phần mềm
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10102 Kiến tập nghề nghiệp
# CSC10104 Quy hoạch tuyến tính
# CSC14005 Nhập môn học máy
# CSC14006 Nhận dạng
# CSC14008 Phương pháp nghiên cứu khoa học
# CSC10108 Trực quan hóa dữ liệu
# CSC14118 Nhập môn dữ liệu lớn
# CSC14001 Automata và ngôn ngữ hình thức
# CSC10103 Khởi nghiệp (Học kỳ hè năm 3)
# {'source': 'KHMT.txt', '_id': 'b55ad22c-98d3-40bd-abb9-3b4bdb5a610a', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------
#
# Kết quả 6:
# 8.7. Các môn học Học kỳ 2 năm 3 Ngành Hệ thống Thông tin
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC14003 Cơ sở trí tuệ nhân tạo
# CSC10102 Kiến tập nghề nghiệp
# CSC10104 Quy hoạch tuyến tính
# CSC10106 Thuật toán tổ hợp và ứng dụng
# CSC10107 Thực tập thực tế
# CSC12001 An toàn và bảo mật dữ liệu trong hệ thống thông tin
# CSC12004 Phân tích thiết kế hệ thống thông tin
# CSC12103 Chuyên đề Hệ quản trị cơ sở dữ liệu nâng cao
# CSC12105 Thương mại điện tử
#
# 8.8. Các môn học Học kỳ hè năm 3 Ngành Hệ thống Thông tin
# CSC10103 Khởi nghiệp
# {'source': 'HTTT.txt', '_id': 'ed6474a6-93fb-40cd-84f4-1fe78c1dd290', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------
#
# Kết quả 7:
# 8.2.6. Các môn học Học kỳ 2 năm 3 Chuyên ngành Công nghệ tri thức
# CSC13002 Nhập môn công nghệ phần mềm
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10102 Kiến tập nghề nghiệp
# CSC10104 Quy hoạch tuyến tính
# CSC10106 Thuật toán tổ hợp ứng dụng
# CSC10107 Thực tập thực tế
# CSC15002 Bảo mật cơ sở dữ liệu
# CSC15003 Mã hóa ứng dụng
# CSC15004 Học thống kê
# CSC15007 Thống kê máy tính và ứng dụng
# CSC15012 Ứng dụng xử lý ngôn ngữ tự nhiên trong doanh nghiệp
# CSC15107 Phân tích dữ liệu bảo toàn tinh riêng tư
# CSC15108 Pháp chứng cho dữ liệu số
# CSC15105 Khai thác dữ liệu văn bản và ứng dụng
# {'source': 'KHMT.txt', '_id': 'a7a10543-daa1-41c9-911a-5e2eb181e8f3', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------
#
# Kết quả 8:
# 8.1.4. Các môn học Học kỳ 2 năm 2 Chuyên ngành Mạng máy tính và Viễn thông
# ADD00034 Anh văn 4
# BAA00101 Triết học Mác – Lênin
# BAA00005 Kinh tế đại cương
# BAA00006 Tâm lý đại cương
# BAA00007 Phương pháp luận sáng tạo
# MTH00051 Toán ứng dụng và thống kê
# MTH00052 Phương pháp tính
# MTH00053 Lý thuyết số
# CSC10003 Phương pháp lập trình hướng đối tượng
# CSC10006 Cơ sở dữ liệu
# CSC10009 Hệ thống máy tính
# CSC10121 Kỹ năng mềm (Học kỳ hè năm 2)
# {'source': 'CNTT.txt', '_id': 'f30c1bb2-7ca2-48fc-935c-8090baaa8e2e', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------
#
# Kết quả 9:
# 8.6. Các môn học Học kỳ 2 năm 3 Ngành Kỹ thuật phần mềm
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC14003 Cơ sở trí tuệ nhân tạo
# CSC10102 Kiến tập nghề nghiệp
# CSC10107 Thực tập thực tế
# CSC13005 Phân tích và quản lý yêu cầu phần mềm
# CSC13010 Thiết kế phần mềm
# CSC11007 Nhập môn DevOps
# CSC14005 Nhập môn học máy
# CSC10103 Khởi nghiệp (Học kỳ hè năm 3)
# {'source': 'KTPM.txt', '_id': '0b4c6606-9777-4438-a317-a7dd2e9419a3', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------
#
# Kết quả 10:
# 8.2.4. Các môn học Học kỳ 2 năm 2 Chuyên ngành Công nghệ thông tin
# ADD00034 Anh văn 4
# BAA00101 Triết học Mác – Lênin
# BAA00005 Kinh tế đại cương
# BAA00006 Tâm lý đại cương
# BAA00007 Phương pháp luận sáng tạo
# MTH00051 Toán ứng dụng và thống kê
# MTH00052 Phương pháp tính
# MTH00053 Lý thuyết số
# CSC10003 Phương pháp lập trình hướng đối tượng
# CSC10006 Cơ sở dữ liệu
# CSC10009 Hệ thống máy tính
# CSC10121 Kỹ năng mềm (Học kỳ hè năm 2)
# {'source': 'CNTT.txt', '_id': '83babd21-fd6a-4de2-8570-706067547ae1', '_collection_name': 'ITUS_e5_R_600'}
# --------------------------------------------------------------------------------

# %% [markdown]
# # **Sử dụng TextSplitter cải tiến Chunking theo đề mục**

# %%
import re
from typing import List
from langchain.docstore.document import Document
from langchain.text_splitter import TextSplitter

class TextSplitter(TextSplitter):
    def __init__(self, chunk_size: int = 600, chunk_overlap: int = 200):
        super().__init__(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        print(f"Initialized with chunk_size={chunk_size}, chunk_overlap={chunk_overlap}")

    def is_title(self, line: str) -> bool:
        return bool(re.match(r'^\d+(\.\d+)*\.', line.strip()))

    def find_last_title(self, lines: List[str]) -> str:
        """Tìm dòng tiêu đề cuối cùng trong danh sách dòng."""
        for line in reversed(lines):
            if self.is_title(line):
                return line
        return ""

    def normalize_whitespace(self, text: str) -> str:
        """Đảm bảo nội dung không chứa nhiều hơn 2 ký tự xuống dòng liên tiếp."""
        return re.sub(r'(\n{2,})', '\n\n', text)

    def find_nearest_split_point(self, text: str) -> int:
        """Tìm vị trí khoảng trắng gần nhất để cắt."""
        split_point = max(text.rfind(' '), text.rfind('!'), text.rfind('?'))
        return split_point if split_point != -1 else len(text)

    def split_text(self, text: str) -> List[str]:
        print("\nStarting split_text...")
        text = self.normalize_whitespace(text)  # Chuẩn hóa các ký tự xuống dòng
        chunks = []
        current_chunk = []
        current_length = 0
        lines = text.splitlines()
        last_title = ""

        for line in lines:
            line_length = len(line)

            if current_length + line_length > self.chunk_size:
                # Đảm bảo kích thước chunk không vượt quá chunk_size
                chunk = "\n".join(current_chunk).strip()
                if len(chunk) > self.chunk_size:
                    split_point = self.find_nearest_split_point(chunk[:self.chunk_size])
                    chunks.append(chunk[:split_point + 1].strip())
                    overlap_text = chunk[split_point + 1:]
                else:
                    chunks.append(chunk)
                    overlap_text = "\n".join(current_chunk)[-self.chunk_overlap:]

                overlap_lines = overlap_text.splitlines()

                # Kiểm tra nếu overlap chứa dòng tiêu đề
                contains_title = any(self.is_title(ol) for ol in overlap_lines)

                if contains_title:
                    # Cắt bỏ nội dung trước dòng tiêu đề đầu tiên trong overlap
                    for i, ol in enumerate(overlap_lines):
                        if self.is_title(ol):
                            overlap_lines = overlap_lines[i:]
                            break
                elif last_title:
                    # Nếu dòng đầu tiên của overlap không phải tiêu đề, cắt bỏ dòng đầu tiên
                    if overlap_lines and not self.is_title(overlap_lines[0]):
                        overlap_lines.pop(0)

                    # Thêm dòng tiêu đề cuối cùng từ chunk trước đó
                    overlap_lines.insert(0, last_title)

                overlap = "\n".join(overlap_lines).strip()

                # Đảm bảo dòng tiêu đề có thể được sử dụng nhiều lần
                current_chunk = overlap_lines.copy() if overlap else []
                current_length = len(overlap)

                last_title = self.find_last_title(current_chunk)  # Cập nhật dòng tiêu đề cuối cùng

            current_chunk.append(line)
            current_length += line_length + 1

            if self.is_title(line):
                last_title = line  # Cập nhật dòng tiêu đề nếu tìm thấy

        if current_chunk:
            chunk = "\n".join(current_chunk).strip()
            if len(chunk) < self.chunk_overlap and len(chunks) > 0:
                chunks[-1] += "\n" + chunk
            elif len(chunk) > self.chunk_size:
                split_point = self.find_nearest_split_point(chunk[:self.chunk_size])
                chunks.append(chunk[:split_point + 1].strip())
                chunks.append(chunk[split_point + 1:].strip())
            else:
                chunks.append(chunk)

        print(f"\nTotal chunks created: {len(chunks)}")
        return chunks

    def create_documents(self, texts: List[str], metadatas: List[dict] = None) -> List[Document]:
        print("\nStarting create_documents...")
        documents = []
        for i, text in enumerate(texts):
            print(f"\nProcessing text {i+1}/{len(texts)}")
            metadata = metadatas[i] if metadatas else {}
            chunks = self.split_text(text)
            for j, chunk in enumerate(chunks):
                doc = Document(page_content=chunk, metadata=metadata.copy())
                documents.append(doc)
                print(f"Created document {j+1}/{len(chunks)} for text {i+1}")
        print(f"\nTotal documents created: {len(documents)}")
        return documents

# %%
chunk_size = 600
chunk_overlap = 200
# 1. Khởi tạo splitter
text_splitter = TextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

# 2. Tạo danh sách chứa tất cả các chunks từ nhiều tài liệu
chunked_documents = []
for doc in documents:
    # Lấy tên file từ metadata source
    filename = os.path.basename(doc.metadata['source']) if 'source' in doc.metadata else "unknown"

    # Tạo các chunks với metadata là tên file
    chunks = text_splitter.create_documents(
        texts=[doc.page_content],
        metadatas=[{"source": filename}]
    )
    chunked_documents.extend(chunks)

# 3. Thống kê kết quả
print(f"Số lượng chunks được tạo: {len(chunked_documents)}\n")

# 4. In mẫu một số chunks (tối đa 5 để tránh quá dài)
for i, doc in enumerate(chunked_documents[:5]):
    print("============================")
    print(f"Chunk {i+1}:")
    print(doc.page_content)
    print(f"Metadata: {doc.metadata}")
    print("-" * 80)

# 5. Tính toán độ dài trung bình
lengths = [len(doc.page_content) for doc in chunked_documents]
if lengths:  # Tránh lỗi chia cho 0 nếu không có chunk nào
    avg_length = sum(lengths) / len(lengths)
    print(f"\nĐộ dài trung bình của chunks: {avg_length:.2f} ký tự")
    print(f"Chunk ngắn nhất: {min(lengths)} ký tự")
    print(f"Chunk dài nhất: {max(lengths)} ký tự")
else:
    print("\nKhông có chunks nào được tạo.")
# Out:
# Initialized with chunk_size=600, chunk_overlap=200
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 68
# Created document 1/68 for text 1
# Created document 2/68 for text 1
# Created document 3/68 for text 1
# Created document 4/68 for text 1
# Created document 5/68 for text 1
# Created document 6/68 for text 1
# Created document 7/68 for text 1
# Created document 8/68 for text 1
# Created document 9/68 for text 1
# Created document 10/68 for text 1
# Created document 11/68 for text 1
# Created document 12/68 for text 1
# Created document 13/68 for text 1
# Created document 14/68 for text 1
# Created document 15/68 for text 1
# Created document 16/68 for text 1
# Created document 17/68 for text 1
# Created document 18/68 for text 1
# Created document 19/68 for text 1
# Created document 20/68 for text 1
# Created document 21/68 for text 1
# Created document 22/68 for text 1
# Created document 23/68 for text 1
# Created document 24/68 for text 1
# Created document 25/68 for text 1
# Created document 26/68 for text 1
# Created document 27/68 for text 1
# Created document 28/68 for text 1
# Created document 29/68 for text 1
# Created document 30/68 for text 1
# Created document 31/68 for text 1
# Created document 32/68 for text 1
# Created document 33/68 for text 1
# Created document 34/68 for text 1
# Created document 35/68 for text 1
# Created document 36/68 for text 1
# Created document 37/68 for text 1
# Created document 38/68 for text 1
# Created document 39/68 for text 1
# Created document 40/68 for text 1
# Created document 41/68 for text 1
# Created document 42/68 for text 1
# Created document 43/68 for text 1
# Created document 44/68 for text 1
# Created document 45/68 for text 1
# Created document 46/68 for text 1
# Created document 47/68 for text 1
# Created document 48/68 for text 1
# Created document 49/68 for text 1
# Created document 50/68 for text 1
# Created document 51/68 for text 1
# Created document 52/68 for text 1
# Created document 53/68 for text 1
# Created document 54/68 for text 1
# Created document 55/68 for text 1
# Created document 56/68 for text 1
# Created document 57/68 for text 1
# Created document 58/68 for text 1
# Created document 59/68 for text 1
# Created document 60/68 for text 1
# Created document 61/68 for text 1
# Created document 62/68 for text 1
# Created document 63/68 for text 1
# Created document 64/68 for text 1
# Created document 65/68 for text 1
# Created document 66/68 for text 1
# Created document 67/68 for text 1
# Created document 68/68 for text 1
#
# Total documents created: 68
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 11
# Created document 1/11 for text 1
# Created document 2/11 for text 1
# Created document 3/11 for text 1
# Created document 4/11 for text 1
# Created document 5/11 for text 1
# Created document 6/11 for text 1
# Created document 7/11 for text 1
# Created document 8/11 for text 1
# Created document 9/11 for text 1
# Created document 10/11 for text 1
# Created document 11/11 for text 1
#
# Total documents created: 11
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 109
# Created document 1/109 for text 1
# Created document 2/109 for text 1
# Created document 3/109 for text 1
# Created document 4/109 for text 1
# Created document 5/109 for text 1
# Created document 6/109 for text 1
# Created document 7/109 for text 1
# Created document 8/109 for text 1
# Created document 9/109 for text 1
# Created document 10/109 for text 1
# Created document 11/109 for text 1
# Created document 12/109 for text 1
# Created document 13/109 for text 1
# Created document 14/109 for text 1
# Created document 15/109 for text 1
# Created document 16/109 for text 1
# Created document 17/109 for text 1
# Created document 18/109 for text 1
# Created document 19/109 for text 1
# Created document 20/109 for text 1
# Created document 21/109 for text 1
# Created document 22/109 for text 1
# Created document 23/109 for text 1
# Created document 24/109 for text 1
# Created document 25/109 for text 1
# Created document 26/109 for text 1
# Created document 27/109 for text 1
# Created document 28/109 for text 1
# Created document 29/109 for text 1
# Created document 30/109 for text 1
# Created document 31/109 for text 1
# Created document 32/109 for text 1
# Created document 33/109 for text 1
# Created document 34/109 for text 1
# Created document 35/109 for text 1
# Created document 36/109 for text 1
# Created document 37/109 for text 1
# Created document 38/109 for text 1
# Created document 39/109 for text 1
# Created document 40/109 for text 1
# Created document 41/109 for text 1
# Created document 42/109 for text 1
# Created document 43/109 for text 1
# Created document 44/109 for text 1
# Created document 45/109 for text 1
# Created document 46/109 for text 1
# Created document 47/109 for text 1
# Created document 48/109 for text 1
# Created document 49/109 for text 1
# Created document 50/109 for text 1
# Created document 51/109 for text 1
# Created document 52/109 for text 1
# Created document 53/109 for text 1
# Created document 54/109 for text 1
# Created document 55/109 for text 1
# Created document 56/109 for text 1
# Created document 57/109 for text 1
# Created document 58/109 for text 1
# Created document 59/109 for text 1
# Created document 60/109 for text 1
# Created document 61/109 for text 1
# Created document 62/109 for text 1
# Created document 63/109 for text 1
# Created document 64/109 for text 1
# Created document 65/109 for text 1
# Created document 66/109 for text 1
# Created document 67/109 for text 1
# Created document 68/109 for text 1
# Created document 69/109 for text 1
# Created document 70/109 for text 1
# Created document 71/109 for text 1
# Created document 72/109 for text 1
# Created document 73/109 for text 1
# Created document 74/109 for text 1
# Created document 75/109 for text 1
# Created document 76/109 for text 1
# Created document 77/109 for text 1
# Created document 78/109 for text 1
# Created document 79/109 for text 1
# Created document 80/109 for text 1
# Created document 81/109 for text 1
# Created document 82/109 for text 1
# Created document 83/109 for text 1
# Created document 84/109 for text 1
# Created document 85/109 for text 1
# Created document 86/109 for text 1
# Created document 87/109 for text 1
# Created document 88/109 for text 1
# Created document 89/109 for text 1
# Created document 90/109 for text 1
# Created document 91/109 for text 1
# Created document 92/109 for text 1
# Created document 93/109 for text 1
# Created document 94/109 for text 1
# Created document 95/109 for text 1
# Created document 96/109 for text 1
# Created document 97/109 for text 1
# Created document 98/109 for text 1
# Created document 99/109 for text 1
# Created document 100/109 for text 1
# Created document 101/109 for text 1
# Created document 102/109 for text 1
# Created document 103/109 for text 1
# Created document 104/109 for text 1
# Created document 105/109 for text 1
# Created document 106/109 for text 1
# Created document 107/109 for text 1
# Created document 108/109 for text 1
# Created document 109/109 for text 1
#
# Total documents created: 109
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 29
# Created document 1/29 for text 1
# Created document 2/29 for text 1
# Created document 3/29 for text 1
# Created document 4/29 for text 1
# Created document 5/29 for text 1
# Created document 6/29 for text 1
# Created document 7/29 for text 1
# Created document 8/29 for text 1
# Created document 9/29 for text 1
# Created document 10/29 for text 1
# Created document 11/29 for text 1
# Created document 12/29 for text 1
# Created document 13/29 for text 1
# Created document 14/29 for text 1
# Created document 15/29 for text 1
# Created document 16/29 for text 1
# Created document 17/29 for text 1
# Created document 18/29 for text 1
# Created document 19/29 for text 1
# Created document 20/29 for text 1
# Created document 21/29 for text 1
# Created document 22/29 for text 1
# Created document 23/29 for text 1
# Created document 24/29 for text 1
# Created document 25/29 for text 1
# Created document 26/29 for text 1
# Created document 27/29 for text 1
# Created document 28/29 for text 1
# Created document 29/29 for text 1
#
# Total documents created: 29
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 143
# Created document 1/143 for text 1
# Created document 2/143 for text 1
# Created document 3/143 for text 1
# Created document 4/143 for text 1
# Created document 5/143 for text 1
# Created document 6/143 for text 1
# Created document 7/143 for text 1
# Created document 8/143 for text 1
# Created document 9/143 for text 1
# Created document 10/143 for text 1
# Created document 11/143 for text 1
# Created document 12/143 for text 1
# Created document 13/143 for text 1
# Created document 14/143 for text 1
# Created document 15/143 for text 1
# Created document 16/143 for text 1
# Created document 17/143 for text 1
# Created document 18/143 for text 1
# Created document 19/143 for text 1
# Created document 20/143 for text 1
# Created document 21/143 for text 1
# Created document 22/143 for text 1
# Created document 23/143 for text 1
# Created document 24/143 for text 1
# Created document 25/143 for text 1
# Created document 26/143 for text 1
# Created document 27/143 for text 1
# Created document 28/143 for text 1
# Created document 29/143 for text 1
# Created document 30/143 for text 1
# Created document 31/143 for text 1
# Created document 32/143 for text 1
# Created document 33/143 for text 1
# Created document 34/143 for text 1
# Created document 35/143 for text 1
# Created document 36/143 for text 1
# Created document 37/143 for text 1
# Created document 38/143 for text 1
# Created document 39/143 for text 1
# Created document 40/143 for text 1
# Created document 41/143 for text 1
# Created document 42/143 for text 1
# Created document 43/143 for text 1
# Created document 44/143 for text 1
# Created document 45/143 for text 1
# Created document 46/143 for text 1
# Created document 47/143 for text 1
# Created document 48/143 for text 1
# Created document 49/143 for text 1
# Created document 50/143 for text 1
# Created document 51/143 for text 1
# Created document 52/143 for text 1
# Created document 53/143 for text 1
# Created document 54/143 for text 1
# Created document 55/143 for text 1
# Created document 56/143 for text 1
# Created document 57/143 for text 1
# Created document 58/143 for text 1
# Created document 59/143 for text 1
# Created document 60/143 for text 1
# Created document 61/143 for text 1
# Created document 62/143 for text 1
# Created document 63/143 for text 1
# Created document 64/143 for text 1
# Created document 65/143 for text 1
# Created document 66/143 for text 1
# Created document 67/143 for text 1
# Created document 68/143 for text 1
# Created document 69/143 for text 1
# Created document 70/143 for text 1
# Created document 71/143 for text 1
# Created document 72/143 for text 1
# Created document 73/143 for text 1
# Created document 74/143 for text 1
# Created document 75/143 for text 1
# Created document 76/143 for text 1
# Created document 77/143 for text 1
# Created document 78/143 for text 1
# Created document 79/143 for text 1
# Created document 80/143 for text 1
# Created document 81/143 for text 1
# Created document 82/143 for text 1
# Created document 83/143 for text 1
# Created document 84/143 for text 1
# Created document 85/143 for text 1
# Created document 86/143 for text 1
# Created document 87/143 for text 1
# Created document 88/143 for text 1
# Created document 89/143 for text 1
# Created document 90/143 for text 1
# Created document 91/143 for text 1
# Created document 92/143 for text 1
# Created document 93/143 for text 1
# Created document 94/143 for text 1
# Created document 95/143 for text 1
# Created document 96/143 for text 1
# Created document 97/143 for text 1
# Created document 98/143 for text 1
# Created document 99/143 for text 1
# Created document 100/143 for text 1
# Created document 101/143 for text 1
# Created document 102/143 for text 1
# Created document 103/143 for text 1
# Created document 104/143 for text 1
# Created document 105/143 for text 1
# Created document 106/143 for text 1
# Created document 107/143 for text 1
# Created document 108/143 for text 1
# Created document 109/143 for text 1
# Created document 110/143 for text 1
# Created document 111/143 for text 1
# Created document 112/143 for text 1
# Created document 113/143 for text 1
# Created document 114/143 for text 1
# Created document 115/143 for text 1
# Created document 116/143 for text 1
# Created document 117/143 for text 1
# Created document 118/143 for text 1
# Created document 119/143 for text 1
# Created document 120/143 for text 1
# Created document 121/143 for text 1
# Created document 122/143 for text 1
# Created document 123/143 for text 1
# Created document 124/143 for text 1
# Created document 125/143 for text 1
# Created document 126/143 for text 1
# Created document 127/143 for text 1
# Created document 128/143 for text 1
# Created document 129/143 for text 1
# Created document 130/143 for text 1
# Created document 131/143 for text 1
# Created document 132/143 for text 1
# Created document 133/143 for text 1
# Created document 134/143 for text 1
# Created document 135/143 for text 1
# Created document 136/143 for text 1
# Created document 137/143 for text 1
# Created document 138/143 for text 1
# Created document 139/143 for text 1
# Created document 140/143 for text 1
# Created document 141/143 for text 1
# Created document 142/143 for text 1
# Created document 143/143 for text 1
#
# Total documents created: 143
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 919
# Created document 1/919 for text 1
# Created document 2/919 for text 1
# Created document 3/919 for text 1
# Created document 4/919 for text 1
# Created document 5/919 for text 1
# Created document 6/919 for text 1
# Created document 7/919 for text 1
# Created document 8/919 for text 1
# Created document 9/919 for text 1
# Created document 10/919 for text 1
# Created document 11/919 for text 1
# Created document 12/919 for text 1
# Created document 13/919 for text 1
# Created document 14/919 for text 1
# Created document 15/919 for text 1
# Created document 16/919 for text 1
# Created document 17/919 for text 1
# Created document 18/919 for text 1
# Created document 19/919 for text 1
# Created document 20/919 for text 1
# Created document 21/919 for text 1
# Created document 22/919 for text 1
# Created document 23/919 for text 1
# Created document 24/919 for text 1
# Created document 25/919 for text 1
# Created document 26/919 for text 1
# Created document 27/919 for text 1
# Created document 28/919 for text 1
# Created document 29/919 for text 1
# Created document 30/919 for text 1
# Created document 31/919 for text 1
# Created document 32/919 for text 1
# Created document 33/919 for text 1
# Created document 34/919 for text 1
# Created document 35/919 for text 1
# Created document 36/919 for text 1
# Created document 37/919 for text 1
# Created document 38/919 for text 1
# Created document 39/919 for text 1
# Created document 40/919 for text 1
# Created document 41/919 for text 1
# Created document 42/919 for text 1
# Created document 43/919 for text 1
# Created document 44/919 for text 1
# Created document 45/919 for text 1
# Created document 46/919 for text 1
# Created document 47/919 for text 1
# Created document 48/919 for text 1
# Created document 49/919 for text 1
# Created document 50/919 for text 1
# Created document 51/919 for text 1
# Created document 52/919 for text 1
# Created document 53/919 for text 1
# Created document 54/919 for text 1
# Created document 55/919 for text 1
# Created document 56/919 for text 1
# Created document 57/919 for text 1
# Created document 58/919 for text 1
# Created document 59/919 for text 1
# Created document 60/919 for text 1
# Created document 61/919 for text 1
# Created document 62/919 for text 1
# Created document 63/919 for text 1
# Created document 64/919 for text 1
# Created document 65/919 for text 1
# Created document 66/919 for text 1
# Created document 67/919 for text 1
# Created document 68/919 for text 1
# Created document 69/919 for text 1
# Created document 70/919 for text 1
# Created document 71/919 for text 1
# Created document 72/919 for text 1
# Created document 73/919 for text 1
# Created document 74/919 for text 1
# Created document 75/919 for text 1
# Created document 76/919 for text 1
# Created document 77/919 for text 1
# Created document 78/919 for text 1
# Created document 79/919 for text 1
# Created document 80/919 for text 1
# Created document 81/919 for text 1
# Created document 82/919 for text 1
# Created document 83/919 for text 1
# Created document 84/919 for text 1
# Created document 85/919 for text 1
# Created document 86/919 for text 1
# Created document 87/919 for text 1
# Created document 88/919 for text 1
# Created document 89/919 for text 1
# Created document 90/919 for text 1
# Created document 91/919 for text 1
# Created document 92/919 for text 1
# Created document 93/919 for text 1
# Created document 94/919 for text 1
# Created document 95/919 for text 1
# Created document 96/919 for text 1
# Created document 97/919 for text 1
# Created document 98/919 for text 1
# Created document 99/919 for text 1
# Created document 100/919 for text 1
# Created document 101/919 for text 1
# Created document 102/919 for text 1
# Created document 103/919 for text 1
# Created document 104/919 for text 1
# Created document 105/919 for text 1
# Created document 106/919 for text 1
# Created document 107/919 for text 1
# Created document 108/919 for text 1
# Created document 109/919 for text 1
# Created document 110/919 for text 1
# Created document 111/919 for text 1
# Created document 112/919 for text 1
# Created document 113/919 for text 1
# Created document 114/919 for text 1
# Created document 115/919 for text 1
# Created document 116/919 for text 1
# Created document 117/919 for text 1
# Created document 118/919 for text 1
# Created document 119/919 for text 1
# Created document 120/919 for text 1
# Created document 121/919 for text 1
# Created document 122/919 for text 1
# Created document 123/919 for text 1
# Created document 124/919 for text 1
# Created document 125/919 for text 1
# Created document 126/919 for text 1
# Created document 127/919 for text 1
# Created document 128/919 for text 1
# Created document 129/919 for text 1
# Created document 130/919 for text 1
# Created document 131/919 for text 1
# Created document 132/919 for text 1
# Created document 133/919 for text 1
# Created document 134/919 for text 1
# Created document 135/919 for text 1
# Created document 136/919 for text 1
# Created document 137/919 for text 1
# Created document 138/919 for text 1
# Created document 139/919 for text 1
# Created document 140/919 for text 1
# Created document 141/919 for text 1
# Created document 142/919 for text 1
# Created document 143/919 for text 1
# Created document 144/919 for text 1
# Created document 145/919 for text 1
# Created document 146/919 for text 1
# Created document 147/919 for text 1
# Created document 148/919 for text 1
# Created document 149/919 for text 1
# Created document 150/919 for text 1
# Created document 151/919 for text 1
# Created document 152/919 for text 1
# Created document 153/919 for text 1
# Created document 154/919 for text 1
# Created document 155/919 for text 1
# Created document 156/919 for text 1
# Created document 157/919 for text 1
# Created document 158/919 for text 1
# Created document 159/919 for text 1
# Created document 160/919 for text 1
# Created document 161/919 for text 1
# Created document 162/919 for text 1
# Created document 163/919 for text 1
# Created document 164/919 for text 1
# Created document 165/919 for text 1
# Created document 166/919 for text 1
# Created document 167/919 for text 1
# Created document 168/919 for text 1
# Created document 169/919 for text 1
# Created document 170/919 for text 1
# Created document 171/919 for text 1
# Created document 172/919 for text 1
# Created document 173/919 for text 1
# Created document 174/919 for text 1
# Created document 175/919 for text 1
# Created document 176/919 for text 1
# Created document 177/919 for text 1
# Created document 178/919 for text 1
# Created document 179/919 for text 1
# Created document 180/919 for text 1
# Created document 181/919 for text 1
# Created document 182/919 for text 1
# Created document 183/919 for text 1
# Created document 184/919 for text 1
# Created document 185/919 for text 1
# Created document 186/919 for text 1
# Created document 187/919 for text 1
# Created document 188/919 for text 1
# Created document 189/919 for text 1
# Created document 190/919 for text 1
# Created document 191/919 for text 1
# Created document 192/919 for text 1
# Created document 193/919 for text 1
# Created document 194/919 for text 1
# Created document 195/919 for text 1
# Created document 196/919 for text 1
# Created document 197/919 for text 1
# Created document 198/919 for text 1
# Created document 199/919 for text 1
# Created document 200/919 for text 1
# Created document 201/919 for text 1
# Created document 202/919 for text 1
# Created document 203/919 for text 1
# Created document 204/919 for text 1
# Created document 205/919 for text 1
# Created document 206/919 for text 1
# Created document 207/919 for text 1
# Created document 208/919 for text 1
# Created document 209/919 for text 1
# Created document 210/919 for text 1
# Created document 211/919 for text 1
# Created document 212/919 for text 1
# Created document 213/919 for text 1
# Created document 214/919 for text 1
# Created document 215/919 for text 1
# Created document 216/919 for text 1
# Created document 217/919 for text 1
# Created document 218/919 for text 1
# Created document 219/919 for text 1
# Created document 220/919 for text 1
# Created document 221/919 for text 1
# Created document 222/919 for text 1
# Created document 223/919 for text 1
# Created document 224/919 for text 1
# Created document 225/919 for text 1
# Created document 226/919 for text 1
# Created document 227/919 for text 1
# Created document 228/919 for text 1
# Created document 229/919 for text 1
# Created document 230/919 for text 1
# Created document 231/919 for text 1
# Created document 232/919 for text 1
# Created document 233/919 for text 1
# Created document 234/919 for text 1
# Created document 235/919 for text 1
# Created document 236/919 for text 1
# Created document 237/919 for text 1
# Created document 238/919 for text 1
# Created document 239/919 for text 1
# Created document 240/919 for text 1
# Created document 241/919 for text 1
# Created document 242/919 for text 1
# Created document 243/919 for text 1
# Created document 244/919 for text 1
# Created document 245/919 for text 1
# Created document 246/919 for text 1
# Created document 247/919 for text 1
# Created document 248/919 for text 1
# Created document 249/919 for text 1
# Created document 250/919 for text 1
# Created document 251/919 for text 1
# Created document 252/919 for text 1
# Created document 253/919 for text 1
# Created document 254/919 for text 1
# Created document 255/919 for text 1
# Created document 256/919 for text 1
# Created document 257/919 for text 1
# Created document 258/919 for text 1
# Created document 259/919 for text 1
# Created document 260/919 for text 1
# Created document 261/919 for text 1
# Created document 262/919 for text 1
# Created document 263/919 for text 1
# Created document 264/919 for text 1
# Created document 265/919 for text 1
# Created document 266/919 for text 1
# Created document 267/919 for text 1
# Created document 268/919 for text 1
# Created document 269/919 for text 1
# Created document 270/919 for text 1
# Created document 271/919 for text 1
# Created document 272/919 for text 1
# Created document 273/919 for text 1
# Created document 274/919 for text 1
# Created document 275/919 for text 1
# Created document 276/919 for text 1
# Created document 277/919 for text 1
# Created document 278/919 for text 1
# Created document 279/919 for text 1
# Created document 280/919 for text 1
# Created document 281/919 for text 1
# Created document 282/919 for text 1
# Created document 283/919 for text 1
# Created document 284/919 for text 1
# Created document 285/919 for text 1
# Created document 286/919 for text 1
# Created document 287/919 for text 1
# Created document 288/919 for text 1
# Created document 289/919 for text 1
# Created document 290/919 for text 1
# Created document 291/919 for text 1
# Created document 292/919 for text 1
# Created document 293/919 for text 1
# Created document 294/919 for text 1
# Created document 295/919 for text 1
# Created document 296/919 for text 1
# Created document 297/919 for text 1
# Created document 298/919 for text 1
# Created document 299/919 for text 1
# Created document 300/919 for text 1
# Created document 301/919 for text 1
# Created document 302/919 for text 1
# Created document 303/919 for text 1
# Created document 304/919 for text 1
# Created document 305/919 for text 1
# Created document 306/919 for text 1
# Created document 307/919 for text 1
# Created document 308/919 for text 1
# Created document 309/919 for text 1
# Created document 310/919 for text 1
# Created document 311/919 for text 1
# Created document 312/919 for text 1
# Created document 313/919 for text 1
# Created document 314/919 for text 1
# Created document 315/919 for text 1
# Created document 316/919 for text 1
# Created document 317/919 for text 1
# Created document 318/919 for text 1
# Created document 319/919 for text 1
# Created document 320/919 for text 1
# Created document 321/919 for text 1
# Created document 322/919 for text 1
# Created document 323/919 for text 1
# Created document 324/919 for text 1
# Created document 325/919 for text 1
# Created document 326/919 for text 1
# Created document 327/919 for text 1
# Created document 328/919 for text 1
# Created document 329/919 for text 1
# Created document 330/919 for text 1
# Created document 331/919 for text 1
# Created document 332/919 for text 1
# Created document 333/919 for text 1
# Created document 334/919 for text 1
# Created document 335/919 for text 1
# Created document 336/919 for text 1
# Created document 337/919 for text 1
# Created document 338/919 for text 1
# Created document 339/919 for text 1
# Created document 340/919 for text 1
# Created document 341/919 for text 1
# Created document 342/919 for text 1
# Created document 343/919 for text 1
# Created document 344/919 for text 1
# Created document 345/919 for text 1
# Created document 346/919 for text 1
# Created document 347/919 for text 1
# Created document 348/919 for text 1
# Created document 349/919 for text 1
# Created document 350/919 for text 1
# Created document 351/919 for text 1
# Created document 352/919 for text 1
# Created document 353/919 for text 1
# Created document 354/919 for text 1
# Created document 355/919 for text 1
# Created document 356/919 for text 1
# Created document 357/919 for text 1
# Created document 358/919 for text 1
# Created document 359/919 for text 1
# Created document 360/919 for text 1
# Created document 361/919 for text 1
# Created document 362/919 for text 1
# Created document 363/919 for text 1
# Created document 364/919 for text 1
# Created document 365/919 for text 1
# Created document 366/919 for text 1
# Created document 367/919 for text 1
# Created document 368/919 for text 1
# Created document 369/919 for text 1
# Created document 370/919 for text 1
# Created document 371/919 for text 1
# Created document 372/919 for text 1
# Created document 373/919 for text 1
# Created document 374/919 for text 1
# Created document 375/919 for text 1
# Created document 376/919 for text 1
# Created document 377/919 for text 1
# Created document 378/919 for text 1
# Created document 379/919 for text 1
# Created document 380/919 for text 1
# Created document 381/919 for text 1
# Created document 382/919 for text 1
# Created document 383/919 for text 1
# Created document 384/919 for text 1
# Created document 385/919 for text 1
# Created document 386/919 for text 1
# Created document 387/919 for text 1
# Created document 388/919 for text 1
# Created document 389/919 for text 1
# Created document 390/919 for text 1
# Created document 391/919 for text 1
# Created document 392/919 for text 1
# Created document 393/919 for text 1
# Created document 394/919 for text 1
# Created document 395/919 for text 1
# Created document 396/919 for text 1
# Created document 397/919 for text 1
# Created document 398/919 for text 1
# Created document 399/919 for text 1
# Created document 400/919 for text 1
# Created document 401/919 for text 1
# Created document 402/919 for text 1
# Created document 403/919 for text 1
# Created document 404/919 for text 1
# Created document 405/919 for text 1
# Created document 406/919 for text 1
# Created document 407/919 for text 1
# Created document 408/919 for text 1
# Created document 409/919 for text 1
# Created document 410/919 for text 1
# Created document 411/919 for text 1
# Created document 412/919 for text 1
# Created document 413/919 for text 1
# Created document 414/919 for text 1
# Created document 415/919 for text 1
# Created document 416/919 for text 1
# Created document 417/919 for text 1
# Created document 418/919 for text 1
# Created document 419/919 for text 1
# Created document 420/919 for text 1
# Created document 421/919 for text 1
# Created document 422/919 for text 1
# Created document 423/919 for text 1
# Created document 424/919 for text 1
# Created document 425/919 for text 1
# Created document 426/919 for text 1
# Created document 427/919 for text 1
# Created document 428/919 for text 1
# Created document 429/919 for text 1
# Created document 430/919 for text 1
# Created document 431/919 for text 1
# Created document 432/919 for text 1
# Created document 433/919 for text 1
# Created document 434/919 for text 1
# Created document 435/919 for text 1
# Created document 436/919 for text 1
# Created document 437/919 for text 1
# Created document 438/919 for text 1
# Created document 439/919 for text 1
# Created document 440/919 for text 1
# Created document 441/919 for text 1
# Created document 442/919 for text 1
# Created document 443/919 for text 1
# Created document 444/919 for text 1
# Created document 445/919 for text 1
# Created document 446/919 for text 1
# Created document 447/919 for text 1
# Created document 448/919 for text 1
# Created document 449/919 for text 1
# Created document 450/919 for text 1
# Created document 451/919 for text 1
# Created document 452/919 for text 1
# Created document 453/919 for text 1
# Created document 454/919 for text 1
# Created document 455/919 for text 1
# Created document 456/919 for text 1
# Created document 457/919 for text 1
# Created document 458/919 for text 1
# Created document 459/919 for text 1
# Created document 460/919 for text 1
# Created document 461/919 for text 1
# Created document 462/919 for text 1
# Created document 463/919 for text 1
# Created document 464/919 for text 1
# Created document 465/919 for text 1
# Created document 466/919 for text 1
# Created document 467/919 for text 1
# Created document 468/919 for text 1
# Created document 469/919 for text 1
# Created document 470/919 for text 1
# Created document 471/919 for text 1
# Created document 472/919 for text 1
# Created document 473/919 for text 1
# Created document 474/919 for text 1
# Created document 475/919 for text 1
# Created document 476/919 for text 1
# Created document 477/919 for text 1
# Created document 478/919 for text 1
# Created document 479/919 for text 1
# Created document 480/919 for text 1
# Created document 481/919 for text 1
# Created document 482/919 for text 1
# Created document 483/919 for text 1
# Created document 484/919 for text 1
# Created document 485/919 for text 1
# Created document 486/919 for text 1
# Created document 487/919 for text 1
# Created document 488/919 for text 1
# Created document 489/919 for text 1
# Created document 490/919 for text 1
# Created document 491/919 for text 1
# Created document 492/919 for text 1
# Created document 493/919 for text 1
# Created document 494/919 for text 1
# Created document 495/919 for text 1
# Created document 496/919 for text 1
# Created document 497/919 for text 1
# Created document 498/919 for text 1
# Created document 499/919 for text 1
# Created document 500/919 for text 1
# Created document 501/919 for text 1
# Created document 502/919 for text 1
# Created document 503/919 for text 1
# Created document 504/919 for text 1
# Created document 505/919 for text 1
# Created document 506/919 for text 1
# Created document 507/919 for text 1
# Created document 508/919 for text 1
# Created document 509/919 for text 1
# Created document 510/919 for text 1
# Created document 511/919 for text 1
# Created document 512/919 for text 1
# Created document 513/919 for text 1
# Created document 514/919 for text 1
# Created document 515/919 for text 1
# Created document 516/919 for text 1
# Created document 517/919 for text 1
# Created document 518/919 for text 1
# Created document 519/919 for text 1
# Created document 520/919 for text 1
# Created document 521/919 for text 1
# Created document 522/919 for text 1
# Created document 523/919 for text 1
# Created document 524/919 for text 1
# Created document 525/919 for text 1
# Created document 526/919 for text 1
# Created document 527/919 for text 1
# Created document 528/919 for text 1
# Created document 529/919 for text 1
# Created document 530/919 for text 1
# Created document 531/919 for text 1
# Created document 532/919 for text 1
# Created document 533/919 for text 1
# Created document 534/919 for text 1
# Created document 535/919 for text 1
# Created document 536/919 for text 1
# Created document 537/919 for text 1
# Created document 538/919 for text 1
# Created document 539/919 for text 1
# Created document 540/919 for text 1
# Created document 541/919 for text 1
# Created document 542/919 for text 1
# Created document 543/919 for text 1
# Created document 544/919 for text 1
# Created document 545/919 for text 1
# Created document 546/919 for text 1
# Created document 547/919 for text 1
# Created document 548/919 for text 1
# Created document 549/919 for text 1
# Created document 550/919 for text 1
# Created document 551/919 for text 1
# Created document 552/919 for text 1
# Created document 553/919 for text 1
# Created document 554/919 for text 1
# Created document 555/919 for text 1
# Created document 556/919 for text 1
# Created document 557/919 for text 1
# Created document 558/919 for text 1
# Created document 559/919 for text 1
# Created document 560/919 for text 1
# Created document 561/919 for text 1
# Created document 562/919 for text 1
# Created document 563/919 for text 1
# Created document 564/919 for text 1
# Created document 565/919 for text 1
# Created document 566/919 for text 1
# Created document 567/919 for text 1
# Created document 568/919 for text 1
# Created document 569/919 for text 1
# Created document 570/919 for text 1
# Created document 571/919 for text 1
# Created document 572/919 for text 1
# Created document 573/919 for text 1
# Created document 574/919 for text 1
# Created document 575/919 for text 1
# Created document 576/919 for text 1
# Created document 577/919 for text 1
# Created document 578/919 for text 1
# Created document 579/919 for text 1
# Created document 580/919 for text 1
# Created document 581/919 for text 1
# Created document 582/919 for text 1
# Created document 583/919 for text 1
# Created document 584/919 for text 1
# Created document 585/919 for text 1
# Created document 586/919 for text 1
# Created document 587/919 for text 1
# Created document 588/919 for text 1
# Created document 589/919 for text 1
# Created document 590/919 for text 1
# Created document 591/919 for text 1
# Created document 592/919 for text 1
# Created document 593/919 for text 1
# Created document 594/919 for text 1
# Created document 595/919 for text 1
# Created document 596/919 for text 1
# Created document 597/919 for text 1
# Created document 598/919 for text 1
# Created document 599/919 for text 1
# Created document 600/919 for text 1
# Created document 601/919 for text 1
# Created document 602/919 for text 1
# Created document 603/919 for text 1
# Created document 604/919 for text 1
# Created document 605/919 for text 1
# Created document 606/919 for text 1
# Created document 607/919 for text 1
# Created document 608/919 for text 1
# Created document 609/919 for text 1
# Created document 610/919 for text 1
# Created document 611/919 for text 1
# Created document 612/919 for text 1
# Created document 613/919 for text 1
# Created document 614/919 for text 1
# Created document 615/919 for text 1
# Created document 616/919 for text 1
# Created document 617/919 for text 1
# Created document 618/919 for text 1
# Created document 619/919 for text 1
# Created document 620/919 for text 1
# Created document 621/919 for text 1
# Created document 622/919 for text 1
# Created document 623/919 for text 1
# Created document 624/919 for text 1
# Created document 625/919 for text 1
# Created document 626/919 for text 1
# Created document 627/919 for text 1
# Created document 628/919 for text 1
# Created document 629/919 for text 1
# Created document 630/919 for text 1
# Created document 631/919 for text 1
# Created document 632/919 for text 1
# Created document 633/919 for text 1
# Created document 634/919 for text 1
# Created document 635/919 for text 1
# Created document 636/919 for text 1
# Created document 637/919 for text 1
# Created document 638/919 for text 1
# Created document 639/919 for text 1
# Created document 640/919 for text 1
# Created document 641/919 for text 1
# Created document 642/919 for text 1
# Created document 643/919 for text 1
# Created document 644/919 for text 1
# Created document 645/919 for text 1
# Created document 646/919 for text 1
# Created document 647/919 for text 1
# Created document 648/919 for text 1
# Created document 649/919 for text 1
# Created document 650/919 for text 1
# Created document 651/919 for text 1
# Created document 652/919 for text 1
# Created document 653/919 for text 1
# Created document 654/919 for text 1
# Created document 655/919 for text 1
# Created document 656/919 for text 1
# Created document 657/919 for text 1
# Created document 658/919 for text 1
# Created document 659/919 for text 1
# Created document 660/919 for text 1
# Created document 661/919 for text 1
# Created document 662/919 for text 1
# Created document 663/919 for text 1
# Created document 664/919 for text 1
# Created document 665/919 for text 1
# Created document 666/919 for text 1
# Created document 667/919 for text 1
# Created document 668/919 for text 1
# Created document 669/919 for text 1
# Created document 670/919 for text 1
# Created document 671/919 for text 1
# Created document 672/919 for text 1
# Created document 673/919 for text 1
# Created document 674/919 for text 1
# Created document 675/919 for text 1
# Created document 676/919 for text 1
# Created document 677/919 for text 1
# Created document 678/919 for text 1
# Created document 679/919 for text 1
# Created document 680/919 for text 1
# Created document 681/919 for text 1
# Created document 682/919 for text 1
# Created document 683/919 for text 1
# Created document 684/919 for text 1
# Created document 685/919 for text 1
# Created document 686/919 for text 1
# Created document 687/919 for text 1
# Created document 688/919 for text 1
# Created document 689/919 for text 1
# Created document 690/919 for text 1
# Created document 691/919 for text 1
# Created document 692/919 for text 1
# Created document 693/919 for text 1
# Created document 694/919 for text 1
# Created document 695/919 for text 1
# Created document 696/919 for text 1
# Created document 697/919 for text 1
# Created document 698/919 for text 1
# Created document 699/919 for text 1
# Created document 700/919 for text 1
# Created document 701/919 for text 1
# Created document 702/919 for text 1
# Created document 703/919 for text 1
# Created document 704/919 for text 1
# Created document 705/919 for text 1
# Created document 706/919 for text 1
# Created document 707/919 for text 1
# Created document 708/919 for text 1
# Created document 709/919 for text 1
# Created document 710/919 for text 1
# Created document 711/919 for text 1
# Created document 712/919 for text 1
# Created document 713/919 for text 1
# Created document 714/919 for text 1
# Created document 715/919 for text 1
# Created document 716/919 for text 1
# Created document 717/919 for text 1
# Created document 718/919 for text 1
# Created document 719/919 for text 1
# Created document 720/919 for text 1
# Created document 721/919 for text 1
# Created document 722/919 for text 1
# Created document 723/919 for text 1
# Created document 724/919 for text 1
# Created document 725/919 for text 1
# Created document 726/919 for text 1
# Created document 727/919 for text 1
# Created document 728/919 for text 1
# Created document 729/919 for text 1
# Created document 730/919 for text 1
# Created document 731/919 for text 1
# Created document 732/919 for text 1
# Created document 733/919 for text 1
# Created document 734/919 for text 1
# Created document 735/919 for text 1
# Created document 736/919 for text 1
# Created document 737/919 for text 1
# Created document 738/919 for text 1
# Created document 739/919 for text 1
# Created document 740/919 for text 1
# Created document 741/919 for text 1
# Created document 742/919 for text 1
# Created document 743/919 for text 1
# Created document 744/919 for text 1
# Created document 745/919 for text 1
# Created document 746/919 for text 1
# Created document 747/919 for text 1
# Created document 748/919 for text 1
# Created document 749/919 for text 1
# Created document 750/919 for text 1
# Created document 751/919 for text 1
# Created document 752/919 for text 1
# Created document 753/919 for text 1
# Created document 754/919 for text 1
# Created document 755/919 for text 1
# Created document 756/919 for text 1
# Created document 757/919 for text 1
# Created document 758/919 for text 1
# Created document 759/919 for text 1
# Created document 760/919 for text 1
# Created document 761/919 for text 1
# Created document 762/919 for text 1
# Created document 763/919 for text 1
# Created document 764/919 for text 1
# Created document 765/919 for text 1
# Created document 766/919 for text 1
# Created document 767/919 for text 1
# Created document 768/919 for text 1
# Created document 769/919 for text 1
# Created document 770/919 for text 1
# Created document 771/919 for text 1
# Created document 772/919 for text 1
# Created document 773/919 for text 1
# Created document 774/919 for text 1
# Created document 775/919 for text 1
# Created document 776/919 for text 1
# Created document 777/919 for text 1
# Created document 778/919 for text 1
# Created document 779/919 for text 1
# Created document 780/919 for text 1
# Created document 781/919 for text 1
# Created document 782/919 for text 1
# Created document 783/919 for text 1
# Created document 784/919 for text 1
# Created document 785/919 for text 1
# Created document 786/919 for text 1
# Created document 787/919 for text 1
# Created document 788/919 for text 1
# Created document 789/919 for text 1
# Created document 790/919 for text 1
# Created document 791/919 for text 1
# Created document 792/919 for text 1
# Created document 793/919 for text 1
# Created document 794/919 for text 1
# Created document 795/919 for text 1
# Created document 796/919 for text 1
# Created document 797/919 for text 1
# Created document 798/919 for text 1
# Created document 799/919 for text 1
# Created document 800/919 for text 1
# Created document 801/919 for text 1
# Created document 802/919 for text 1
# Created document 803/919 for text 1
# Created document 804/919 for text 1
# Created document 805/919 for text 1
# Created document 806/919 for text 1
# Created document 807/919 for text 1
# Created document 808/919 for text 1
# Created document 809/919 for text 1
# Created document 810/919 for text 1
# Created document 811/919 for text 1
# Created document 812/919 for text 1
# Created document 813/919 for text 1
# Created document 814/919 for text 1
# Created document 815/919 for text 1
# Created document 816/919 for text 1
# Created document 817/919 for text 1
# Created document 818/919 for text 1
# Created document 819/919 for text 1
# Created document 820/919 for text 1
# Created document 821/919 for text 1
# Created document 822/919 for text 1
# Created document 823/919 for text 1
# Created document 824/919 for text 1
# Created document 825/919 for text 1
# Created document 826/919 for text 1
# Created document 827/919 for text 1
# Created document 828/919 for text 1
# Created document 829/919 for text 1
# Created document 830/919 for text 1
# Created document 831/919 for text 1
# Created document 832/919 for text 1
# Created document 833/919 for text 1
# Created document 834/919 for text 1
# Created document 835/919 for text 1
# Created document 836/919 for text 1
# Created document 837/919 for text 1
# Created document 838/919 for text 1
# Created document 839/919 for text 1
# Created document 840/919 for text 1
# Created document 841/919 for text 1
# Created document 842/919 for text 1
# Created document 843/919 for text 1
# Created document 844/919 for text 1
# Created document 845/919 for text 1
# Created document 846/919 for text 1
# Created document 847/919 for text 1
# Created document 848/919 for text 1
# Created document 849/919 for text 1
# Created document 850/919 for text 1
# Created document 851/919 for text 1
# Created document 852/919 for text 1
# Created document 853/919 for text 1
# Created document 854/919 for text 1
# Created document 855/919 for text 1
# Created document 856/919 for text 1
# Created document 857/919 for text 1
# Created document 858/919 for text 1
# Created document 859/919 for text 1
# Created document 860/919 for text 1
# Created document 861/919 for text 1
# Created document 862/919 for text 1
# Created document 863/919 for text 1
# Created document 864/919 for text 1
# Created document 865/919 for text 1
# Created document 866/919 for text 1
# Created document 867/919 for text 1
# Created document 868/919 for text 1
# Created document 869/919 for text 1
# Created document 870/919 for text 1
# Created document 871/919 for text 1
# Created document 872/919 for text 1
# Created document 873/919 for text 1
# Created document 874/919 for text 1
# Created document 875/919 for text 1
# Created document 876/919 for text 1
# Created document 877/919 for text 1
# Created document 878/919 for text 1
# Created document 879/919 for text 1
# Created document 880/919 for text 1
# Created document 881/919 for text 1
# Created document 882/919 for text 1
# Created document 883/919 for text 1
# Created document 884/919 for text 1
# Created document 885/919 for text 1
# Created document 886/919 for text 1
# Created document 887/919 for text 1
# Created document 888/919 for text 1
# Created document 889/919 for text 1
# Created document 890/919 for text 1
# Created document 891/919 for text 1
# Created document 892/919 for text 1
# Created document 893/919 for text 1
# Created document 894/919 for text 1
# Created document 895/919 for text 1
# Created document 896/919 for text 1
# Created document 897/919 for text 1
# Created document 898/919 for text 1
# Created document 899/919 for text 1
# Created document 900/919 for text 1
# Created document 901/919 for text 1
# Created document 902/919 for text 1
# Created document 903/919 for text 1
# Created document 904/919 for text 1
# Created document 905/919 for text 1
# Created document 906/919 for text 1
# Created document 907/919 for text 1
# Created document 908/919 for text 1
# Created document 909/919 for text 1
# Created document 910/919 for text 1
# Created document 911/919 for text 1
# Created document 912/919 for text 1
# Created document 913/919 for text 1
# Created document 914/919 for text 1
# Created document 915/919 for text 1
# Created document 916/919 for text 1
# Created document 917/919 for text 1
# Created document 918/919 for text 1
# Created document 919/919 for text 1
#
# Total documents created: 919
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 101
# Created document 1/101 for text 1
# Created document 2/101 for text 1
# Created document 3/101 for text 1
# Created document 4/101 for text 1
# Created document 5/101 for text 1
# Created document 6/101 for text 1
# Created document 7/101 for text 1
# Created document 8/101 for text 1
# Created document 9/101 for text 1
# Created document 10/101 for text 1
# Created document 11/101 for text 1
# Created document 12/101 for text 1
# Created document 13/101 for text 1
# Created document 14/101 for text 1
# Created document 15/101 for text 1
# Created document 16/101 for text 1
# Created document 17/101 for text 1
# Created document 18/101 for text 1
# Created document 19/101 for text 1
# Created document 20/101 for text 1
# Created document 21/101 for text 1
# Created document 22/101 for text 1
# Created document 23/101 for text 1
# Created document 24/101 for text 1
# Created document 25/101 for text 1
# Created document 26/101 for text 1
# Created document 27/101 for text 1
# Created document 28/101 for text 1
# Created document 29/101 for text 1
# Created document 30/101 for text 1
# Created document 31/101 for text 1
# Created document 32/101 for text 1
# Created document 33/101 for text 1
# Created document 34/101 for text 1
# Created document 35/101 for text 1
# Created document 36/101 for text 1
# Created document 37/101 for text 1
# Created document 38/101 for text 1
# Created document 39/101 for text 1
# Created document 40/101 for text 1
# Created document 41/101 for text 1
# Created document 42/101 for text 1
# Created document 43/101 for text 1
# Created document 44/101 for text 1
# Created document 45/101 for text 1
# Created document 46/101 for text 1
# Created document 47/101 for text 1
# Created document 48/101 for text 1
# Created document 49/101 for text 1
# Created document 50/101 for text 1
# Created document 51/101 for text 1
# Created document 52/101 for text 1
# Created document 53/101 for text 1
# Created document 54/101 for text 1
# Created document 55/101 for text 1
# Created document 56/101 for text 1
# Created document 57/101 for text 1
# Created document 58/101 for text 1
# Created document 59/101 for text 1
# Created document 60/101 for text 1
# Created document 61/101 for text 1
# Created document 62/101 for text 1
# Created document 63/101 for text 1
# Created document 64/101 for text 1
# Created document 65/101 for text 1
# Created document 66/101 for text 1
# Created document 67/101 for text 1
# Created document 68/101 for text 1
# Created document 69/101 for text 1
# Created document 70/101 for text 1
# Created document 71/101 for text 1
# Created document 72/101 for text 1
# Created document 73/101 for text 1
# Created document 74/101 for text 1
# Created document 75/101 for text 1
# Created document 76/101 for text 1
# Created document 77/101 for text 1
# Created document 78/101 for text 1
# Created document 79/101 for text 1
# Created document 80/101 for text 1
# Created document 81/101 for text 1
# Created document 82/101 for text 1
# Created document 83/101 for text 1
# Created document 84/101 for text 1
# Created document 85/101 for text 1
# Created document 86/101 for text 1
# Created document 87/101 for text 1
# Created document 88/101 for text 1
# Created document 89/101 for text 1
# Created document 90/101 for text 1
# Created document 91/101 for text 1
# Created document 92/101 for text 1
# Created document 93/101 for text 1
# Created document 94/101 for text 1
# Created document 95/101 for text 1
# Created document 96/101 for text 1
# Created document 97/101 for text 1
# Created document 98/101 for text 1
# Created document 99/101 for text 1
# Created document 100/101 for text 1
# Created document 101/101 for text 1
#
# Total documents created: 101
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 19
# Created document 1/19 for text 1
# Created document 2/19 for text 1
# Created document 3/19 for text 1
# Created document 4/19 for text 1
# Created document 5/19 for text 1
# Created document 6/19 for text 1
# Created document 7/19 for text 1
# Created document 8/19 for text 1
# Created document 9/19 for text 1
# Created document 10/19 for text 1
# Created document 11/19 for text 1
# Created document 12/19 for text 1
# Created document 13/19 for text 1
# Created document 14/19 for text 1
# Created document 15/19 for text 1
# Created document 16/19 for text 1
# Created document 17/19 for text 1
# Created document 18/19 for text 1
# Created document 19/19 for text 1
#
# Total documents created: 19
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 72
# Created document 1/72 for text 1
# Created document 2/72 for text 1
# Created document 3/72 for text 1
# Created document 4/72 for text 1
# Created document 5/72 for text 1
# Created document 6/72 for text 1
# Created document 7/72 for text 1
# Created document 8/72 for text 1
# Created document 9/72 for text 1
# Created document 10/72 for text 1
# Created document 11/72 for text 1
# Created document 12/72 for text 1
# Created document 13/72 for text 1
# Created document 14/72 for text 1
# Created document 15/72 for text 1
# Created document 16/72 for text 1
# Created document 17/72 for text 1
# Created document 18/72 for text 1
# Created document 19/72 for text 1
# Created document 20/72 for text 1
# Created document 21/72 for text 1
# Created document 22/72 for text 1
# Created document 23/72 for text 1
# Created document 24/72 for text 1
# Created document 25/72 for text 1
# Created document 26/72 for text 1
# Created document 27/72 for text 1
# Created document 28/72 for text 1
# Created document 29/72 for text 1
# Created document 30/72 for text 1
# Created document 31/72 for text 1
# Created document 32/72 for text 1
# Created document 33/72 for text 1
# Created document 34/72 for text 1
# Created document 35/72 for text 1
# Created document 36/72 for text 1
# Created document 37/72 for text 1
# Created document 38/72 for text 1
# Created document 39/72 for text 1
# Created document 40/72 for text 1
# Created document 41/72 for text 1
# Created document 42/72 for text 1
# Created document 43/72 for text 1
# Created document 44/72 for text 1
# Created document 45/72 for text 1
# Created document 46/72 for text 1
# Created document 47/72 for text 1
# Created document 48/72 for text 1
# Created document 49/72 for text 1
# Created document 50/72 for text 1
# Created document 51/72 for text 1
# Created document 52/72 for text 1
# Created document 53/72 for text 1
# Created document 54/72 for text 1
# Created document 55/72 for text 1
# Created document 56/72 for text 1
# Created document 57/72 for text 1
# Created document 58/72 for text 1
# Created document 59/72 for text 1
# Created document 60/72 for text 1
# Created document 61/72 for text 1
# Created document 62/72 for text 1
# Created document 63/72 for text 1
# Created document 64/72 for text 1
# Created document 65/72 for text 1
# Created document 66/72 for text 1
# Created document 67/72 for text 1
# Created document 68/72 for text 1
# Created document 69/72 for text 1
# Created document 70/72 for text 1
# Created document 71/72 for text 1
# Created document 72/72 for text 1
#
# Total documents created: 72
#
# Starting create_documents...
#
# Processing text 1/1
#
# Starting split_text...
#
# Total chunks created: 68
# Created document 1/68 for text 1
# Created document 2/68 for text 1
# Created document 3/68 for text 1
# Created document 4/68 for text 1
# Created document 5/68 for text 1
# Created document 6/68 for text 1
# Created document 7/68 for text 1
# Created document 8/68 for text 1
# Created document 9/68 for text 1
# Created document 10/68 for text 1
# Created document 11/68 for text 1
# Created document 12/68 for text 1
# Created document 13/68 for text 1
# Created document 14/68 for text 1
# Created document 15/68 for text 1
# Created document 16/68 for text 1
# Created document 17/68 for text 1
# Created document 18/68 for text 1
# Created document 19/68 for text 1
# Created document 20/68 for text 1
# Created document 21/68 for text 1
# Created document 22/68 for text 1
# Created document 23/68 for text 1
# Created document 24/68 for text 1
# Created document 25/68 for text 1
# Created document 26/68 for text 1
# Created document 27/68 for text 1
# Created document 28/68 for text 1
# Created document 29/68 for text 1
# Created document 30/68 for text 1
# Created document 31/68 for text 1
# Created document 32/68 for text 1
# Created document 33/68 for text 1
# Created document 34/68 for text 1
# Created document 35/68 for text 1
# Created document 36/68 for text 1
# Created document 37/68 for text 1
# Created document 38/68 for text 1
# Created document 39/68 for text 1
# Created document 40/68 for text 1
# Created document 41/68 for text 1
# Created document 42/68 for text 1
# Created document 43/68 for text 1
# Created document 44/68 for text 1
# Created document 45/68 for text 1
# Created document 46/68 for text 1
# Created document 47/68 for text 1
# Created document 48/68 for text 1
# Created document 49/68 for text 1
# Created document 50/68 for text 1
# Created document 51/68 for text 1
# Created document 52/68 for text 1
# Created document 53/68 for text 1
# Created document 54/68 for text 1
# Created document 55/68 for text 1
# Created document 56/68 for text 1
# Created document 57/68 for text 1
# Created document 58/68 for text 1
# Created document 59/68 for text 1
# Created document 60/68 for text 1
# Created document 61/68 for text 1
# Created document 62/68 for text 1
# Created document 63/68 for text 1
# Created document 64/68 for text 1
# Created document 65/68 for text 1
# Created document 66/68 for text 1
# Created document 67/68 for text 1
# Created document 68/68 for text 1
#
# Total documents created: 68
# Số lượng chunks được tạo: 1539
#
# ============================
# Chunk 1:
# Ngành Trí tuệ nhân tạo
# Chương trình: Đại học Chính quy
# Khóa tuyển: 2023
# (Ban hành kèm theo Quyết định số 1712/QĐ - KHTN ngày 07/9/2023
# của Hiệu trưởng Trường Đại học Khoa học Tự nhiên, ĐHQG-HCM)
#
# 1. Thông tin chung về chương trình đào tạo
# 1.1. Tên ngành:
# - Tiếng Việt: Trí tuệ nhân tạo
# - Tiếng Anh: Artificial Intelligence
# 1.2. Mã ngành: 7480107
# 1.3. Trình độ đào tạo : Đại học
# 1.4. Tên chương trình : Cử nhân Trí tuệ nhân tạo
# 1.5. Loại hình đào tạo : Chính quy
# 1.6. Thời gian đào tạo : 4 năm
# 1.7. Tên văn bằng sau khi tốt nghiệp:
# - Tiếng Việt : Cử nhân Trí tuệ nhân tạo
# Metadata: {'source': 'TTNT.txt'}
# --------------------------------------------------------------------------------
# ============================
# Chunk 2:
# 1.4. Tên chương trình : Cử nhân Trí tuệ nhân tạo
# 1.5. Loại hình đào tạo : Chính quy
# 1.6. Thời gian đào tạo : 4 năm
# 1.7. Tên văn bằng sau khi tốt nghiệp:
# - Tiếng Việt : Cử nhân Trí tuệ nhân tạo
# - Tiếng Anh Bachelor of Science in Artificial Intelligence
# 1.8. Ngôn ngữ giảng dạy tiếng Việt
# 1.9. Nơi đào tạo:
# - Cơ sở 1: 227 Nguyễn Văn Cừ, P4, Q5, Tp. HCM
# - Cơ sở 2: Phường Linh Trung, Thành phố Thủ Đức, Tp. HCM
#
# 2. Mục tiêu đào tạo
# 2.1. Mục tiêu chung
# Mục tiêu của chương trình là nhằm đào tạo ra các sinh viên tốt nghiệp:
# Metadata: {'source': 'TTNT.txt'}
# --------------------------------------------------------------------------------
# ============================
# Chunk 3:
# 2. Mục tiêu đào tạo
# 2.1. Mục tiêu chung
# Mục tiêu của chương trình là nhằm đào tạo ra các sinh viên tốt nghiệp:
# - Có kiến thức kỹ thuật vững chắc; hiểu được trách nhiệm và đạo đức nghề nghiệp để áp dụng các công nghệ, kỹ thuật mới nhất của ngành công nghệ thông tin (CNTT) vào việc giải quyết các vấn đề thực tế; có thể áp dụng các phương pháp khoa học trong việc thực hiện nghiên cứu trong lĩnh vực CNTT.
# - Được trang bị những kỹ năng cá nhân, kỹ năng nhóm, kỹ năng giao tiếp và kỹ năng phân tích để nhận biết và giải quyết các vấn đề thực tế một cách có hệ thống, có logic và sáng
# tạo.
# Metadata: {'source': 'TTNT.txt'}
# --------------------------------------------------------------------------------
# ============================
# Chunk 4:
# 2.1. Mục tiêu chung
# - Được trang bị những kỹ năng cá nhân, kỹ năng nhóm, kỹ năng giao tiếp và kỹ năng phân tích để nhận biết và giải quyết các vấn đề thực tế một cách có hệ thống, có logic và sáng
# tạo.
# - Được trang bị đầy đủ kiến thức và kỹ năng để có thể hình thành vấn đề, phân tích, thiết kế, giải quyết vấn đề và vận hành hệ thống CNTT.
#
# 2.2. Mục tiêu cụ thể
# PO1: Nhận biết được trách nhiệm, đạo đức nghề nghiệp, và hiện trạng kinh tế, môi trường
# và xã hội.
# PO2: Có đầy đủ các kỹ năng cá nhân, kỹ năng nhóm, kỹ năng giao tiếp và kỹ năng phân
# tích.
# Metadata: {'source': 'TTNT.txt'}
# --------------------------------------------------------------------------------
# ============================
# Chunk 5:
# 2.2. Mục tiêu cụ thể
# PO1: Nhận biết được trách nhiệm, đạo đức nghề nghiệp, và hiện trạng kinh tế, môi trường
# và xã hội.
# PO2: Có đầy đủ các kỹ năng cá nhân, kỹ năng nhóm, kỹ năng giao tiếp và kỹ năng phân
# tích.
# РОЗ: Có khả năng học và tự học suốt đời; có khả năng kế thừa và phát triển kiến thức, kỹ năng chuyên môn.
# PO4: Có khả năng áp dụng các kiến thức và kỹ năng chuyên môn trong quá trình giải quyết các vấn đề thực tế.
# PO5: Có khả năng hình thành ý tưởng, phân tích, thiết kế, giải quyết và vận hành các hệ thống CNTT.
# Metadata: {'source': 'TTNT.txt'}
# --------------------------------------------------------------------------------
#
# Độ dài trung bình của chunks: 544.07 ký tự
# Chunk ngắn nhất: 203 ký tự
# Chunk dài nhất: 635 ký tự

# %%
COLLECTION_NAME = "ITUS_e5_600v2"

# %%
from langchain.embeddings import HuggingFaceInferenceAPIEmbeddings

# 1. Sử dụng chunked_documents từ TextSplitter
print(f"Số lượng chunks để add vào Qdrant: {len(chunked_documents)}")

# 2. Tạo embeddings và add vào Qdrant
if len(chunked_documents) > 0:
    # Khởi tạo embeddings
    embeddings = HuggingFaceInferenceAPIEmbeddings(
        model_name=EMBEDDINGS_MODEL_NAME,
        api_key=HUGGINGFACE_API_KEY
    )

    # Tạo vector database từ chunks
    qdrant = Qdrant.from_documents(
        chunked_documents,
        embeddings,
        url=QDRANT_URL,
        prefer_grpc=False,
        collection_name=COLLECTION_NAME,  # Đổi tên collection để phân biệt
        api_key=QDRANT_API_KEY
    )
    print("Đã tạo vector database thành công!")
else:
    print("Không có dữ liệu chunks để tạo vector database!")
# Out:
# Số lượng chunks để add vào Qdrant: 1539
# Đã tạo vector database thành công!

# %%
# Test tìm kiếm
query = "Các môn học Học kỳ 2 năm 3 ngành hệ thống thông tin"
found_docs = qdrant.similarity_search(query, k=10)

print("\nKết quả test tìm kiếm:")
for i, doc in enumerate(found_docs):
    print(f"\nKết quả {i+1}:")
    print(doc.page_content)
    print(doc.metadata)
    print("-" * 80)
# Out:
# Kết quả test tìm kiếm:
#
# Kết quả 1:
# 8.2.6. Các môn học Học kỳ 2 năm 3 Chuyên ngành Công nghệ thông tin
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10107 Thực tập thực tế
# CSC11006 Nhập môn điện toán đám mây
# CSC15003 Mã hóa ứng dụng
# CSC10102 Kiến tập nghề nghiệp
# CSC10103 Khởi nghiệp
# CSC10104 Quy hoạch tuyển tinh
# CSC10106 Thuật toán tổ hợp và ứng dụng
# CSC12004 Phân tích thiết kế hệ thống thông tin
# CSC11006 Nhập môn điện toán đám mây
# CSC12105 Thương mại điện tử
# CSC13010 Thiết kế phần mềm
# CSC14005 Nhập môn học máy
# CSC14118 Nhập môn dữ liệu lớn
# CSC17001 Phân tích dữ liệu thông minh
# CSC15004 Học thống kê
# CSC15007 Thống kê máy tính và ứng
# {'source': 'CNTT.txt', '_id': '983b2ee8-c625-43e8-90f2-3b64f20b7777', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
#
# Kết quả 2:
# 8.2.6. Các môn học Học kỳ 2 năm 3 Chuyên ngành Công nghệ thông tin
# CSC15107 Phân tích dữ liệu bảo toàn
#
# 8.2.7. Các môn học Học kỳ 1 năm 4 Chuyên ngành Công nghệ thông tin
# BAA00104 Lịch sử Đảng Cộng sản Việt Nam
# CSC15001 An ninh máy tính
# CSC11003 Lập trình mạng
# CSC11106 Truyền thông không dây
# CSC12110 Phân tích dữ liệu ứng dụng
# CSC13003 Kiểm thử phần mềm
# CSC13106 Kiến trúc phần mềm
# CSC13006 Quản lý dự án phần mềm
# CSC13112 Thiết kế giao diện
# CSC14117 Nhập môn lập trình kết nối vạn vật
# CSC14120 Lập trình song song
# CSC15011 Nhập môn ngôn ngữ học thống kê và ứng dụng
# CSC15010 Blockchain và ứng
# {'source': 'CNTT.txt', '_id': 'd935cd57-7b32-42d9-9deb-dd4c273e4706', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
#
# Kết quả 3:
# 8.7. Các môn học Học kỳ 2 năm 3 Ngành Hệ thống Thông tin
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC14003 Cơ sở trí tuệ nhân tạo
# CSC10102 Kiến tập nghề nghiệp
# CSC10104 Quy hoạch tuyến tính
# CSC10106 Thuật toán tổ hợp và ứng dụng
# CSC10107 Thực tập thực tế
# CSC12001 An toàn và bảo mật dữ liệu trong hệ thống thông tin
# CSC12004 Phân tích thiết kế hệ thống thông tin
# CSC12103 Chuyên đề Hệ quản trị cơ sở dữ liệu nâng cao
# CSC12105 Thương mại điện tử
#
# 8.8. Các môn học Học kỳ hè năm 3 Ngành Hệ thống Thông tin
# CSC10103 Khởi nghiệp
#
# 8.9. Các môn học Học kỳ 1 năm 4 Ngành Hệ thống Thông tin
# {'source': 'HTTT.txt', '_id': '79a04be7-d01c-4bc9-b342-bdcb7a83c0f3', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
#
# Kết quả 4:
# 8.2.8. Các môn học Học kỳ 2 năm 4 Chuyên ngành Công nghệ thông tin
# CSC10108 Trực quan hóa dữ liệu
# CSC14101 Ẩn dữ liệu và chia sẻ thông tin
# CSC10251 Khóa luận tốt nghiệp
# CSC10252 Thực tập tốt nghiệp
# CSC10204 Thực tập dự án tốt nghiệp
# 9. Khả năng liên thông với các chương trình đào tạo khác
# Sinh viên có thể liên thông với chương trình đào tạo trình độ đại học của các ngành sau đây:
# Ngành Công nghệ thông tin
# Ngành Kỹ thuật phần mềm
# Ngành Khoa học máy tính
# Ngành Trí tuệ nhân tạo
# Ngoài ra, sinh viên cũng có thể liên thông với chương trình đào tạo trình độ thạc sỹ của các ngành sau đây:
# {'source': 'CNTT.txt', '_id': 'b47c0523-5827-4941-bade-c0199a8bcb49', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
#
# Kết quả 5:
# 8.2.6. Các môn học Học kỳ 2 năm 3 Chuyên ngành Công nghệ tri thức
# CSC13002 Nhập môn công nghệ phần mềm
# BAA00103 Chủ nghĩa xã hội khoa học
# CSC10102 Kiến tập nghề nghiệp
# CSC10104 Quy hoạch tuyến tính
# CSC10106 Thuật toán tổ hợp ứng dụng
# CSC10107 Thực tập thực tế
# CSC15002 Bảo mật cơ sở dữ liệu
# CSC15003 Mã hóa ứng dụng
# CSC15004 Học thống kê
# CSC15007 Thống kê máy tính và ứng dụng
# CSC15012 Ứng dụng xử lý ngôn ngữ tự nhiên trong doanh nghiệp
# CSC15107 Phân tích dữ liệu bảo toàn tinh riêng tư
# CSC15108 Pháp chứng cho dữ liệu số
# CSC15105 Khai thác dữ liệu văn bản và ứng dụng
# {'source': 'KHMT.txt', '_id': '5fbe2c0d-dd1e-42e3-9b36-d5ed5319161e', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
#
# Kết quả 6:
# 8.5.8. Các môn học Học kỳ 2 năm 4 Chuyên ngành Khoa học dữ liệu
# CSC10251 Khóa luận tốt nghiệp
# CSC10252 Thực tập tốt nghiệp
# CSC10204 Thực tập dự án tốt nghiệp
# CSC14115 Khoa học dữ liệu ứng dụng
# CSC14116 Lập trình song song ứng dụng
# 9. Khả năng liên thông với các chương trình đào tạo khác
# Sinh viên có thể liên thông với chương trình đào tạo trình độ đại học của các ngành sau đây:
# Ngành Công nghệ thông tin
# Ngành Kỹ thuật phần mềm
# Ngành Khoa học máy tính
# Ngành Trí tuệ nhân tạo
# Ngoài ra, sinh viên cũng có thể liên thông với chương trình đào tạo trình độ thạc sỹ của các ngành sau đây:
# {'source': 'KHMT.txt', '_id': '6a328539-71cd-429b-b1fb-0c044b99e877', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
#
# Kết quả 7:
# 8.8. Các môn học Học kỳ 2 năm 4 Ngành Kỹ thuật phần mềm
# CSC13117 Phát triển game nâng cao
# CSC10251 Khóa luận tốt nghiệp
# CSC10252 Thực tập tốt nghiệp
# CSC10204 Thực tập dự án tốt nghiệp
# CSC13115 Các công nghệ mới trong phát triển phần mềm
# CSC13116 Đồ án Công nghệ phần mềm
#
# 9. Khả năng liên thông với các chương trình đào tạo khác của Ngành Kỹ thuật phần mềm
# Sinh viên có thể liên thông với chương trình đào tạo trình độ đại học của các ngành sau đây:
# Ngành Công nghệ thông tin
# Ngành Kỹ thuật phần mềm
# Ngành Khoa học máy tính
# Ngành Trí tuệ nhân tạo
# {'source': 'KTPM.txt', '_id': 'c897ef0a-31e8-43e6-a78c-d1d21fe81e38', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
#
# Kết quả 8:
# 8.4.4. Các môn học Học kỳ 2 năm 2 Chuyên ngành An toàn thông tin
# ADD00034 Anh văn 4
# BAA00101 Triết học Mác – Lênin
# BAA00005 Kinh tế đại cương
# BAA00006 Tâm lý đại cương
# BAA00007 Phương pháp luận sáng tạo
# MTH00051 Toán ứng dụng và thống kê
# MTH00052 Phương pháp tính
# MTH00053 Lý thuyết số
# CSC10003 Phương pháp lập trình hướng đối tượng
# CSC10006 Cơ sở dữ liệu
# CSC10009 Hệ thống máy tính
# CSC10121 Kỹ năng mềm (Học kỳ hè năm 2)
#
# 8.4.5. Các môn học Học kỳ 1 năm 3 Chuyên ngành An toàn thông tin
# BAA00102 Kinh tế chính trị Mác – Lênin
# GEO00002 Khoa học Trái đất
# ENV00001 Môi trường đại cương
# {'source': 'KHMT.txt', '_id': 'fc3d9ae1-6745-4584-aa63-993d9ccfaa35', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
#
# Kết quả 9:
# 8.2.4. Các môn học Học kỳ 2 năm 2 Chuyên ngành Công nghệ thông tin
# ADD00034 Anh văn 4
# BAA00101 Triết học Mác – Lênin
# BAA00005 Kinh tế đại cương
# BAA00006 Tâm lý đại cương
# BAA00007 Phương pháp luận sáng tạo
# MTH00051 Toán ứng dụng và thống kê
# MTH00052 Phương pháp tính
# MTH00053 Lý thuyết số
# CSC10003 Phương pháp lập trình hướng đối tượng
# CSC10006 Cơ sở dữ liệu
# CSC10009 Hệ thống máy tính
# CSC10121 Kỹ năng mềm (Học kỳ hè năm 2)
#
# 8.2.5. Các môn học Học kỳ 1 năm 3 Chuyên ngành Công nghệ thông tin
# BAA00102 Kinh tế chính trị Mác – Lênin
# GEO00002 Khoa học Trái đất
# ENV00001 Môi trường đại cương
# {'source': 'CNTT.txt', '_id': '5e9339f4-c962-4f67-9ec2-7ee290dcc704', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
#
# Kết quả 10:
# 8.10. Các môn học Học kỳ 2 năm 4 Ngành Hệ thống Thông tin
# CSC12107 Hệ thống thông tin phục vụ trí tuệ kinh doanh
# BAA00003 Tư tưởng Hồ Chí Minh
# CSC10108 Trực quan hóa dữ liệu
# CSC12102 Chuyên đề chọn lọc trong Hệ thống thông tin
# CSC17101 Hệ thống tư vấn
# CSC10251 Khóa luận tốt nghiệp
# CSC10252 Thực tập tốt nghiệp
# CSC10204 Thực tập dự án tốt nghiệp
# CSC12108 Ứng dụng phân tán
# CSC12111 Quản trị cơ sở dữ liệu hiện đại
#
# 9. Khả năng liên thông với các chương trình đào tạo khác của Ngành Hệ thống Thông tin
# {'source': 'HTTT.txt', '_id': 'dc370839-fb20-4d78-888b-04dfb1c5b2d1', '_collection_name': 'ITUS_e5_600v2'}
# --------------------------------------------------------------------------------
